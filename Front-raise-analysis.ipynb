# %%
from Parser import parse_frames
from scipy.signal import medfilt
from Functions import find_extremas, filter_extremas, detect_side, analyse_each_rep
from JointAngles import JointAngles
import numpy as np
import math
import glob
import os
import itertools
import pickle
import matplotlib.pyplot as plt

# %%
# modify this path for other videos 
# input_folder = "/home/aleko/Documents/Projects/IndividualProject/bicepvid"
input_folder = "C:\\Users\\altaok\\Documents\\GitHub\\IndividualProject\\keypoints_for_all\\front raise"
#input_folder = 'C:\\Users\\ak5u16\\Desktop\\IndividualProject\\keypoints_for_all\\front raise'
folder_paths = glob.glob(os.path.join(input_folder, 'front_raise_incorrect*'))     

min_upper_arm_forearm = [] 
max_upper_arm_forearm = []
max_upper_arm_trunk = []
min_upper_arm_trunk = []
min_trunk_knee = []
max_trunk_knee = []


for folder in folder_paths:
    print("Starting..." + "\nKeypoints from folder: " + os.path.basename(folder))
    video_name = os.path.basename(folder)
    frame_poses = parse_frames(folder)
    
    joint_angles = JointAngles('triceps pushdown', frame_poses)
    print('Detected arm: ' + joint_angles.side)

    upArm_trunk_angles = np.array(joint_angles.upArm_trunk_angles)
    upArm_trunk_angles_filtered = medfilt(medfilt(upArm_trunk_angles, 5), 5)
    
   
    upArm_forearm_angles = np.array(joint_angles.upArm_forearm_angles)
    upArm_forearm_angles_filtered = medfilt(medfilt(upArm_forearm_angles, 5), 5)
    
    trunk_knee_angles = np.array(joint_angles.trunk_knee_angles)
    trunk_knee_angles_filtered = medfilt(medfilt(trunk_knee_angles, 5), 5)
    
    # Find upper arm and trunk maximum angles to detect wrong form 
    upArm_trunk_maximas = find_extremas(upArm_trunk_angles_filtered)
    upArm_trunk_maximas = filter_extremas(upArm_trunk_angles_filtered, upArm_trunk_maximas)
    indexesmax1 = np.array([np.argwhere(upArm_trunk_angles_filtered == maxima)[0][0] for maxima in upArm_trunk_maximas])
    
    print('\n----------------------------Filtering minimas-------------------------------------')
    upArm_trunk_minimas = find_extremas(upArm_trunk_angles_filtered, maxima=False)
    upArm_trunk_minimas = filter_extremas(upArm_trunk_angles_filtered, upArm_trunk_minimas, maxima=False)
    indexesmin2 = np.array([np.argwhere(upArm_trunk_angles_filtered == minima)[0][0] for minima in upArm_trunk_minimas])
  
    # print("Largest angles between upper arm and trunk: " + str(upArm_trunk_maximas))

    # Find trunk and knee maximum angles to detect wrong form 
    trunk_knee_maximas = find_extremas(trunk_knee_angles_filtered)
    trunk_knee_maximas = filter_extremas(trunk_knee_angles_filtered, trunk_knee_maximas)
    indexesmax2 = np.array([np.argwhere(trunk_knee_angles_filtered == maxima)[0][0] for maxima in trunk_knee_maximas])
   
    # print("Largest angles between trunk and knee: " + str(trunk_knee_maximas))

    # Count repetitions
    upArm_forearm_maximas = find_extremas(upArm_forearm_angles_filtered)  
    upArm_forearm_maximas = filter_extremas(upArm_forearm_angles_filtered, upArm_forearm_maximas)
    indexesmax3 = np.array([np.argwhere(upArm_forearm_angles_filtered == maxima)[0][0] for maxima in upArm_forearm_maximas])
   
    # print("Number of maxima points between Upper Arm and Forearm: " + str(upArm_forearm_maximas.size))
    # print(upArm_forearm_maximas)
    
    # Find upper arm and forearm minimum points to count reps 
    upArm_forearm_minimas = find_extremas(upArm_forearm_angles_filtered, maxima=False)
    upArm_forearm_minimas = filter_extremas(upArm_forearm_angles_filtered, upArm_forearm_minimas, maxima=False)
    indexesmin = np.array([np.argwhere(upArm_forearm_angles_filtered == minima)[0][0] for minima in upArm_forearm_minimas])
    print("\nSize of minima array: " + str(upArm_forearm_minimas.size))
    print('-'*90)
    
   
    # Plot 1
    plt.figure(figsize=(10,4))
    plt.scatter(np.arange(upArm_trunk_angles.shape[0]), upArm_trunk_angles, alpha=0.5)
    plt.scatter(np.arange(upArm_trunk_angles_filtered.shape[0]), upArm_trunk_angles_filtered, c='r', alpha=0.5)
    plt.title(video_name)
    plt.xlabel('Frames')
    plt.ylabel('Angle between Upper Arm and Trunk')
    # Set range on y-axis so the plots are consistent
    plt.ylim(0,180)
    
    # Annontate extrema points
    plt.plot(indexesmax1, upArm_trunk_angles_filtered[indexesmax1], 'ks')
    
    plt.plot(indexesmin2, upArm_trunk_angles_filtered[indexesmin2], 'bo')
    plt.show()
    
    # Plot 2
    plt.figure(figsize=(10,4))
    plt.scatter(np.arange(trunk_knee_angles.shape[0]), trunk_knee_angles, alpha=0.5)
    plt.scatter(np.arange(trunk_knee_angles_filtered.shape[0]), trunk_knee_angles_filtered, c='r', alpha=0.5)
    plt.title(video_name)
    plt.xlabel('Frames')
    plt.ylabel('Angle between Trunk and Knee')
    # Set range on y-axis so the plots are consistent
    plt.ylim(0,360)
    
    # Annontate maxima points
    #plt.plot(indexesmax2, trunk_knee_angles_filtered[indexesmax2], 'ks')
    plt.show()

    # Plot 3
    plt.figure(figsize=(10,4))
    plt.scatter(np.arange(upArm_forearm_angles.shape[0]), upArm_forearm_angles, alpha=0.5)
    plt.scatter(np.arange(upArm_forearm_angles_filtered.shape[0]), upArm_forearm_angles_filtered, c='r', alpha=0.5)
    plt.title(video_name)
    plt.xlabel('Frames')
    plt.ylabel('Angle between Upper Arm and Forearm')
    # Set range on y-axis so the plots are consistent
    plt.ylim(0,220) 
    
    # Annotate minima apoints on the graph   
    max_points = upArm_forearm_angles_filtered[indexesmax3]
    #min_points = upArm_forearm_angles_filtered[indexesmin]
    #plt.plot(indexesmin, min_points, 'bo')
    plt.plot(indexesmax3, max_points, 'ks')

    """
        # Annotate local maximas
        for maxp, indx in zip(max_points, indexesmax3):
            plt.annotate('local max', xy=(indx, maxp), xytext=(indx, maxp+25),
                    arrowprops=dict(facecolor='black', shrink=0.05))

        # Annotate local minimas
        for minp, indx in zip(min_points, indexesmin):
            plt.annotate('local min', xy=(indx, minp), xytext=(indx, minp-35),
                    arrowprops=dict(facecolor='black', shrink=0.05))     
    """
    plt.show()

    # Plot 4
    plt.figure(figsize=(10,4))
    plt.scatter(np.arange(upArm_forearm_angles_filtered.shape[0]), upArm_forearm_angles_filtered, c='r', alpha=0.5)
    plt.scatter(np.arange(upArm_trunk_angles_filtered.shape[0]), upArm_trunk_angles_filtered, c='r', alpha=0.5)
    plt.scatter(np.arange(trunk_knee_angles_filtered.shape[0]), trunk_knee_angles_filtered, c='r', alpha=0.5)
    plt.title(video_name)
    plt.xlabel('Frames')
    plt.ylabel('Whole body movement')
    # Set range on y-axis so the plots are consistent
    plt.ylim(0,250) 
    # Annotate minima apoints      
    #plt.plot(indexesmin, upArm_forearm_angles_filtered[indexesmin], 'bo')
    plt.plot(indexesmin2, upArm_trunk_angles_filtered[indexesmin2], 'ks')
    #plt.plot(indexesmax2, trunk_knee_angles_filtered[indexesmax2], 'ks')
    plt.plot(indexesmax3, upArm_forearm_angles_filtered[indexesmax3], 'ks')
    
    plt.show()
   
    
    # Each rep analysis
    # local minimums for upper arm and forearm are min angles in each rep
    """
    min_upper_arm_forearm1, max_upper_arm_forearm1, min_upper_arm_trunk1, max_upper_arm_trunk1, min_trunk_knee1, max_trunk_knee1 = analyse_each_rep(exercise='front raise', string='thresholds', 
                                                                                                                                         extremas1=upArm_trunk_minimas, 
                                                                                                                                         uf_angles1=upArm_forearm_angles_filtered, 
                                                                                                                                         ut_angles1=upArm_trunk_angles_filtered, 
                                                                                                                                         tk_angles1=trunk_knee_angles_filtered)

    """
    analyse_each_rep(exercise='front raise', string='analysis', extremas1=upArm_trunk_minimas,
                     uf_angles1=upArm_forearm_angles_filtered, ut_angles1=upArm_trunk_angles_filtered,
                     tk_angles1=trunk_knee_angles_filtered)
    """
    min_upper_arm_forearm = min_upper_arm_forearm + min_upper_arm_forearm1
    max_upper_arm_forearm = max_upper_arm_forearm + max_upper_arm_forearm1
    min_upper_arm_trunk = min_upper_arm_trunk + min_upper_arm_trunk1
    max_upper_arm_trunk = max_upper_arm_trunk + max_upper_arm_trunk1
    min_trunk_knee = min_trunk_knee + min_trunk_knee1
    max_trunk_knee = max_trunk_knee + max_trunk_knee1
    
    
    print('\n' + '='*120 + '\n')


print('Minimum in minimums Upper Arm Forearm threshold: ' + str(min(min_upper_arm_forearm)))
print('Maximum in minimums Upper Arm Forearm threshold: ' + str(max(min_upper_arm_forearm)))
print('Minimum in maximum Upper Arm Forearm threshold: ' + str(min(max_upper_arm_forearm)))
print('Maximum in maximum Upper Arm Forearm threshold: ' + str(max(max_upper_arm_forearm)))
print('Minimum in minimum Upper Arm Trunk angles: ' + str(min(min_upper_arm_trunk)))
print('Maximum in maximum Upper Arm Trunk angles: ' + str(max(max_upper_arm_trunk)))
print('Maximum in minimum Upper Arm Trunk angles: ' + str(max(min_upper_arm_trunk)))
print('Minimum in maximum Upper Arm Trunk angles: ' + str(min(max_upper_arm_trunk)))
print('Minimum Trunk Knee threshold: ' + str(min(min_trunk_knee)))
print('Maximum Trunk Knee threshold: ' + str(min(max_trunk_knee)))
"""
# Out:
# Starting...
# Keypoints from folder: front_raise_incorrect_1
# Detected arm: right
#
#
# extremas: [132.77352778 142.85506208 134.60112202 135.80276439]
# angle change threshold: 26.51237224223661
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [47, 49, 50]
# threshold: 27
# average count: 48
# []
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
#
#
# extremas: [ 4.93624419  8.59529477  2.60883937 18.73272207]
# angle change threshold: 28.589796228026813
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [50, 48, 47]
# threshold: 27
# average count: 48
# []
# Array filtering: Done
#
#
# extremas: [178.4768991  170.35031258 178.06643914 173.5069478  172.7033958
#  176.31629697 178.29533618 174.29153625 178.22995747 172.04691359]
# angle change threshold: 24.546995757340262
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [14, 27, 11, 7, 19, 14, 34, 14, 17]
# threshold: 17
# average count: 17
# [14, 11, 7, 14, 14]
# Array filtering: Done
#
#
# extremas: [171.58957518 166.80001518 171.89963705 168.5481759  167.71121315
#  170.13480011 165.33201629 160.99685834 168.29599588 165.80699717]
# angle change threshold: 23.936363417347238
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [17, 30, 16, 20, 9, 15, 21, 13, 13]
# threshold: 17
# average count: 17
# [16, 9, 15, 13, 13]
# Array filtering: Done
#
#
# extremas: [164.06950373 155.51889217 162.36136256 156.88324102 165.71429458
#  160.27744271 148.6254684  157.8294602  160.70467161 145.38914912]
# angle change threshold: 28.242867661522034
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [21, 21, 24, 11, 11, 21, 13, 17, 22]
# threshold: 17
# average count: 17
# [11, 11, 13]
# Array filtering: Done
#
# Size of minima array: 10
# ------------------------------------------------------------------------------------------
# Number of reps performed: 4
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 155.51889216913108
# Maximum angle between upper arm and forearm: 171.58957518102963
# Minimum angle between upper arm and trunk: 4.936244185782099
# Maximum angle between upper arm and trunk: 132.77352777856447
# Minimum angle between trunk and knee: 169.19894725065564
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 155.51889216913108
# Maximum angle between upper arm and forearm: 171.89963705049817
# Minimum angle between upper arm and trunk: 4.936244185782099
# Maximum angle between upper arm and trunk: 142.85506208358538
# Minimum angle between trunk and knee: 168.2414335504619
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 148.62546839573858
# Maximum angle between upper arm and forearm: 170.1348001105293
# Minimum angle between upper arm and trunk: 2.6088393673600545
# Maximum angle between upper arm and trunk: 134.6011220240967
# Minimum angle between trunk and knee: 167.2216837483698
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 145.38914912014673
# Maximum angle between upper arm and forearm: 168.29599587906102
# Minimum angle between upper arm and trunk: 2.6088393673600545
# Maximum angle between upper arm and trunk: 135.80276438629693
# Minimum angle between trunk and knee: 168.2635203922429
# Starting...
# Keypoints from folder: front_raise_incorrect_10
# Detected arm: left
#
#
# extremas: [135.04074924 132.09112483 138.70855264 124.44256395 139.98848492
#  126.72470318 126.73879617 117.31686576]
# angle change threshold: 28.868395289147784
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [45, 48, 43, 45, 44, 42, 41]
# threshold: 29
# average count: 44
# []
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
#
#
# extremas: [30.80890257 25.35889841 24.3693231  29.86866417 24.69714413 25.96720004
#  22.45606358]
# angle change threshold: 23.648605491658113
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [45, 46, 44, 45, 42, 40]
# threshold: 27
# average count: 43
# []
# Array filtering: Done
#
#
# extremas: [150.84913186 152.21998198 151.36392595 152.5576713  154.26791711
#  151.69800991 151.27520268 151.25504758 151.66929547 155.53328197
#  154.31241639 148.10606952 149.56637307 153.56880676 152.86650075
#  152.27550195 151.4230197  151.7041377  151.27227753 151.2882583
#  154.28683772 153.50574446]
# angle change threshold: 21.522208076715575
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [12, 15, 17, 10, 14, 20, 13, 19, 12, 10, 15, 5, 8, 15, 12, 16, 16, 13, 13, 10, 30]
# threshold: 28
# average count: 14
# [12, 15, 17, 10, 14, 20, 13, 19, 12, 10, 15, 5, 8, 15, 12, 16, 16, 13, 13, 10]
# Array filtering: Done
#
#
# extremas: [176.47664008 174.69423391 178.17207872 171.56524958 174.61781414
#  174.50264388 175.79553818 171.82883731 166.18122347 176.84067777
#  173.59136598 174.87670059 178.0117786  163.14719245 175.07497521
#  169.95150618]
# angle change threshold: 25.079136039493683
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [8, 40, 13, 26, 1, 49, 5, 10, 23, 14, 29, 46, 20, 16, 11]
# threshold: 25
# average count: 20
# [8, 13, 1, 5, 10, 23, 14, 20, 16, 11]
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [8, 40, 13, 26, 1, 49, 5, 10, 23, 14, 29, 46, 20, 16, 11]
# threshold: 25
# Array filtering: Done
#
#
# extremas: [173.29061657 163.4704031  170.7269924  160.08061563 174.49887964
#  162.09477884 171.71473074 165.92295659 163.58025948 172.82149966
#  158.23940443 159.63307226 161.9964588  163.04632882 169.76709023
#  168.11595448]
# angle change threshold: 27.28680829758858
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [21, 32, 13, 22, 25, 26, 6, 12, 25, 17, 42, 41, 1, 21, 6]
# threshold: 25
# average count: 20
# [21, 13, 22, 6, 12, 17, 1, 21, 6]
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [21, 32, 13, 22, 25, 26, 6, 12, 25, 17, 42, 41, 1, 21, 6]
# threshold: 25
# Array filtering: Done
#
# Size of minima array: 8
# ------------------------------------------------------------------------------------------
# Number of reps performed: 8
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 158.09905894276864
# Maximum angle between upper arm and forearm: 176.47664008288544
# Minimum angle between upper arm and trunk: 25.590007295243446
# Maximum angle between upper arm and trunk: 135.0407492408277
# Minimum angle between trunk and knee: 147.18666972495078
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 160.08061562611647
# Maximum angle between upper arm and forearm: 178.1720787246211
# Minimum angle between upper arm and trunk: 25.358898413870033
# Maximum angle between upper arm and trunk: 132.09112482968527
# Minimum angle between trunk and knee: 149.72742454219937
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 160.08061562611647
# Maximum angle between upper arm and forearm: 174.6178141392648
# Minimum angle between upper arm and trunk: 24.369323097170902
# Maximum angle between upper arm and trunk: 138.70855263873239
# Minimum angle between trunk and knee: 148.00319346006586
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 162.094778844944
# Maximum angle between upper arm and forearm: 175.79553817549305
# Minimum angle between upper arm and trunk: 24.369323097170902
# Maximum angle between upper arm and trunk: 124.44256394548619
# Minimum angle between trunk and knee: 147.88660689865196
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 159.17244943616438
# Maximum angle between upper arm and forearm: 176.84067776585135
# Minimum angle between upper arm and trunk: 24.69714412836952
# Maximum angle between upper arm and trunk: 139.98848492147684
# Minimum angle between trunk and knee: 148.10606951514416
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 158.23940442625877
# Maximum angle between upper arm and forearm: 174.87670059060335
# Minimum angle between upper arm and trunk: 24.69714412836952
# Maximum angle between upper arm and trunk: 126.724703182696
# Minimum angle between trunk and knee: 149.06689854017935
#
# Repetition: 7
#
# Minimum angle between upper arm and forearm: 159.6330722596847
# Maximum angle between upper arm and forearm: 178.0117785976531
# Minimum angle between upper arm and trunk: 22.456063581562933
# Maximum angle between upper arm and trunk: 126.73879616755907
# Minimum angle between trunk and knee: 149.9901147777888
#
# Repetition: 8
#
# Minimum angle between upper arm and forearm: 161.99645879646917
# Maximum angle between upper arm and forearm: 175.0749752107569
# Minimum angle between upper arm and trunk: 22.456063581562933
# Maximum angle between upper arm and trunk: 117.31686575659488
# Minimum angle between trunk and knee: 150.2636528806528
# Starting...
# Keypoints from folder: front_raise_incorrect_2
# Detected arm: right
#
#
# extremas: [161.23980392 145.54231581 140.24205359 164.75619581 143.17222206
#  147.51550699]
# angle change threshold: 34.28783024322118
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [50, 49, 52, 54, 58]
# threshold: 31
# average count: 52
# []
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
#
#
# extremas: [10.87002628 14.84786572 10.09129276 10.37839817 13.04388768]
# angle change threshold: 22.92175182968952
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [48, 51, 55, 55]
# threshold: 30
# average count: 52
# []
# Array filtering: Done
#
#
# extremas: [179.32068579 178.95955371 179.67599261 176.74347037 178.9315952
#  178.80438632 171.81302158 174.42579049 170.0075059  176.91211944
#  176.5511975  178.90142073 178.08135384 177.48104148 174.5244644
#  176.32158855 177.39802435 179.13659508 179.32265351]
# angle change threshold: 22.17437496242317
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [12, 13, 7, 15, 7, 15, 26, 22, 19, 17, 36, 14, 6, 22, 15, 9, 12, 27]
# threshold: 26
# average count: 16
# [12, 13, 7, 15, 7, 15, 22, 19, 17, 14, 6, 22, 15, 9, 12]
# Array filtering: Done
#
#
# extremas: [178.25601398 172.97144378 175.0346691  177.73628489 171.8091389
#  168.8002634  171.9489389  172.23125153 168.77875604 165.76932773
#  176.5742693  168.66079374 164.69188927 164.69188927 171.67870412
#  169.83636662 168.33308505 168.44840174 170.83538559 167.13089423
#  168.86679823]
# angle change threshold: 23.492039807135694
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [16, 5, 27, 8, 8, 19, 8, 24, 7, 22, 11, 9, 1, 31, 14, 7, 21, 17, 11, 10]
# threshold: 26
# average count: 13
# [16, 5, 8, 8, 19, 8, 24, 7, 22, 11, 9, 1, 14, 7, 21, 17, 11, 10]
# Array filtering: Done
#
#
# extremas: [173.06929283 169.95601122 171.23654092 166.78614459 171.26053013
#  167.6996342  163.41047291 169.96421411 163.51476832 164.58514994
#  163.16730941 164.19121637 162.74652736 163.56491613 159.52160211
#  167.95833626 168.20412913 157.87976544 167.58202299 166.72988167
#  166.76881311]
# angle change threshold: 23.67952896668222
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [19, 7, 8, 27, 12, 7, 13, 24, 10, 8, 22, 10, 3, 8, 33, 11, 14, 15, 18, 11]
# threshold: 27
# average count: 14
# [19, 7, 8, 12, 7, 13, 24, 10, 8, 22, 10, 3, 8, 11, 14, 15, 18, 11]
# Array filtering: Done
#
# Size of minima array: 21
# ------------------------------------------------------------------------------------------
# Number of reps performed: 6
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 166.78614459044888
# Maximum angle between upper arm and forearm: 178.25601397640523
# Minimum angle between upper arm and trunk: 10.870026279961548
# Maximum angle between upper arm and trunk: 161.2398039208578
# Minimum angle between trunk and knee: 176.28335332839876
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 163.41047290576566
# Maximum angle between upper arm and forearm: 177.73628488924325
# Minimum angle between upper arm and trunk: 10.870026279961548
# Maximum angle between upper arm and trunk: 145.54231580968656
# Minimum angle between trunk and knee: 167.99740841272146
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 163.16730941138863
# Maximum angle between upper arm and forearm: 172.2312515294552
# Minimum angle between upper arm and trunk: 10.09129275762906
# Maximum angle between upper arm and trunk: 140.2420535931947
# Minimum angle between trunk and knee: 168.1453643222777
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 159.52160210992875
# Maximum angle between upper arm and forearm: 176.57426930270267
# Minimum angle between upper arm and trunk: 10.09129275762906
# Maximum angle between upper arm and trunk: 164.75619580817346
# Minimum angle between trunk and knee: 166.79551174801358
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 157.8797654391836
# Maximum angle between upper arm and forearm: 171.67870411906154
# Minimum angle between upper arm and trunk: 10.378398167328488
# Maximum angle between upper arm and trunk: 143.1722220617325
# Minimum angle between trunk and knee: 170.662642454097
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 156.2903738103767
# Maximum angle between upper arm and forearm: 170.83538558972563
# Minimum angle between upper arm and trunk: 9.287752271706827
# Maximum angle between upper arm and trunk: 147.51550698875556
# Minimum angle between trunk and knee: 173.53408087040478
# Starting...
# Keypoints from folder: front_raise_incorrect_3
# Detected arm: right
#
#
# extremas: [151.50699333 162.96783665 150.96731081 149.48299012 155.61056367
#  148.54489752 143.13771509]
# angle change threshold: 27.257685331141115
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [54, 59, 55, 52, 58, 57]
# threshold: 33
# average count: 55
# []
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
#
#
# extremas: [13.82691387 14.69324654 15.90909261 10.94768264  7.3356377  14.30168878]
# angle change threshold: 23.524336947478833
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [56, 58, 50, 58, 56]
# threshold: 32
# average count: 55
# []
# Array filtering: Done
#
#
# extremas: [178.86034149 172.77205746 175.30480885 177.65320947 179.2132069
#  178.81238945 178.89225227 173.86981413 179.92084322 179.48308941
#  179.51532914 174.13160336 177.53735458 174.30736045 176.5059556
#  177.7790157  175.97959515 176.78697076 176.66489977 173.26893404
#  179.16273114 178.77650979 179.70533121 175.25406581 179.15831712]
# angle change threshold: 22.5722454295401
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [25, 15, 21, 31, 7, 18, 13, 18, 7, 14, 14, 16, 11, 8, 12, 15, 9, 14, 15, 16, 11, 10, 17, 19]
# threshold: 31
# average count: 14
# [25, 15, 21, 7, 18, 13, 18, 7, 14, 14, 16, 11, 8, 12, 15, 9, 14, 15, 16, 11, 10, 17, 19]
# Array filtering: Done
#
#
# extremas: [173.2976666  170.82284259 177.21258126 174.91088023 174.47985504
#  169.51558136 169.71677439 170.35585668 176.78265322 169.51516039
#  168.53072483 172.50051077 170.99878734 175.19388038 169.13133956
#  166.83645187 166.13889004 173.05760131 171.56238255 168.34116194
#  167.42247209 169.85754645 174.51868306 171.02147533]
# angle change threshold: 23.215191946494414
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [14, 40, 12, 2, 11, 8, 9, 14, 25, 16, 11, 24, 26, 20, 14, 14, 8, 17, 7, 9, 7, 12, 25]
# threshold: 30
# average count: 15
# [14, 12, 2, 11, 8, 9, 14, 25, 16, 11, 24, 26, 20, 14, 14, 8, 17, 7, 9, 7, 12, 25]
# Array filtering: Done
#
#
# extremas: [164.70452541 161.16302547 171.90690874 173.87155699 168.98430758
#  168.48899286 165.44962602 169.47335752 162.08619332 165.79236526
#  164.83237462 166.45188802 165.5036211  167.44640396 165.74849378
#  159.18558913 166.07856828 167.05371883 167.46206081 167.27866331
#  166.75150179 168.55731349 164.29924811]
# angle change threshold: 23.116877567391477
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [31, 21, 5, 12, 7, 9, 6, 20, 26, 13, 9, 31, 29, 16, 14, 2, 16, 15, 7, 7, 10, 22]
# threshold: 29
# average count: 14
# [21, 5, 12, 7, 9, 6, 20, 26, 13, 9, 16, 14, 2, 16, 15, 7, 7, 10, 22]
# Array filtering: Done
#
# Size of minima array: 23
# ------------------------------------------------------------------------------------------
# Number of reps performed: 7
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 158.50004736641364
# Maximum angle between upper arm and forearm: 173.29766660251235
# Minimum angle between upper arm and trunk: 9.858411459633079
# Maximum angle between upper arm and trunk: 151.50699332938015
# Minimum angle between trunk and knee: 170.1170768882293
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 163.2591963479931
# Maximum angle between upper arm and forearm: 177.2125812644359
# Minimum angle between upper arm and trunk: 13.826913872245502
# Maximum angle between upper arm and trunk: 162.96783664553848
# Minimum angle between trunk and knee: 174.09884694075026
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 162.0861933152818
# Maximum angle between upper arm and forearm: 176.78265321902353
# Minimum angle between upper arm and trunk: 14.69324653878376
# Maximum angle between upper arm and trunk: 150.96731081360755
# Minimum angle between trunk and knee: 169.87438907393008
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 164.83237462160744
# Maximum angle between upper arm and forearm: 172.50051076642126
# Minimum angle between upper arm and trunk: 10.947682636440346
# Maximum angle between upper arm and trunk: 149.48299011514158
# Minimum angle between trunk and knee: 169.7455294723921
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 162.3942192241956
# Maximum angle between upper arm and forearm: 175.19388037794008
# Minimum angle between upper arm and trunk: 7.335637698808204
# Maximum angle between upper arm and trunk: 155.6105636724488
# Minimum angle between trunk and knee: 171.6389582349829
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 159.18558912879735
# Maximum angle between upper arm and forearm: 173.05760131012715
# Minimum angle between upper arm and trunk: 7.335637698808204
# Maximum angle between upper arm and trunk: 148.54489751719612
# Minimum angle between trunk and knee: 169.63628106471265
#
# Repetition: 7
#
# Minimum angle between upper arm and forearm: 160.2458916319914
# Maximum angle between upper arm and forearm: 174.5186830637865
# Minimum angle between upper arm and trunk: 10.899294251575137
# Maximum angle between upper arm and trunk: 143.13771508946456
# Minimum angle between trunk and knee: 172.32123522486023
# Starting...
# Keypoints from folder: front_raise_incorrect_4
# Detected arm: right
#
#
# extremas: [142.68689542 142.4193868  145.10145401 138.98332352 160.85987539]
# angle change threshold: 27.73606454820306
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [50, 64, 64, 62]
# threshold: 34
# average count: 60
# []
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
#
#
# extremas: [12.11845735  7.42826894  8.98033932 11.44827086]
# angle change threshold: 22.903396777280904
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [55, 69, 58]
# threshold: 33
# average count: 60
# []
# Array filtering: Done
#
#
# extremas: [179.24590012 178.362016   176.88968968 176.82296415 175.69097134
#  175.62244247 175.69373914 175.84728099 171.77076772 171.70077775
#  172.93401284 176.69216309 174.39720134 178.0748466  176.92203136
#  178.21751722 176.78280779]
# angle change threshold: 21.42761264227105
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [8, 31, 13, 25, 9, 20, 6, 23, 14, 8, 16, 10, 18, 10, 23, 17]
# threshold: 23
# average count: 15
# [8, 13, 9, 20, 6, 14, 8, 16, 10, 18, 10, 17]
# Array filtering: Done
#
#
# extremas: [174.42591186 169.67426098 172.86382013 168.42621101 163.802863
#  171.57958195 167.10989805 168.31085434 165.57848909 175.12021991
#  165.42210198 169.96195054 171.62440263 176.01337684]
# angle change threshold: 24.847155012086652
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [19, 32, 20, 16, 23, 19, 6, 18, 19, 21, 23, 7, 7]
# threshold: 21
# average count: 17
# [19, 20, 16, 19, 6, 18, 19, 7, 7]
# Array filtering: Done
#
#
# extremas: [166.74044416 159.99424922 165.43525649 163.17803966 161.06131343
#  161.11730646 166.72086756 163.20915293 164.57382778 161.49399983
#  164.43193262 168.00706274 171.21061731]
# angle change threshold: 23.324461190808506
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [22, 36, 16, 7, 31, 10, 18, 6, 27, 16, 20, 6]
# threshold: 20
# average count: 17
# [16, 7, 10, 18, 6, 16, 6]
# Array filtering: Done
#
# Size of minima array: 13
# ------------------------------------------------------------------------------------------
# Number of reps performed: 5
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 159.99424922437873
# Maximum angle between upper arm and forearm: 174.42591185618218
# Minimum angle between upper arm and trunk: 12.11845735217331
# Maximum angle between upper arm and trunk: 142.68689542219764
# Minimum angle between trunk and knee: 171.01817191849275
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 162.90961866561744
# Maximum angle between upper arm and forearm: 172.86382012853355
# Minimum angle between upper arm and trunk: 7.428268942513958
# Maximum angle between upper arm and trunk: 142.41938680489082
# Minimum angle between trunk and knee: 169.69901092808666
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 161.06131343120916
# Maximum angle between upper arm and forearm: 171.5795819535732
# Minimum angle between upper arm and trunk: 7.428268942513958
# Maximum angle between upper arm and trunk: 145.1014540109153
# Minimum angle between trunk and knee: 168.8825713041338
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 161.49399983411243
# Maximum angle between upper arm and forearm: 175.12021991027098
# Minimum angle between upper arm and trunk: 8.980339323458029
# Maximum angle between upper arm and trunk: 138.9833235170059
# Minimum angle between trunk and knee: 170.9422518216572
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 155.61948140219675
# Maximum angle between upper arm and forearm: 176.0133768410056
# Minimum angle between upper arm and trunk: 11.448270864697314
# Maximum angle between upper arm and trunk: 160.8598753925775
# Minimum angle between trunk and knee: 172.33219850905243
# Starting...
# Keypoints from folder: front_raise_incorrect_5
# Detected arm: left
#
#
# extremas: [100.99234878 119.29587689 116.8878919  120.60299959 121.26471573
#  118.03836243]
# angle change threshold: 25.662938046425886
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [59, 56, 53, 52, 55]
# threshold: 32
# average count: 55
# []
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
#
#
# extremas: [10.64767934 18.61174984 17.8548392  20.79853999 20.78543311]
# angle change threshold: 22.9194472069976
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [61, 53, 53, 54]
# threshold: 31
# average count: 55
# []
# Array filtering: Done
#
#
# extremas: [140.00230474 138.50902534 138.70606243 139.7788356  139.01013135
#  137.41500922 137.99252441 134.77223233 134.9313536  137.44884976
#  135.44088738 132.67068444 135.08308703 134.99150712 133.33322505
#  134.90697812 134.53289733]
# angle change threshold: 21.40560027954637
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [26, 7, 26, 26, 14, 17, 21, 13, 12, 7, 18, 14, 12, 26, 13, 13]
# threshold: 24
# average count: 16
# [7, 14, 17, 21, 13, 12, 7, 18, 14, 12, 13, 13]
# Array filtering: Done
#
#
# extremas: [163.22075997 162.96764034 162.30192229 164.90827835 162.9505825
#  161.14470747 168.65939634 165.92623645 160.18849115 160.4772275
#  167.44998356 165.09255091 157.73247394 169.27794946 165.80311867
#  163.69029753 167.56689694 165.39968342 161.97653371 161.38830941]
# angle change threshold: 23.549561846391285
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [18, 15, 13, 10, 21, 23, 9, 13, 8, 22, 7, 9, 29, 13, 22, 21, 10, 17, 8]
# threshold: 26
# average count: 15
# [18, 15, 13, 10, 21, 23, 9, 13, 8, 22, 7, 9, 13, 22, 21, 10, 17, 8]
# Array filtering: Done
#
#
# extremas: [162.41865682 153.90070409 160.17527045 161.06873344 159.97271466
#  152.67555524 156.57537674 161.26069041 157.41259507 153.20004607
#  158.20578715 162.07580806 155.58616479 156.50465027 162.27792046
#  157.55384101 159.97923509 162.34261968 155.60112169 159.08707654]
# angle change threshold: 24.343284826224824
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [11, 18, 11, 14, 15, 15, 24, 8, 12, 10, 20, 9, 6, 34, 18, 14, 21, 18, 9]
# threshold: 26
# average count: 15
# [11, 18, 11, 14, 15, 15, 24, 8, 12, 10, 20, 9, 6, 18, 14, 21, 18, 9]
# Array filtering: Done
#
# Size of minima array: 20
# ------------------------------------------------------------------------------------------
# Number of reps performed: 6
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 153.90070408706643
# Maximum angle between upper arm and forearm: 166.6428097539321
# Minimum angle between upper arm and trunk: 10.647679335603199
# Maximum angle between upper arm and trunk: 100.99234877938756
# Minimum angle between trunk and knee: 134.03451184961094
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 152.675555235722
# Maximum angle between upper arm and forearm: 167.4547484989661
# Minimum angle between upper arm and trunk: 10.647679335603199
# Maximum angle between upper arm and trunk: 119.29587689198586
# Minimum angle between trunk and knee: 134.58510990391395
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 153.2000460727053
# Maximum angle between upper arm and forearm: 168.6593963395435
# Minimum angle between upper arm and trunk: 17.854839199303782
# Maximum angle between upper arm and trunk: 116.88789190209745
# Minimum angle between trunk and knee: 132.1467539450868
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 155.5861647908406
# Maximum angle between upper arm and forearm: 169.27794945644192
# Minimum angle between upper arm and trunk: 17.854839199303782
# Maximum angle between upper arm and trunk: 120.60299959497044
# Minimum angle between trunk and knee: 131.389920097435
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 157.55384100659475
# Maximum angle between upper arm and forearm: 169.27794945644192
# Minimum angle between upper arm and trunk: 20.785433110555804
# Maximum angle between upper arm and trunk: 121.26471573203332
# Minimum angle between trunk and knee: 130.05172156090475
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 155.60112169293467
# Maximum angle between upper arm and forearm: 167.56689693575075
# Minimum angle between upper arm and trunk: 20.656782754887395
# Maximum angle between upper arm and trunk: 118.03836243232648
# Minimum angle between trunk and knee: 131.20477994213573
# Starting...
# Keypoints from folder: front_raise_incorrect_6
# Detected arm: left
#
#
# extremas: [117.66603319 121.56220349 116.9396863  119.40234892 122.6426558
#  126.32078648 122.52539309]
# angle change threshold: 23.615863513012894
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [51, 54, 52, 51, 54, 55]
# threshold: 32
# average count: 52
# []
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
#
#
# extremas: [15.07952316 20.09187507 21.04447383 20.36823035 20.36056358 16.29039728]
# angle change threshold: 22.143805443416646
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [56, 52, 50, 55, 55]
# threshold: 31
# average count: 53
# []
# Array filtering: Done
#
#
# extremas: [135.1481234  133.53790353 134.5984949  136.1342806  138.75812516
#  137.05716183 135.40005126 136.04316278 135.05286118 133.89017655
#  133.96076955 135.73325227 136.23459238 132.14648281 135.2335612
#  136.06764498 135.58173185 134.14765695 134.66641706 135.46939203
#  134.95411453 134.91199242]
# angle change threshold: 21.292258259514412
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [21, 8, 20, 11, 8, 20, 19, 5, 12, 15, 9, 7, 30, 14, 12, 5, 20, 15, 40, 21, 8]
# threshold: 28
# average count: 15
# [21, 8, 20, 11, 8, 20, 19, 5, 12, 15, 9, 7, 14, 12, 5, 20, 15, 21, 8]
# Array filtering: Done
#
#
# extremas: [168.22863513 163.66908055 157.23561249 158.37523548 164.24165099
#  164.88594357 163.42333505 162.46969335 166.06476868 169.67361121
#  164.4550931  161.85958453 165.21138991 163.72417025 164.25244787
#  169.81903265 167.36014506 158.22061978 166.78752924 173.94034535
#  168.36959326 170.10919714 169.94870755 165.58778945 163.56408057]
# angle change threshold: 23.67437695556875
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [12, 9, 9, 12, 8, 9, 8, 11, 23, 10, 20, 26, 13, 9, 20, 10, 9, 12, 23, 28, 16, 7, 7, 10]
# threshold: 30
# average count: 13
# [12, 9, 9, 12, 8, 9, 8, 11, 23, 10, 20, 26, 13, 9, 20, 10, 9, 12, 23, 28, 16, 7, 7, 10]
# Array filtering: Done
#
#
# extremas: [161.48922531 156.61377141 156.36815166 157.73253462 163.53766793
#  158.52598333 159.31459819 158.89902786 162.83435396 161.18241809
#  157.6250079  158.59549802 157.59105227 155.55384774 161.96600779
#  165.30244903 155.06065636 157.0851063  164.75264825 159.42570141
#  165.17096275 166.22090742 165.3979649  161.19428244 158.96534866]
# angle change threshold: 23.363473736721865
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [12, 7, 8, 13, 8, 10, 8, 13, 22, 17, 18, 24, 9, 10, 19, 11, 7, 16, 30, 23, 10, 6, 10, 8]
# threshold: 30
# average count: 13
# [12, 7, 8, 13, 8, 10, 8, 13, 22, 17, 18, 24, 9, 10, 19, 11, 7, 16, 23, 10, 6, 10, 8]
# Array filtering: Done
#
# Size of minima array: 25
# ------------------------------------------------------------------------------------------
# Number of reps performed: 7
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 156.3681516636919
# Maximum angle between upper arm and forearm: 168.22863513252383
# Minimum angle between upper arm and trunk: 15.079523159643232
# Maximum angle between upper arm and trunk: 117.6660331922996
# Minimum angle between trunk and knee: 131.42280899399455
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 158.5259833334053
# Maximum angle between upper arm and forearm: 168.91167914195327
# Minimum angle between upper arm and trunk: 15.079523159643232
# Maximum angle between upper arm and trunk: 121.56220349324444
# Minimum angle between trunk and knee: 131.84325736905637
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 157.62500789913378
# Maximum angle between upper arm and forearm: 169.67361121469403
# Minimum angle between upper arm and trunk: 20.09187507458622
# Maximum angle between upper arm and trunk: 116.9396862983184
# Minimum angle between trunk and knee: 132.27669082855695
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 155.5538477378339
# Maximum angle between upper arm and forearm: 166.4750650910012
# Minimum angle between upper arm and trunk: 20.368230345382592
# Maximum angle between upper arm and trunk: 119.40234891979772
# Minimum angle between trunk and knee: 129.17507098514665
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 155.06065636194162
# Maximum angle between upper arm and forearm: 170.62803030506248
# Minimum angle between upper arm and trunk: 20.360563580849696
# Maximum angle between upper arm and trunk: 122.64265580094713
# Minimum angle between trunk and knee: 131.30962133344326
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 159.4257014113057
# Maximum angle between upper arm and forearm: 173.94034535127017
# Minimum angle between upper arm and trunk: 16.29039728461151
# Maximum angle between upper arm and trunk: 126.3207864827845
# Minimum angle between trunk and knee: 130.9765769537804
#
# Repetition: 7
#
# Minimum angle between upper arm and forearm: 158.9653486550334
# Maximum angle between upper arm and forearm: 169.94870755215715
# Minimum angle between upper arm and trunk: 16.29039728461151
# Maximum angle between upper arm and trunk: 122.5253930850441
# Minimum angle between trunk and knee: 131.55856368516112
# Starting...
# Keypoints from folder: front_raise_incorrect_7
# Detected arm: left
#
#
# extremas: [165.12113455 176.11478234 167.00304678 167.23670624 154.32579957
#  167.11534294 158.19350646 155.00753193  15.37598697]
# angle change threshold: 44.722356102761665
#
#
# Testing to filter by average angle change....
# Testing Finished
# Filtering by average angle change...
# extrema array size: 9
# angles removed: [15.375986965020099]
#
# New extrema array: [165.12113455 176.11478234 167.00304678 167.23670624 154.32579957
#  167.11534294 158.19350646 155.00753193]
# new size: 8
#
# Testing to filter by number of angles inbetween....
# count list: [78, 74, 74, 73, 69, 67, 66]
# threshold: 42
# average count: 71
# []
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
#
#
# extremas: [ 6.98494667  1.05703265  1.28460754  1.64352117  1.30122342  0.19754673
#   0.16253771 15.37596277]
# angle change threshold: 23.31554443534866
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [76, 74, 75, 68, 69, 71, 53]
# threshold: 41
# average count: 69
# []
# Array filtering: Done
#
#
# extremas: [156.03535689 141.81268363 141.45500286 138.11012176 139.88543985
#  142.04397638 160.23604941 159.40831135 171.17622565 163.88704263
#  163.82515757 164.86887434 163.74064387 160.5726612  162.2757454
#  164.83723265 161.24562362 161.59943963 166.09117148 156.61186962
#  158.96883553 164.64174009 164.32944928 156.69247016 167.79717826
#  153.20343303 155.42604824]
# angle change threshold: 25.054578933178885
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [15, 9, 19, 14, 19, 23, 12, 23, 33, 16, 21, 7, 24, 18, 29, 22, 22, 17, 25, 21, 19, 11, 17, 35, 30, 19]
# threshold: 36
# average count: 20
# [15, 9, 19, 14, 19, 23, 12, 23, 33, 16, 21, 7, 24, 18, 29, 22, 22, 17, 25, 21, 19, 11, 17, 35, 30, 19]
# Array filtering: Done
#
#
# extremas: [177.33548106 175.84410546 175.33325645 174.14927739 159.054529
#  159.65793117 173.79060601 174.80669977 159.28774539 175.64451108
#  172.30206115 155.65413934 158.25840811 173.81997517 168.44219277
#  169.33610702 157.58375487 158.46346304 177.14094868 178.81392621
#  174.54403298 173.49326098 177.90565414 177.38938616 172.10761886]
# angle change threshold: 26.618765178010555
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [24, 51, 25, 16, 11, 23, 20, 15, 36, 22, 23, 8, 22, 10, 7, 18, 7, 21, 18, 46, 19, 51, 13, 10]
# threshold: 34
# average count: 21
# [24, 25, 16, 11, 23, 20, 15, 22, 23, 8, 22, 10, 7, 18, 7, 21, 18, 19, 13, 10]
# Array filtering: Done
#
#
# extremas: [167.60484431 155.23716224 163.71153272 158.1913673  157.99255956
#  156.45353099 163.98412524 158.80289055 156.3604923  162.04245902
#  153.59304155 154.82214848 153.81969743 165.99168466 164.80186433
#  157.57497564 157.06316441 154.4113     153.67664886 155.10566009
#  164.01180015 149.29789321 167.95635317 171.03380628 158.51345226]
# angle change threshold: 25.975398831391672
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [44, 36, 29, 2, 15, 25, 25, 7, 39, 31, 5, 12, 22, 6, 18, 8, 7, 28, 32, 35, 36, 28, 10, 12]
# threshold: 34
# average count: 21
# [29, 2, 15, 25, 25, 7, 31, 5, 12, 22, 6, 18, 8, 7, 28, 32, 28, 10, 12]
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [44, 36, 29, 2, 15, 25, 25, 7, 39, 31, 5, 12, 22, 6, 18, 8, 7, 28, 32, 35, 36, 28, 10, 12]
# threshold: 34
#
# Starting another stage of filtering...
#
#
# Testing to filter by number of angles inbetween....
# count list: [44, 85, 59, 71, 18, 94, 68, 36, 52]
# threshold: 38
# average count: 58
# [18, 36]
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [44, 85, 59, 71, 18, 94, 68, 36, 52]
# threshold: 38
# Array filtering: Done
#
# Size of minima array: 8
# ------------------------------------------------------------------------------------------
# Number of reps performed: 8
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 155.23716224497713
# Maximum angle between upper arm and forearm: 177.33548106354147
# Minimum angle between upper arm and trunk: 6.984946670848609
# Maximum angle between upper arm and trunk: 165.12113454883527
# Minimum angle between trunk and knee: 133.53076719714585
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 156.53855293647734
# Maximum angle between upper arm and forearm: 175.3332564492654
# Minimum angle between upper arm and trunk: 1.0570326520216216
# Maximum angle between upper arm and trunk: 176.1147823417142
# Minimum angle between trunk and knee: 134.80590394918607
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 156.36049230087423
# Maximum angle between upper arm and forearm: 174.8066997723935
# Minimum angle between upper arm and trunk: 1.0570326520216216
# Maximum angle between upper arm and trunk: 167.00304678409162
# Minimum angle between trunk and knee: 156.69122561284516
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 153.59304155195625
# Maximum angle between upper arm and forearm: 175.64451107558418
# Minimum angle between upper arm and trunk: 1.2846075413055824
# Maximum angle between upper arm and trunk: 167.23670623765332
# Minimum angle between trunk and knee: 156.15585116877094
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 153.81969743263997
# Maximum angle between upper arm and forearm: 173.81997516651563
# Minimum angle between upper arm and trunk: 1.301223418224288
# Maximum angle between upper arm and trunk: 154.3257995651286
# Minimum angle between trunk and knee: 156.42393088750802
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 153.67664885907115
# Maximum angle between upper arm and forearm: 178.81392620745132
# Minimum angle between upper arm and trunk: 0.19754672830306869
# Maximum angle between upper arm and trunk: 167.11534293782702
# Minimum angle between trunk and knee: 154.46777439470523
#
# Repetition: 7
#
# Minimum angle between upper arm and forearm: 149.29789320814336
# Maximum angle between upper arm and forearm: 174.54403298173762
# Minimum angle between upper arm and trunk: 0.16253770866163458
# Maximum angle between upper arm and trunk: 158.19350645509058
# Minimum angle between trunk and knee: 154.2347555379313
#
# Repetition: 8
#
# Minimum angle between upper arm and forearm: 149.29789320814336
# Maximum angle between upper arm and forearm: 177.90565414277518
# Minimum angle between upper arm and trunk: 0.16253770866163458
# Maximum angle between upper arm and trunk: 155.00753193336777
# Minimum angle between trunk and knee: 151.65382971015507
# Starting...
# Keypoints from folder: front_raise_incorrect_8
# Detected arm: left
#
#
# extremas: [154.13011412 154.8836588  152.12016812 167.3592671  160.70748907
#  159.49448506 156.226807   156.36481078]
# angle change threshold: 24.289514032056097
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [52, 53, 50, 50, 52, 50, 49]
# threshold: 32
# average count: 50
# []
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
#
#
# extremas: [21.47906877 26.78082516 44.57802585 39.30773067 33.81794733 35.58662888
#  39.10074212]
# angle change threshold: 26.523638400488647
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [56, 50, 50, 52, 50, 49]
# threshold: 31
# average count: 51
# []
# Array filtering: Done
#
#
# extremas: [155.24205664 155.8579803  162.4085997  158.72313074 159.33411187
#  158.59454049 160.25238754 159.47711177 159.61171752 158.20845611
#  160.80284388 160.79910715 160.75283978 159.12942287 157.64109442
#  156.58010181 158.96302192 155.86579834 158.75505302 158.68073031
#  158.52491018 158.61917599 158.02681325 156.91926488]
# angle change threshold: 21.451495759329276
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [17, 17, 19, 23, 12, 15, 18, 6, 26, 23, 20, 30, 25, 17, 15, 14, 9, 9, 5, 10, 11, 22, 14]
# threshold: 31
# average count: 16
# [17, 17, 19, 23, 12, 15, 18, 6, 26, 23, 20, 30, 25, 17, 15, 14, 9, 9, 5, 10, 11, 22, 14]
# Array filtering: Done
#
#
# extremas: [173.49569229 175.7290933  172.15843534 175.29911477 170.56361491
#  174.93185946 173.45482064 171.16570356 172.51084156 173.450554
#  172.14394418 174.01285383 167.44643804 171.40669943 171.46489588
#  174.90827529 174.25451424 172.94499675 174.02509228 170.3482091
#  171.20535027 176.02386806 174.88437515 171.46246007]
# angle change threshold: 22.53306894975318
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [21, 6, 33, 12, 38, 16, 5, 17, 8, 18, 32, 10, 7, 5, 27, 16, 32, 16, 6, 12, 12, 14, 6]
# threshold: 31
# average count: 16
# [21, 6, 12, 16, 5, 17, 8, 18, 10, 7, 5, 27, 16, 16, 6, 12, 12, 14, 6]
# Array filtering: Done
#
#
# extremas: [167.00424932 172.15253306 157.82341511 168.15014817 161.36303387
#  169.55279256 171.16007775 166.99392947 172.19587932 154.86285516
#  163.56806673 166.68508292 162.54645932 170.54159993 160.51631038
#  165.93723935 162.13653404 167.29656556 169.46523228 166.95734057
#  170.43175204 166.42973823 171.25101211 164.88571752]
# angle change threshold: 26.29530063943649
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [14, 14, 31, 24, 21, 15, 8, 13, 13, 27, 22, 6, 7, 12, 23, 27, 19, 15, 11, 7, 15, 12, 11]
# threshold: 30
# average count: 15
# [14, 14, 24, 21, 15, 8, 13, 13, 27, 22, 6, 7, 12, 23, 27, 19, 15, 11, 7, 15, 12, 11]
# Array filtering: Done
#
# Size of minima array: 24
# ------------------------------------------------------------------------------------------
# Number of reps performed: 8
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 151.47656648743285
# Maximum angle between upper arm and forearm: 175.7290933028107
# Minimum angle between upper arm and trunk: 2.930780836135733
# Maximum angle between upper arm and trunk: 154.13011411795125
# Minimum angle between trunk and knee: 152.7050655757728
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 160.9132914270953
# Maximum angle between upper arm and forearm: 175.29911477097878
# Minimum angle between upper arm and trunk: 21.47906876529397
# Maximum angle between upper arm and trunk: 154.8836588034048
# Minimum angle between trunk and knee: 154.9800925870732
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 161.3630338722289
# Maximum angle between upper arm and forearm: 174.93185945723772
# Minimum angle between upper arm and trunk: 26.78082516241152
# Maximum angle between upper arm and trunk: 152.12016812336591
# Minimum angle between trunk and knee: 155.8368897020328
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 154.86285515538475
# Maximum angle between upper arm and forearm: 173.4505539992718
# Minimum angle between upper arm and trunk: 39.307730673451495
# Maximum angle between upper arm and trunk: 167.3592671032687
# Minimum angle between trunk and knee: 156.05525470749916
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 160.51631038358082
# Maximum angle between upper arm and forearm: 174.01285382811287
# Minimum angle between upper arm and trunk: 33.817947327260114
# Maximum angle between upper arm and trunk: 160.70748906992497
# Minimum angle between trunk and knee: 156.43447882275157
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 161.69171582416257
# Maximum angle between upper arm and forearm: 174.90827528720104
# Minimum angle between upper arm and trunk: 33.817947327260114
# Maximum angle between upper arm and trunk: 159.49448506167664
# Minimum angle between trunk and knee: 154.14978182753808
#
# Repetition: 7
#
# Minimum angle between upper arm and forearm: 162.13653404456846
# Maximum angle between upper arm and forearm: 174.02509228301594
# Minimum angle between upper arm and trunk: 35.586628882175305
# Maximum angle between upper arm and trunk: 156.2268069996524
# Minimum angle between trunk and knee: 154.81502829794226
#
# Repetition: 8
#
# Minimum angle between upper arm and forearm: 164.88571752020263
# Maximum angle between upper arm and forearm: 176.02386806125597
# Minimum angle between upper arm and trunk: 36.63032825463133
# Maximum angle between upper arm and trunk: 156.36481077503353
# Minimum angle between trunk and knee: 153.78456715440436
# Starting...
# Keypoints from folder: front_raise_incorrect_9
# Detected arm: left
#
#
# extremas: [155.03154161 155.30345795 153.02059748 151.83914557 154.66128917
#  124.89764829 141.82347929 146.04270261]
# angle change threshold: 28.20958107336108
#
#
# Testing to filter by average angle change....
# Testing Finished
# Filtering by average angle change...
# extrema array size: 8
# angles removed: [124.89764829086597]
#
# New extrema array: [155.03154161 155.30345795 153.02059748 151.83914557 154.66128917
#  141.82347929 146.04270261]
# new size: 7
#
# Testing to filter by number of angles inbetween....
# count list: [48, 49, 47, 51, 96, 47]
# threshold: 34
# average count: 56
# []
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
#
#
# extremas: [48.47317195 34.53951285 36.53497977 34.33823814 28.4138392  29.94885356
#  31.55243956]
# angle change threshold: 24.531477821897727
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [49, 48, 50, 50, 48, 45]
# threshold: 30
# average count: 48
# []
# Array filtering: Done
#
#
# extremas: [158.71655001 159.19714255 156.79253688 159.88655535 156.17566227
#  156.30031437 159.55375421 156.6335687  155.28716863 158.67838274
#  156.03331716 155.79558137 160.44233751 155.13602069 154.65605847
#  154.07034808 150.05002777 150.95083111 152.01077895 150.93188729
#  153.60054201 150.33155634 151.26080172 152.41329111 151.71044188
#  150.85901866]
# angle change threshold: 22.050446362010824
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [23, 25, 19, 9, 9, 8, 18, 10, 15, 20, 17, 14, 7, 12, 15, 17, 9, 9, 7, 16, 15, 17, 12, 18, 11]
# threshold: 32
# average count: 14
# [23, 25, 19, 9, 9, 8, 18, 10, 15, 20, 17, 14, 7, 12, 15, 17, 9, 9, 7, 16, 15, 17, 12, 18, 11]
# Array filtering: Done
#
#
# extremas: [174.01419249 173.50700151 171.21088961 172.84213486 173.37131494
#  174.77695411 171.14636627 171.8408642  172.88758241 172.8565361
#  170.98703649 178.93762086 175.09569869 175.15535401 175.72849891
#  172.38580043 178.17203368 164.81620263 176.93242228 177.42516574
#  173.96647068 174.97395792]
# angle change threshold: 23.12509201017153
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [17, 10, 8, 7, 5, 9, 7, 28, 12, 13, 19, 18, 33, 15, 6, 35, 27, 13, 9, 36, 12]
# threshold: 29
# average count: 16
# [17, 10, 8, 7, 5, 9, 7, 28, 12, 13, 19, 18, 15, 6, 27, 13, 9, 12]
# Array filtering: Done
#
#
# extremas: [164.46951669 169.55751379 169.872976   169.28075289 172.11287733
#  169.10884341 170.03248881 163.30438573 167.63116965 170.13631703
#  164.73668052 167.67081727 165.06914454 169.30054262 170.54802391
#  162.84475153 163.11782131 164.27853545 174.16336371 164.12669318
#  170.14462728]
# angle change threshold: 23.890316754814457
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# count list: [11, 8, 10, 7, 7, 10, 17, 18, 17, 10, 20, 28, 23, 10, 16, 45, 6, 15, 26, 18]
# threshold: 28
# average count: 16
# [11, 8, 10, 7, 7, 10, 17, 18, 17, 10, 20, 23, 10, 16, 6, 15, 26, 18]
# Array filtering: Done
#
# Size of minima array: 21
# ------------------------------------------------------------------------------------------
# Number of reps performed: 8
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 164.46951669447017
# Maximum angle between upper arm and forearm: 174.01419249441176
# Minimum angle between upper arm and trunk: 38.31507239307319
# Maximum angle between upper arm and trunk: 155.03154160959997
# Minimum angle between trunk and knee: 155.33298671663093
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 165.51521416527004
# Maximum angle between upper arm and forearm: 174.7769541060204
# Minimum angle between upper arm and trunk: 34.53951285187133
# Maximum angle between upper arm and trunk: 155.3034579540549
# Minimum angle between trunk and knee: 154.80976596907757
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 163.30438572996337
# Maximum angle between upper arm and forearm: 172.88758240603306
# Minimum angle between upper arm and trunk: 34.53951285187133
# Maximum angle between upper arm and trunk: 153.02059747755942
# Minimum angle between trunk and knee: 154.33385857003952
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 164.7366805180722
# Maximum angle between upper arm and forearm: 178.93762086456897
# Minimum angle between upper arm and trunk: 34.33823813559408
# Maximum angle between upper arm and trunk: 151.8391455709375
# Minimum angle between trunk and knee: 151.76979647346317
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 162.8447515295828
# Maximum angle between upper arm and forearm: 175.72849890657767
# Minimum angle between upper arm and trunk: 28.413839204963207
# Maximum angle between upper arm and trunk: 154.66128916634565
# Minimum angle between trunk and knee: 150.17432435082515
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 162.8447515295828
# Maximum angle between upper arm and forearm: 178.17203368185992
# Minimum angle between upper arm and trunk: 28.413839204963207
# Maximum angle between upper arm and trunk: 124.89764829086597
# Minimum angle between trunk and knee: 149.14766998797717
#
# Repetition: 7
#
# Minimum angle between upper arm and forearm: 164.27853545222897
# Maximum angle between upper arm and forearm: 177.42516574194966
# Minimum angle between upper arm and trunk: 29.94885355783119
# Maximum angle between upper arm and trunk: 141.82347929329455
# Minimum angle between trunk and knee: 148.50837669745275
#
# Repetition: 8
#
# Minimum angle between upper arm and forearm: 157.0964411689257
# Maximum angle between upper arm and forearm: 174.97395792200444
# Minimum angle between upper arm and trunk: 26.951053269256978
# Maximum angle between upper arm and trunk: 146.04270260593336
# Minimum angle between trunk and knee: 148.29000638655197

# %%
import os
import sys

#import heuristic model files

hm_files_path = os.path.join(os.path.dirname(os.getcwd()), 'Heuristic_model')
print(hm_files_path)

if hm_files_path in sys.path:
    pass
else:
    sys.path.append(hm_files_path)

# %%
from Parser import parse_frames
from scipy.signal import medfilt
from Functions import find_extremas, filter_extremas, detect_side, analyse_each_rep
from JointAngles import JointAngles
import numpy as np
import math
import glob
import itertools
import pickle
import matplotlib.pyplot as plt

# %%
# modify this path for other videos 
# input_folder = "/home/aleko/Documents/Projects/IndividualProject/bicepvid"
#input_folder = "C:\\Users\\kvash\\Documents\\GitHub\\IndividualProject\\keypoints_for_all\\triceps_pushdown"
input_folder = "C:\\Users\\kvash\\Documents\\GitHub\\IndividualProject\\keypoints_for_all\\triceps_pushdown"

#input_folder = 'C:\\Users\\ak5u16\\Desktop\\IndividualProject\\keypoints_for_all\\triceps pushdown'
folder_paths = glob.glob(os.path.join(input_folder, 'triceps_pushdown_incorrect_58*'))     
min_upper_arm_forearm = [] 
max_upper_arm_forearm = []
min_upper_arm_trunk = []
max_upper_arm_trunk = []
min_trunk_knee = []
max_trunk_knee = []


for folder in folder_paths:
    print("Starting..." + "\nKeypoints from folder: " + os.path.basename(folder))
    video_name = os.path.basename(folder)
    frame_poses = parse_frames(folder)
    
    joint_angles = JointAngles('triceps_pushdown', frame_poses)
    print('Detected arm: ' + joint_angles.side)

    upArm_trunk_angles = np.array(joint_angles.upArm_trunk_angles)
    upArm_trunk_angles_filtered = medfilt(medfilt(upArm_trunk_angles, 5), 5)
    
   
    upArm_forearm_angles = np.array(joint_angles.upArm_forearm_angles)
    upArm_forearm_angles_filtered = medfilt(medfilt(upArm_forearm_angles, 5), 5)
    
    trunk_knee_angles = np.array(joint_angles.trunk_knee_angles)
    trunk_knee_angles_filtered = medfilt(medfilt(trunk_knee_angles, 5), 5)
    
    # Find upper arm and trunk maximum angles to detect wrong form 
    upArm_trunk_maximas = find_extremas(upArm_trunk_angles_filtered)
    upArm_trunk_maximas = filter_extremas(upArm_trunk_angles_filtered, upArm_trunk_maximas)
    indexesmax1 = np.array([np.argwhere(upArm_trunk_angles_filtered == maxima)[0][0] for maxima in upArm_trunk_maximas])
    # print("Largest angles between upper arm and trunk: " + str(upArm_trunk_maximas))

    # Find trunk and knee maximum angles to detect wrong form 
    trunk_knee_maximas = find_extremas(trunk_knee_angles_filtered)
    trunk_knee_maximas = filter_extremas(trunk_knee_angles_filtered, trunk_knee_maximas)
    indexesmax2 = np.array([np.argwhere(trunk_knee_angles_filtered == maxima)[0][0] for maxima in trunk_knee_maximas])
   
    # print("Largest angles between trunk and knee: " + str(trunk_knee_maximas))

    # Count repetitions
    upArm_forearm_maximas = find_extremas(upArm_forearm_angles_filtered)  
    upArm_forearm_maximas = filter_extremas(upArm_forearm_angles_filtered, upArm_forearm_maximas)
    indexesmax3 = np.array([np.argwhere(upArm_forearm_angles_filtered == maxima)[0][0] for maxima in upArm_forearm_maximas])
   
    # print("Number of maxima points between Upper Arm and Forearm: " + str(upArm_forearm_maximas.size))
    # print(upArm_forearm_maximas)
    
    # Find upper arm and forearm minimum points to count reps 
    upArm_forearm_minimas = find_extremas(upArm_forearm_angles_filtered, maxima=False)
    print('\n----------------------------Filtering minimas-------------------------------------')
    upArm_forearm_minimas = filter_extremas(upArm_forearm_angles_filtered, upArm_forearm_minimas, maxima=False)
    indexesmin = np.array([np.argwhere(upArm_forearm_angles_filtered == minima)[0][0] for minima in upArm_forearm_minimas])
    print("\nSize of minima array: " + str(upArm_forearm_minimas.size))
    print('-'*90)
    
    # Plot 1
    plt.figure(figsize=(10,4))
    #plt.scatter(np.arange(upArm_forearm_angles.shape[0]), upArm_forearm_angles, alpha=0.5)
    plt.plot(np.arange(upArm_forearm_angles_filtered.shape[0]), upArm_forearm_angles_filtered, c='r', alpha=1)
    #plt.title(video_name)
    plt.xlabel('Frames')
    plt.ylabel('Angle between Upper Arm and Forearm')
    # Set range on y-axis so the plots are consistent
    plt.ylim(0,220) 
    
    # Annotate minima apoints on the graph   
    #max_points = upArm_forearm_angles_filtered[indexesmax3]
    #min_points = upArm_forearm_angles_filtered[indexesmin]
    #plt.plot(indexesmin, min_points, 'bo')
    #plt.plot(indexesmax3, max_points, 'ks')

    """
        # Annotate local maximas
        for maxp, indx in zip(max_points, indexesmax3):
            plt.annotate('local max', xy=(indx, maxp), xytext=(indx, maxp+25),
                    arrowprops=dict(facecolor='black', shrink=0.05))

        # Annotate local minimas
        for minp, indx in zip(min_points, indexesmin):
            plt.annotate('local min', xy=(indx, minp), xytext=(indx, minp-35),
                    arrowprops=dict(facecolor='black', shrink=0.05))     
    """
    plt.show()
    
    # Plot 2
    plt.figure(figsize=(10,4))
    #plt.scatter(np.arange(upArm_trunk_angles.shape[0]), upArm_trunk_angles, alpha=0.5)
    plt.plot(np.arange(upArm_trunk_angles_filtered.shape[0]), upArm_trunk_angles_filtered, c='r', alpha=1)
    #plt.title(video_name)
    plt.xlabel('Frames')
    plt.ylabel('Angle between Upper Arm and Trunk')
    # Set range on y-axis so the plots are consistent
    plt.ylim(0,90)
    
    # Annontate maxima points
    #plt.plot(indexesmax1, upArm_trunk_angles_filtered[indexesmax1], 'ks')
    plt.show()
  
    # Plot 3
    plt.figure(figsize=(10,4))
    #plt.scatter(np.arange(trunk_knee_angles.shape[0]), trunk_knee_angles, alpha=0.5)
    plt.plot(np.arange(trunk_knee_angles_filtered.shape[0]), trunk_knee_angles_filtered, c='r', alpha=1)
    #plt.title(video_name)
    plt.xlabel('Frames')
    plt.ylabel('Angle between Trunk and Knee')
    # Set range on y-axis so the plots are consistent
    plt.ylim(0,200)
    
    # Annontate maxima points
    #plt.plot(indexesmax2, trunk_knee_angles_filtered[indexesmax2], 'ks')
    plt.show()

   
 
  

    # Plot 4
    plt.figure(figsize=(10,4))
    plt.plot(np.arange(upArm_forearm_angles_filtered.shape[0]), upArm_forearm_angles_filtered, c='r', alpha=1)
    plt.plot(np.arange(upArm_trunk_angles_filtered.shape[0]), upArm_trunk_angles_filtered, c='r', alpha=1)
    plt.plot(np.arange(trunk_knee_angles_filtered.shape[0]), trunk_knee_angles_filtered, c='r', alpha=1)
    plt.title("triceps_pushdown_correct_4__6")
    plt.xlabel('Frames')
    plt.ylabel('Whole body movement')
    # Set range on y-axis so the plots are consistent
    plt.ylim(0,250) 
    
    # Annotate minima apoints      
    #plt.plot(indexesmin, upArm_forearm_angles_filtered[indexesmin], 'ko')
    #plt.plot(indexesmax1, upArm_trunk_angles_filtered[indexesmax1], 'ks')
    #plt.plot(indexesmax2, trunk_knee_angles_filtered[indexesmax2], 'ks')
    plt.plot(indexesmax3, upArm_forearm_angles_filtered[indexesmax3], 'ro')
    
    plt.show()
   
    
    # Each rep analysis
    # local minimums for upper arm and forearm are min angles in each rep
    """
    min_upper_arm_forearm1, max_upper_arm_forearm1, min_upper_arm_trunk1, max_upper_arm_trunk1, min_trunk_knee1, max_trunk_knee1 = analyse_each_rep(exercise='triceps_pushdown', mode='thresholds', 
                                                                                                                                         extremas1=upArm_forearm_minimas, 
                                                                                                                                         uf_angles1=upArm_forearm_angles_filtered, 
                                                                                                                                         ut_angles1=upArm_trunk_angles_filtered, 
                                                                                                                                tk_angles1=trunk_knee_angles_filtered)
    """
    
    analyse_each_rep(exercise='triceps_pushdown', mode='analysis', extremas1=upArm_forearm_minimas, 
                     uf_angles1=upArm_forearm_angles_filtered, ut_angles1=upArm_trunk_angles_filtered, 
                     tk_angles1=trunk_knee_angles_filtered)
    """
    min_upper_arm_forearm = min_upper_arm_forearm + min_upper_arm_forearm1
    max_upper_arm_forearm = max_upper_arm_forearm + max_upper_arm_forearm1
    min_upper_arm_trunk = min_upper_arm_trunk + min_upper_arm_trunk1
    max_upper_arm_trunk = max_upper_arm_trunk + max_upper_arm_trunk1
    min_trunk_knee = min_trunk_knee + min_trunk_knee1
    max_trunk_knee = max_trunk_knee + max_trunk_knee1
    
    print('\n' + '='*120 + '\n')


#print('Minimum Upper Arm Forearm threshold: ' + str(min(min_upper_arm_forearm)))
#print('Maximum Upper Arm Forearm threshold: ' + str(min(max_upper_arm_forearm)))
#print('Maximum value in minimum Upper Arm Trunk angles: ' + str(max(min_upper_arm_trunk)))
#print('Maximum value in maximum Upper Arm Trunk angles: ' + str(max(max_upper_arm_trunk)))
#print('Minimum Trunk Knee threshold: ' + str(min(min_trunk_knee)))
#print('Maximum Trunk Knee threshold: ' + str(max(max_trunk_knee)))
print('Minimum in minimum trunk Knee threshold: ' + str(min(min_trunk_knee)))
print('Maximum in maximum Trunk Knee threshold: ' + str(max(max_trunk_knee)))
print('Maximum in minimum Trunk Knee threshold: ' + str(max(min_trunk_knee)))
print('Minimum in maximum Trunk Knee threshold: ' + str(min(max_trunk_knee)))
"""
# Out:
# Starting...
# Keypoints from folder: triceps_pushdown_incorrect_58__12
# Detected arm: left
#
# ----------------------------Filtering minimas-------------------------------------
#
# Size of minima array: 11
# ------------------------------------------------------------------------------------------
# Number of reps performed: 12
#
# Repetition: 1
#
# Starting position upper arm forearm angle: 76.90750049174797
# Starting position upper arm trunk angle: 7.128643403197636
# Starting position trunk knee angle: 174.44346629836008
#
# Maximum angle between upper arm and forearm: 160.56081507773322
# Maximum angle between upper arm and trunk: 14.211342598546576
# Maximum angle between trunk and knee: 174.44346629836008
# Minimum angle between trunk and knee: 166.06558996239383
# Minimum angle between upper arm and trunk: 1.0155865371041857
# Minimum angle between upper arm and forearm: 76.90750049174797
#
# Finishing position upper arm forearm angle: 84.82128903856525
# Finishing  position upper arm trunk angle: 14.211342598546576
# Finishing  position trunk knee angle: 169.32823468146762
#
# Repetition: 2
#
# Starting position upper arm forearm angle: 84.82128903856525
# Starting position upper arm trunk angle: 14.505523823355787
# Starting position trunk knee angle: 169.3142774602918
#
# Maximum angle between upper arm and forearm: 161.02061261609452
# Maximum angle between upper arm and trunk: 15.775248180933765
# Maximum angle between trunk and knee: 171.69423516153773
# Minimum angle between trunk and knee: 168.87004650664196
# Minimum angle between upper arm and trunk: 0.5960113954533105
# Minimum angle between upper arm and forearm: 84.82128903856525
#
# Finishing position upper arm forearm angle: 87.2073493057251
# Finishing  position upper arm trunk angle: 15.775248180933765
# Finishing  position trunk knee angle: 169.8241560341777
#
# Repetition: 3
#
# Starting position upper arm forearm angle: 87.2073493057251
# Starting position upper arm trunk angle: 15.775248180933765
# Starting position trunk knee angle: 169.7661784622347
#
# Maximum angle between upper arm and forearm: 160.61277512277667
# Maximum angle between upper arm and trunk: 15.775248180933765
# Maximum angle between trunk and knee: 173.14072413433271
# Minimum angle between trunk and knee: 168.49190628124163
# Minimum angle between upper arm and trunk: 1.672381999442821
# Minimum angle between upper arm and forearm: 87.2073493057251
#
# Finishing position upper arm forearm angle: 96.21147010316233
# Finishing  position upper arm trunk angle: 13.468510870261618
# Finishing  position trunk knee angle: 172.13361600488648
#
# Repetition: 4
#
# Starting position upper arm forearm angle: 96.21147010316233
# Starting position upper arm trunk angle: 13.468510870261618
# Starting position trunk knee angle: 168.9820218798572
#
# Maximum angle between upper arm and forearm: 166.55162939108973
# Maximum angle between upper arm and trunk: 13.468510870261618
# Maximum angle between trunk and knee: 174.2543152922395
# Minimum angle between trunk and knee: 168.9820218798572
# Minimum angle between upper arm and trunk: 1.798065206714995
# Minimum angle between upper arm and forearm: 95.2234275868066
#
# Finishing position upper arm forearm angle: 95.2234275868066
# Finishing  position upper arm trunk angle: 8.87006173802026
# Finishing  position trunk knee angle: 170.95053994822138
#
# Repetition: 5
#
# Starting position upper arm forearm angle: 95.2234275868066
# Starting position upper arm trunk angle: 8.87006173802026
# Starting position trunk knee angle: 169.89849387024256
#
# Maximum angle between upper arm and forearm: 160.18818034096006
# Maximum angle between upper arm and trunk: 12.116374912513372
# Maximum angle between trunk and knee: 174.32472039015965
# Minimum angle between trunk and knee: 169.80216498014124
# Minimum angle between upper arm and trunk: 1.795034227631801
# Minimum angle between upper arm and forearm: 92.52441560985869
#
# Finishing position upper arm forearm angle: 92.52441560985869
# Finishing  position upper arm trunk angle: 12.116374912513372
# Finishing  position trunk knee angle: 172.6693098816098
#
# Repetition: 6
#
# Starting position upper arm forearm angle: 92.52441560985869
# Starting position upper arm trunk angle: 13.478006567844208
# Starting position trunk knee angle: 171.46858906799628
#
# Maximum angle between upper arm and forearm: 161.69934793147
# Maximum angle between upper arm and trunk: 14.350172210793167
# Maximum angle between trunk and knee: 174.559503314463
# Minimum angle between trunk and knee: 171.46858906799628
# Minimum angle between upper arm and trunk: 1.1486513354917256
# Minimum angle between upper arm and forearm: 92.52441560985869
#
# Finishing position upper arm forearm angle: 92.52506913574214
# Finishing  position upper arm trunk angle: 14.350172210793167
# Finishing  position trunk knee angle: 173.2294401568752
#
# Repetition: 7
#
# Starting position upper arm forearm angle: 92.52506913574214
# Starting position upper arm trunk angle: 14.350172210793167
# Starting position trunk knee angle: 170.62559012512773
#
# Maximum angle between upper arm and forearm: 158.79155279203752
# Maximum angle between upper arm and trunk: 14.350172210793167
# Maximum angle between trunk and knee: 176.07646814180592
# Minimum angle between trunk and knee: 170.62559012512773
# Minimum angle between upper arm and trunk: 0.7684535663759428
# Minimum angle between upper arm and forearm: 92.52506913574214
#
# Finishing position upper arm forearm angle: 94.99142671808566
# Finishing  position upper arm trunk angle: 13.471272452516782
# Finishing  position trunk knee angle: 174.74682388626508
#
# Repetition: 8
#
# Starting position upper arm forearm angle: 94.99142671808566
# Starting position upper arm trunk angle: 13.471272452516782
# Starting position trunk knee angle: 174.74407585459943
#
# Maximum angle between upper arm and forearm: 157.74890894470607
# Maximum angle between upper arm and trunk: 13.471272452516782
# Maximum angle between trunk and knee: 175.76697128870597
# Minimum angle between trunk and knee: 173.64221401017588
# Minimum angle between upper arm and trunk: 3.440609448681823
# Minimum angle between upper arm and forearm: 92.76786784071307
#
# Finishing position upper arm forearm angle: 92.76786784071307
# Finishing  position upper arm trunk angle: 11.783201040436348
# Finishing  position trunk knee angle: 173.64221401017588
#
# Repetition: 9
#
# Starting position upper arm forearm angle: 92.76786784071307
# Starting position upper arm trunk angle: 11.783201040436348
# Starting position trunk knee angle: 173.64221401017588
#
# Maximum angle between upper arm and forearm: 158.57377515300757
# Maximum angle between upper arm and trunk: 11.783201040436348
# Maximum angle between trunk and knee: 176.87531991936245
# Minimum angle between trunk and knee: 173.64221401017588
# Minimum angle between upper arm and trunk: 2.0174059031355993
# Minimum angle between upper arm and forearm: 92.76786784071307
#
# Finishing position upper arm forearm angle: 96.5940767808195
# Finishing  position upper arm trunk angle: 10.638149724355436
# Finishing  position trunk knee angle: 176.87531991936245
#
# Repetition: 10
#
# Starting position upper arm forearm angle: 96.5940767808195
# Starting position upper arm trunk angle: 10.463129988218546
# Starting position trunk knee angle: 174.86466890214933
#
# Maximum angle between upper arm and forearm: 158.45465763966405
# Maximum angle between upper arm and trunk: 13.915188747800629
# Maximum angle between trunk and knee: 177.45826935242695
# Minimum angle between trunk and knee: 174.86466890214933
# Minimum angle between upper arm and trunk: 1.4474225879917026
# Minimum angle between upper arm and forearm: 87.32283384189475
#
# Finishing position upper arm forearm angle: 87.32283384189475
# Finishing  position upper arm trunk angle: 13.915188747800629
# Finishing  position trunk knee angle: 175.03860569884276
#
# Repetition: 11
#
# Starting position upper arm forearm angle: 87.32283384189475
# Starting position upper arm trunk angle: 15.448724655601724
# Starting position trunk knee angle: 173.7280192194315
#
# Maximum angle between upper arm and forearm: 161.82158652077564
# Maximum angle between upper arm and trunk: 16.27756625307677
# Maximum angle between trunk and knee: 177.53152490365875
# Minimum angle between trunk and knee: 173.7280192194315
# Minimum angle between upper arm and trunk: 1.101713652178503
# Minimum angle between upper arm and forearm: 87.32283384189475
#
# Finishing position upper arm forearm angle: 90.81262214304219
# Finishing  position upper arm trunk angle: 16.27756625307677
# Finishing  position trunk knee angle: 175.7734252376108
#
# Repetition: 12
#
# Starting position upper arm forearm angle: 90.81262214304219
# Starting position upper arm trunk angle: 16.27756625307677
# Starting position trunk knee angle: 175.4567440819476
#
# Maximum angle between upper arm and forearm: 160.09207914287975
# Maximum angle between upper arm and trunk: 16.27756625307677
# Maximum angle between trunk and knee: 176.73800538492182
# Minimum angle between upper arm trunk: 2.514162313158208
# Minimum angle between trunk and knee: 173.8666842280986
# Minimum angle between upper arm and forearm: 90.81262214304219
#
# Finishing position upper arm forearm angle: 93.49533807273605
# Finishing  position upper arm trunk angle: 14.020303663545716
# Finishing  position trunk knee angle: 173.8666842280986

# %%
max_trunk_knee
# Out:
# [165.8395625908034,
#  164.74386542927536,
#  165.15388170980685,
#  165.1591240325972,
#  161.75765382837827,
#  160.38495558981958,
#  162.8515839377505,
#  163.23033426220144,
#  162.60796181897567,
#  163.20535313756474,
#  159.85207941189805,
#  159.43960065047284,
#  163.02711189664518,
#  162.29167492947542,
#  161.06650192611502,
#  161.54266631026474,
#  162.2493128273551,
#  161.34036002904233,
#  159.45424572307692,
#  158.93024252590698,
#  179.98180948210762,
#  180.32428812508158,
#  181.44828523188923,
#  181.85738772183538,
#  181.37193747660277,
#  183.07965959571555,
#  181.98242894303522,
#  181.9890462671479,
#  182.5170028173597,
#  181.05773810842686,
#  181.87521691353703,
#  180.03276429352445,
#  182.05712746017593,
#  180.63577544472466,
#  182.02133384319478,
#  182.28155614688083,
#  181.25217444227437,
#  180.40635752646523,
#  181.01206069723466,
#  173.54478267376422,
#  175.2164460007091,
#  177.71842582214057,
#  177.31400778510752,
#  177.0543310751555,
#  177.03929315560728,
#  176.99933413749167,
#  177.03529956358656,
#  176.46298869128574,
#  178.55533081257087,
#  178.59148117514755,
#  180.2926535271475,
#  182.68389697783283,
#  180.36958101001338,
#  178.27156764988237,
#  167.78109428845676,
#  166.54524028635498,
#  162.97366701684223,
#  163.2750438633228,
#  161.45225265499786,
#  162.5590489176735,
#  161.19917362530262,
#  161.7772908315709,
#  160.97259607653953,
#  160.89166683832835,
#  159.47428467661547,
#  162.63025912294873,
#  162.1381551679906,
#  164.81540521340781,
#  163.67311593223226,
#  162.9017325338621,
#  162.2253107176911,
#  160.83880485189297,
#  162.26642717002642,
#  162.4643924576072,
#  178.44249287503078,
#  176.83040019144187,
#  178.27377977896765,
#  177.91066391197498,
#  179.37744748510204,
#  181.1748509662112,
#  178.93731857219055,
#  181.26576238274112,
#  184.5691913716969,
#  183.58601060469962,
#  182.91716854584152,
#  182.97862817866934,
#  186.36291270413977,
#  185.06769473867652,
#  181.2479979372502,
#  181.93168665112958,
#  181.15639656883621,
#  181.12808490914958,
#  181.28279964170594,
#  181.20558271299825,
#  178.02445388033158,
#  179.2699400974694,
#  178.81394267305026,
#  178.7666388197318,
#  180.34701255472518,
#  182.3829333228866,
#  180.49487866209174,
#  176.12386541207294,
#  175.07584672962375,
#  175.5940525403494,
#  175.58455349280007,
#  179.02377081500012,
#  179.48002982550426,
#  178.93037506693108,
#  179.91017955481706,
#  183.583024204538,
#  182.73918202592245,
#  180.7685155106375,
#  161.66753078878742,
#  164.29223324277862,
#  162.38584003178744,
#  165.36687861468474,
#  166.41478991653895,
#  169.783749815852,
#  163.77823152802938,
#  164.57029955720114,
#  165.85058980578475,
#  167.28253133218644,
#  163.68309568486936,
#  169.9088140918185,
#  166.10090662004504,
#  165.82850202939412,
#  165.65684829458667,
#  165.19181742186407,
#  166.56610385599748,
#  165.38226971194354,
#  163.67934490971552,
#  165.5178565303452,
#  165.41353181961514,
#  166.08252939146556,
#  165.3088716998704,
#  165.1571012517648,
#  162.9567210463974,
#  164.061869156823,
#  163.2442014857387,
#  162.89716370696985,
#  166.85001945936986,
#  162.37227490790173,
#  161.87201583113622,
#  182.71047020198685,
#  181.2986649202709,
#  180.52347503530478,
#  180.89291807861616,
#  179.82645120826314,
#  180.0567522658915,
#  164.41230571156308,
#  161.58814338586419,
#  162.64577277172978,
#  163.1519731953807,
#  162.76634768671622,
#  164.60571613084846,
#  165.63390458398277,
#  164.9509834163574,
#  162.91590184021513,
#  163.27859173777313,
#  162.63474988785958,
#  162.8262482913343,
#  162.10902570303276,
#  162.7040320487619,
#  165.13365363050323,
#  163.82100295951025,
#  163.12179015565832,
#  162.06170603241705,
#  185.81797425792217,
#  185.19752439156895,
#  182.35443298924724,
#  183.89684139752893,
#  182.97508766592108,
#  183.4511410335691,
#  182.90909084225262,
#  183.5650587920949,
#  182.8495494999252,
#  182.67387582758627,
#  182.6700504871101,
#  182.69179577549437,
#  182.8934869717816,
#  181.68761143675567,
#  171.8653865679043,
#  170.71647785700546,
#  173.5327784550477,
#  171.46910251593522,
#  172.48648867191858,
#  170.62436719012751,
#  173.16776756867915,
#  173.68423341906782,
#  174.37587798832237,
#  174.49188904318214,
#  173.7553586456929,
#  174.54503356545533,
#  173.36366899271786,
#  172.554850608843,
#  166.42158617951486,
#  164.47226376398694,
#  165.14366186909092,
#  165.6275963005536,
#  174.7632031454925,
#  170.53773669714684,
#  171.11589842047323,
#  171.47323118133323,
#  172.5783279623317,
#  170.52420751625598,
#  168.7283126937031,
#  173.76098696603685,
#  168.8698221875508,
#  170.03278509936885,
#  170.7519841962917,
#  172.76765589875026,
#  174.09713317772034,
#  184.27853311311864,
#  184.86024546269763,
#  184.1448876792911,
#  183.46593383118383,
#  183.66199668272014,
#  182.45114201063834,
#  182.25722192471298,
#  180.9058094608145,
#  180.66770025958286,
#  181.89767086173853,
#  180.11866169978367,
#  180.42250100238238,
#  179.7036370122625,
#  179.92428969229402,
#  179.66618919149994,
#  181.193870307385,
#  179.24945110867895,
#  178.4004894008288,
#  180.40090626418626,
#  180.96339490436702,
#  180.1962826319839,
#  173.0065989310723,
#  173.79326267860046,
#  173.79326267860046,
#  170.46522737618966,
#  168.94995135801983,
#  177.37950074827094,
#  164.29488605330752,
#  169.63396157201774,
#  173.03095217327194,
#  174.91074813751402,
#  174.32875829630976,
#  172.69591421838078,
#  171.26992757356595,
#  170.67802720873826,
#  169.96579200032048,
#  167.5665726704122,
#  168.21358228882377,
#  169.77026077014122,
#  170.00460358028866,
#  171.35331042618157,
#  183.84675383143903,
#  182.98941752434104,
#  181.9722013432445,
#  182.34618271699878,
#  183.58124743567305,
#  182.33508348086704,
#  182.00260250792124,
#  181.72092999598274,
#  181.75477600175805,
#  176.4293358628419,
#  175.67022539208733,
#  174.83305817266717,
#  175.62861929039795,
#  175.10258597591204,
#  176.00239855703285,
#  174.88430206529023,
#  177.23697257059442,
#  173.3334590119246,
#  172.55673854912718,
#  175.33315057785143,
#  174.01169651758258,
#  175.79078367927139,
#  171.41687071153092,
#  173.5232402258669,
#  187.03228290222853,
#  184.81268167952118,
#  186.41231122763944,
#  186.75354441049748,
#  185.49633295578545,
#  185.92387595383596,
#  183.46918480092975,
#  183.66329676027598,
#  183.28098463420517,
#  172.7188690400329,
#  172.65010311454824,
#  172.90008534929325,
#  172.20858658233462,
#  171.97303306034394,
#  172.55630499603004,
#  169.44576120542197,
#  169.60169774082053,
#  169.03767956807644,
#  170.01611678687138,
#  167.07779103608507,
#  169.95312149411396,
#  167.83491374186337,
#  166.3752454679,
#  166.51592983686564,
#  168.18665331040768,
#  166.4171026248374,
#  165.99889873688167,
#  164.86206844801006,
#  165.34694490551973,
#  165.66267413828422,
#  166.43633437463583,
#  165.86581986755075,
#  167.8108527635955,
#  167.77724297220107,
#  180.46180962035658,
#  179.24237454927297,
#  179.54020434457593,
#  181.1763518500324,
#  181.52519849450636,
#  181.56187560245363,
#  180.0378018929444,
#  181.50632861514467,
#  181.0397151453242,
#  178.9353366264757,
#  172.18873119010848,
#  173.18392930191484,
#  171.5935391651883,
#  175.7668929479092,
#  174.71470924648528,
#  176.30473094082717,
#  177.6562476050761,
#  177.53567543044352,
#  176.70714278257276,
#  177.72734422127044,
#  176.5941347811919,
#  174.28630246835584,
#  173.4987170533675,
#  175.09285337793557,
#  180.78628591014487,
#  180.78628591014487,
#  175.24587522384934,
#  177.75898043609632,
#  177.43615370350724,
#  177.06717285704866,
#  177.05587994235884,
#  177.64690988112292,
#  177.21070495662923,
#  176.9184469409494]

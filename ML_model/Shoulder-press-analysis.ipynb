# %%
import os
import sys

#import heuristic model files

hm_files_path = os.path.join(os.path.dirname(os.getcwd()), 'Heuristic_model')
print(hm_files_path)

if hm_files_path in sys.path:
    pass
else:
    sys.path.append(hm_files_path)

# %%
from Parser import parse_frames
from scipy.signal import medfilt
from Functions import find_extremas, filter_extremas, detect_side, analyse_each_rep
from JointAngles import JointAngles
import numpy as np
import math
import glob
import itertools
import itertools
import pickle
import matplotlib.pyplot as plt

# %%
# modify this path for other videos 
# input_folder = "/home/aleko/Documents/Projects/IndividualProject/bicepvid"
#input_folder = "C:\\Users\\kvash\\Documents\\GitHub\\IndividualProject\\keypoints_for_all\\shoulder_press"
input_folder = "C:\\Users\\kvash\\Documents\\GitHub\\IndividualProject\\test_fig\\shoulder_press"
#input_folder = 'C:\\Users\\ak5u16\\Desktop\\IndividualProject\\keypoints_for_all\\shoulder press'
folder_paths = glob.glob(os.path.join(input_folder, 'shoulder_press_correct_13'))     

min_upper_arm_forearm = [] 
max_upper_arm_forearm = []
max_upper_arm_trunk = []
min_upper_arm_trunk = []


for folder in folder_paths:
    print("Starting..." + "\nKeypoints from folder: " + os.path.basename(folder))
    video_name = os.path.basename(folder)
    frame_poses = parse_frames(folder)
       
    joint_angles = JointAngles('shoulder_press', frame_poses)
    
   

    left_upArm_trunk_angles = np.array(joint_angles.left_upArm_trunk_angles)
    left_upArm_trunk_angles_filtered = medfilt(medfilt(left_upArm_trunk_angles, 5), 5)
    
    right_upArm_trunk_angles = np.array(joint_angles.right_upArm_trunk_angles)
    right_upArm_trunk_angles_filtered = medfilt(medfilt(right_upArm_trunk_angles, 5), 5)
    
    left_upArm_forearm_angles = np.array(joint_angles.left_upArm_forearm_angles)
    left_upArm_forearm_angles_filtered = medfilt(medfilt(left_upArm_forearm_angles, 5), 5)
    
    right_upArm_forearm_angles = np.array(joint_angles.right_upArm_forearm_angles)
    right_upArm_forearm_angles_filtered = medfilt(medfilt(right_upArm_forearm_angles, 5), 5)
    
        
    # Find left upper arm and trunk maximum angles to detect wrong form 
    left_upArm_trunk_maximas = find_extremas(left_upArm_trunk_angles_filtered)
    left_upArm_trunk_maximas = filter_extremas(left_upArm_trunk_angles_filtered, left_upArm_trunk_maximas)
    indexesmax1a = np.array([np.argwhere(left_upArm_trunk_angles_filtered == maxima)[0][0] for maxima in left_upArm_trunk_maximas])
   
    
    # print("Largest angles between upper arm and trunk: " + str(upArm_trunk_maximas))
    # Find right upper arm and trunk maximum angles to detect wrong form 
    right_upArm_trunk_maximas = find_extremas(right_upArm_trunk_angles_filtered)
    right_upArm_trunk_maximas = filter_extremas(right_upArm_trunk_angles_filtered, right_upArm_trunk_maximas)
    indexesmax1b = np.array([np.argwhere(right_upArm_trunk_angles_filtered == maxima)[0][0] for maxima in right_upArm_trunk_maximas])
   
    # Count repetitions
    left_upArm_forearm_maximas = find_extremas(left_upArm_forearm_angles_filtered)    
    left_upArm_forearm_maximas = filter_extremas(left_upArm_forearm_angles_filtered, left_upArm_forearm_maximas)
    indexesmax2a = np.array([np.argwhere(left_upArm_forearm_angles_filtered == maxima)[0][0] for maxima in left_upArm_forearm_maximas])
   
    # print("Number of maxima points between Upper Arm and Forearm: " + str(upArm_forearm_maximas.size))
    # print(upArm_forearm_maximas)
    
    right_upArm_forearm_maximas = find_extremas(right_upArm_forearm_angles_filtered) 
    right_upArm_forearm_maximas = filter_extremas(right_upArm_forearm_angles_filtered, right_upArm_forearm_maximas)
    indexesmax2b = np.array([np.argwhere(right_upArm_forearm_angles_filtered == maxima)[0][0] for maxima in right_upArm_forearm_maximas])
   

    # Find upper arm and forearm minimum points to count reps     
    left_upArm_forearm_minimas = find_extremas(left_upArm_forearm_angles_filtered, maxima=False)
    
    left_upArm_forearm_minimas = filter_extremas(left_upArm_forearm_angles_filtered,left_upArm_forearm_minimas, False)
    indexesmin1a = np.array([np.argwhere(left_upArm_forearm_angles_filtered == minima)[0][0] for minima in left_upArm_forearm_minimas])
  
 
    # print(left_upArm_forearm_minimas)
    
    right_upArm_forearm_minimas = find_extremas(right_upArm_forearm_angles_filtered, maxima=False)
   
    right_upArm_forearm_minimas = filter_extremas(right_upArm_forearm_angles_filtered, right_upArm_forearm_minimas, False)
    indexesmin1b = np.array([np.argwhere(right_upArm_forearm_angles_filtered == minima)[0][0] for minima in right_upArm_forearm_minimas])
  
   
    print('----------------------Filtering minimas---------------------------------------------------')
    left_upArm_trunk_minimas = find_extremas(left_upArm_trunk_angles_filtered, maxima=False)
    left_upArm_trunk_minimas = filter_extremas(left_upArm_trunk_angles_filtered, left_upArm_trunk_minimas, False)
    indexesmin2a = np.array([np.argwhere(left_upArm_trunk_angles_filtered == minima)[0][0] for minima in left_upArm_trunk_minimas])

    print("\nSize of left minimas array: " + str(left_upArm_trunk_minimas.size))
    print('---------------------------------------------------------------------------------------------')
    print('----------------------Filtering minimas----------------------------------------------------')
    right_upArm_trunk_minimas = find_extremas(right_upArm_trunk_angles_filtered, maxima=False)
    right_upArm_trunk_minimas = filter_extremas(right_upArm_trunk_angles_filtered, right_upArm_trunk_minimas, False)
    indexesmin2b = np.array([np.argwhere(right_upArm_trunk_angles_filtered == minima)[0][0] for minima in right_upArm_trunk_minimas])
    print("\nSize of right minimas array: " + str(right_upArm_trunk_minimas.size))
    print('----------------------------------------------------------------------------------------------')
    print('\n'+ '-'*120 + '\nLEFT ARM'.center(100) + '\n' + '-'*120 )
    
    # Plot 1 - Left
    plt.figure(figsize=(10,4))
    #plt.scatter(np.arange(left_upArm_trunk_angles.shape[0]), left_upArm_trunk_angles, alpha=0.5)
    plt.plot(np.arange(left_upArm_trunk_angles_filtered.shape[0]), left_upArm_trunk_angles_filtered, c='r', alpha=1)
    #plt.title(video_name)
    plt.xlabel('Frames')
    plt.ylabel('Angle between LEFT Upper Arm and Trunk')
    # Set range on y-axis so the plots are consistent
    plt.ylim(0,200)
    
    # Annontate minima points
    #plt.plot(indexesmin2a, left_upArm_trunk_angles_filtered[indexesmin2a], 'bo')
    # print(indexesmax1a)
    plt.show()
    
    # Plot 2 - Left
    plt.figure(figsize=(10,4))
    #plt.scatter(np.arange(left_upArm_forearm_angles.shape[0]), left_upArm_forearm_angles, alpha=0.5)
    plt.plot(np.arange(left_upArm_forearm_angles_filtered.shape[0]), left_upArm_forearm_angles_filtered, c='r', alpha=1)
    #plt.title(video_name)
    plt.xlabel('Frames')
    plt.ylabel('Angle between LEFT Upper Arm and Forearm')
    # Set range on y-axis so the plots are consistent
    plt.ylim(0,200) 
    
    # Annotate minima apoints on the graph   
    #max_points1a = left_upArm_forearm_angles_filtered[indexesmax2a]
    #min_points1a = left_upArm_forearm_angles_filtered[indexesmin1a]
    #plt.plot(indexesmin1a, min_points1a, 'bo')
    #plt.plot(indexesmax2a, max_points1a, 'ks')

    """
        # Annotate local maximas
        for maxp, indx in zip(max_points, indexesmax2):
            plt.annotate('local max', xy=(indx, maxp), xytext=(indx, maxp+25),
                    arrowprops=dict(facecolor='black', shrink=0.05))

        # Annotate local minimas
        for minp, indx in zip(min_points, indexesmin):
            plt.annotate('local min', xy=(indx, minp), xytext=(indx, minp-35),
                    arrowprops=dict(facecolor='black', shrink=0.05))     
    """
    
    plt.show()
    

    # Plot 3 - All angles LEFT
    plt.figure(figsize=(10,4))
    plt.plot(np.arange(left_upArm_forearm_angles_filtered.shape[0]), left_upArm_forearm_angles_filtered, c='r', alpha=1)
    plt.plot(np.arange(left_upArm_trunk_angles_filtered.shape[0]), left_upArm_trunk_angles_filtered, c='r', alpha=1)
    
    #plt.title(video_name)
    plt.xlabel('Frames')
    plt.ylabel('LEFT arm movement')
    # Set range on y-axis so the plots are consistent
    plt.ylim(0,200) 
    # Annotate minima apoints   
    print(indexesmin2a)
    #plt.plot(indexesmin1a, left_upArm_forearm_angles_filtered[indexesmin1a], 'bo')
    plt.plot(indexesmax1a, left_upArm_trunk_angles_filtered[indexesmax1a], 'ro')
    plt.plot(indexesmin2a, left_upArm_trunk_angles_filtered[indexesmin2a], 'ko')
    #plt.plot(indexesmax2a, left_upArm_forearm_angles_filtered[indexesmax2a], 'ks')  
    plt.show()

   
    
    #---------------------------------------------------------------------------------------------------------------------
    # Same for right side
    
    print('\n'+ '-'*120 + '\nRIGHT ARM'.center(200) + '\n' + '-'*120 )
    
    # Plot 1 - Right
    plt.figure(figsize=(10,4))
    #plt.scatter(np.arange(right_upArm_trunk_angles.shape[0]), right_upArm_trunk_angles, alpha=0.5)
    plt.plot(np.arange(right_upArm_trunk_angles_filtered.shape[0]), right_upArm_trunk_angles_filtered, c='r', alpha=1)
    #plt.title(video_name)
    plt.xlabel('Frames')
    plt.ylabel('Angle between RIGHT Upper Arm and Trunk')
    # Set range on y-axis so the plots are consistent
    plt.ylim(0,200)
    
    # Annontate minima points
    #plt.plot(indexesmin2b, right_upArm_trunk_angles_filtered[indexesmin2b], 'bo')
    plt.show()

    # Plot 2 - Right
    plt.figure(figsize=(10,4))
    #plt.scatter(np.arange(right_upArm_forearm_angles.shape[0]), right_upArm_forearm_angles, alpha=0.5)
    plt.plot(np.arange(right_upArm_forearm_angles_filtered.shape[0]), right_upArm_forearm_angles_filtered, c='r', alpha=1)
    #plt.title(video_name)
    plt.xlabel('Frames')
    plt.ylabel('Angle between RIGHT Upper Arm and Forearm')
    # Set range on y-axis so the plots are consistent
    plt.ylim(0,200) 
    
    # Annotate minima apoints on the graph   
    #max_points1b = right_upArm_forearm_angles_filtered[indexesmax2b]
    #min_points1b = right_upArm_forearm_angles_filtered[indexesmin1b]
    #plt.plot(indexesmin1b, min_points1b, 'bo')
    #plt.plot(indexesmax2b, max_points1b, 'ks')
    
    """
        # Annotate local maximas
        for maxp, indx in zip(max_points1b, indexesmax2b):
            plt.annotate('local max', xy=(indx, maxp), xytext=(indx, maxp+25),
                    arrowprops=dict(facecolor='black', shrink=0.05))

        # Annotate local minimas
        for minp, indx in zip(min_points, indexesmin):
            plt.annotate('local min', xy=(indx, minp), xytext=(indx, minp-35),
                    arrowprops=dict(facecolor='black', shrink=0.05))     
    """
    plt.show()


    # Plot 4 - All angles RIGHT
    plt.figure(figsize=(10,4))
    plt.plot(np.arange(right_upArm_forearm_angles_filtered.shape[0]), right_upArm_forearm_angles_filtered, c='r', alpha=1)
    plt.plot(np.arange(right_upArm_trunk_angles_filtered.shape[0]), right_upArm_trunk_angles_filtered, c='r', alpha=1)
    #plt.title(video_name)
    plt.xlabel('Frames')
    plt.ylabel('RIGHT arm movement')
    # Set range on y-axis so the plots are consistent
    plt.ylim(0,200) 
    # Annotate minima apoints     
    #plt.plot(indexesmin1b, right_upArm_forearm_angles_filtered[indexesmin1b], 'bo')
    plt.plot(indexesmax1b, right_upArm_trunk_angles_filtered[indexesmax1b], 'ro')
    plt.plot(indexesmin2b, right_upArm_trunk_angles_filtered[indexesmin2b], 'ko')
    #plt.plot(indexesmax2b, right_upArm_forearm_angles_filtered[indexesmax2b], 'ks')
    plt.show()


   
    # Each rep analysis
    # local minimums for upper arm and forearm are min angles in each rep
    """
    min_upper_arm_forearm1, max_upper_arm_forearm1, min_upper_arm_trunk1, max_upper_arm_trunk1 = analyse_each_rep(exercise='shoulder_press', mode='thresholds', 
                                                                                                                  extremas1=left_upArm_trunk_minimas, 
                                                                                                                  uf_angles1=left_upArm_forearm_angles_filtered, 
                                                                                                                  ut_angles1=left_upArm_trunk_angles_filtered, 
                                                                                                                  extremas2=right_upArm_trunk_minimas, 
                                                                                                                  uf_angles2=right_upArm_forearm_angles_filtered, 
                                                                                                                  ut_angles2=right_upArm_trunk_angles_filtered)
    
    """
    analyse_each_rep(exercise='shoulder_press', mode='analysis', extremas1=left_upArm_trunk_minimas,
                     uf_angles1=left_upArm_forearm_angles_filtered, ut_angles1=left_upArm_trunk_angles_filtered, 
                     extremas2=right_upArm_trunk_minimas, uf_angles2=right_upArm_forearm_angles_filtered, 
                     ut_angles2=right_upArm_trunk_angles_filtered)
    """ 
    
    min_upper_arm_forearm = min_upper_arm_forearm + min_upper_arm_forearm1
    max_upper_arm_forearm = max_upper_arm_forearm + max_upper_arm_forearm1
    max_upper_arm_trunk = max_upper_arm_trunk + max_upper_arm_trunk1
    min_upper_arm_trunk = min_upper_arm_trunk + min_upper_arm_trunk1

    

    print('\n' + '='*120 + '\n')
    
print('Minimum in Minimum Upper Arm Forearm threshold: ' + str(min(min_upper_arm_forearm)))
print('Maximum in Minimum Upper Arm Forearm threshold: ' + str(max(min_upper_arm_forearm)))
print('Maximum in maximum Upper Arm Forearm threshold: ' + str(max(max_upper_arm_forearm)))
print('Minimum in maximum Upper Arm Forearm threshold: ' + str(min(max_upper_arm_forearm)))
print('Minimum in Minimum Upper Arm Trunk threshold: ' + str(min(min_upper_arm_trunk)))
print('Maximum in Minimum Upper Arm Trunk threshold: ' + str(max(min_upper_arm_trunk)))
print('Minimum in Maximum Upper Arm Trunk threshold: ' + str(min(max_upper_arm_trunk)))
print('Maximum in Maximum Upper Arm Trunk threshold: ' + str(max(max_upper_arm_trunk)))
"""
# Out:
# Starting...
# Keypoints from folder: shoulder_press_correct_13
# ----------------------Filtering minimas---------------------------------------------------
#
# Size of left minimas array: 7
# ---------------------------------------------------------------------------------------------
# ----------------------Filtering minimas----------------------------------------------------
#
# Size of right minimas array: 7
# ----------------------------------------------------------------------------------------------
#
# ------------------------------------------------------------------------------------------------------------------------
# LEFT ARM
# ------------------------------------------------------------------------------------------------------------------------
# [ 60 125 187 251 310 370 427]
# ------------------------------------------------------------------------------------------------------------------------
# RIGHT ARM
# ------------------------------------------------------------------------------------------------------------------------
# Number of reps performed: 8
#
# Repetition: 1
#
# Starting position left upper arm - left forearm angle: 59.93284226729328
# Starting position left upper arm - trunk angle: 74.79139468435079
#
# Left upper arm - left forearm -> Minimum Angle: 59.93284226729328
# Left upper arm - left forearm -> Maximum Angle: 159.32946211868395
# Left upper arm - trunk -> Maximum Angle: 160.36884116598233
# Left upper arm - trunk -> Minimum Angle: 72.76047406311348
#
# Finishing position left upper arm - left forearm angle: 62.72228887134876
# Finishing position left upper arm - trunk angle: 72.76047406311348
# Starting position right upper arm - right forearm angle: 57.39855069834709
# Starting position right upper arm - trunk angle: 67.11602479770629
#
# Right upper arm - right forearm -> Minimum Angle: 57.39855069834709
# Right upper arm - right forearm -> Maximum Angle: 156.97456272218838
# Right upper arm - trunk -> Maximum Angle: 159.68574976572617
# Right upper arm - trunk -> Minimum Angle: 67.11602479770629
#
# Finishing position right upper arm - right forearm angle: 57.85346713967923
# Finishing position right upper arm - trunk angle: 68.4986947283466
#
# Repetition: 2
#
# Starting position left upper arm - left forearm angle: 62.72228887134876
# Starting position left upper arm - trunk angle: 71.69968425890129
#
# Left upper arm - left forearm -> Minimum Angle: 62.72228887134876
# Left upper arm - left forearm -> Maximum Angle: 155.49330802915705
# Left upper arm - trunk -> Maximum Angle: 161.45061226847653
# Left upper arm - trunk -> Minimum Angle: 71.69968425890129
#
# Finishing position left upper arm - left forearm angle: 64.20971649105074
# Finishing position left upper arm - trunk angle: 76.05131964212504
# Starting position right upper arm - right forearm angle: 57.85346713967923
# Starting position right upper arm - trunk angle: 67.08804131120756
#
# Right upper arm - right forearm -> Minimum Angle: 57.85346713967923
# Right upper arm - right forearm -> Maximum Angle: 158.0866728081375
# Right upper arm - trunk -> Maximum Angle: 157.96353362085495
# Right upper arm - trunk -> Minimum Angle: 67.08804131120756
#
# Finishing position right upper arm - right forearm angle: 60.50702389423296
# Finishing position right upper arm - trunk angle: 67.5466706402457
#
# Repetition: 3
#
# Starting position left upper arm - left forearm angle: 64.37162458149555
# Starting position left upper arm - trunk angle: 75.93686356679407
#
# Left upper arm - left forearm -> Minimum Angle: 62.26290218192685
# Left upper arm - left forearm -> Maximum Angle: 153.56099309844268
# Left upper arm - trunk -> Maximum Angle: 160.07773219787
# Left upper arm - trunk -> Minimum Angle: 75.18366944208103
#
# Finishing position left upper arm - left forearm angle: 62.64351277230309
# Finishing position left upper arm - trunk angle: 75.18366944208103
# Starting position right upper arm - right forearm angle: 59.483422379887536
# Starting position right upper arm - trunk angle: 67.17143779276877
#
# Right upper arm - right forearm -> Minimum Angle: 59.483422379887536
# Right upper arm - right forearm -> Maximum Angle: 156.33577344143927
# Right upper arm - trunk -> Maximum Angle: 156.74349584553823
# Right upper arm - trunk -> Minimum Angle: 67.17143779276877
#
# Finishing position right upper arm - right forearm angle: 59.73951452945791
# Finishing position right upper arm - trunk angle: 72.36713347212616
#
# Repetition: 4
#
# Starting position left upper arm - left forearm angle: 62.64394291798687
# Starting position left upper arm - trunk angle: 75.03615258254568
#
# Left upper arm - left forearm -> Minimum Angle: 62.64394291798687
# Left upper arm - left forearm -> Maximum Angle: 155.0627249041381
# Left upper arm - trunk -> Maximum Angle: 163.59696686492921
# Left upper arm - trunk -> Minimum Angle: 74.76156809958741
#
# Finishing position left upper arm - left forearm angle: 65.04727831632563
# Finishing position left upper arm - trunk angle: 74.76156809958741
# Starting position right upper arm - right forearm angle: 58.80659449508425
# Starting position right upper arm - trunk angle: 67.52394941794279
#
# Right upper arm - right forearm -> Minimum Angle: 58.80659449508425
# Right upper arm - right forearm -> Maximum Angle: 159.98252799678815
# Right upper arm - trunk -> Maximum Angle: 159.00511123622033
# Right upper arm - trunk -> Minimum Angle: 67.52394941794279
#
# Finishing position right upper arm - right forearm angle: 65.97642943741418
# Finishing position right upper arm - trunk angle: 70.11467707655832
#
# Repetition: 5
#
# Starting position left upper arm - left forearm angle: 65.04727831632563
# Starting position left upper arm - trunk angle: 74.2995260000172
#
# Left upper arm - left forearm -> Minimum Angle: 65.04727831632563
# Left upper arm - left forearm -> Maximum Angle: 151.72559513066233
# Left upper arm - trunk -> Maximum Angle: 159.3799799886446
# Left upper arm - trunk -> Minimum Angle: 74.2995260000172
#
# Finishing position left upper arm - left forearm angle: 66.07099245084294
# Finishing position left upper arm - trunk angle: 74.64288255809032
# Starting position right upper arm - right forearm angle: 65.97642943741418
# Starting position right upper arm - trunk angle: 68.38789257923975
#
# Right upper arm - right forearm -> Minimum Angle: 60.61099455002618
# Right upper arm - right forearm -> Maximum Angle: 155.58477081784653
# Right upper arm - trunk -> Maximum Angle: 160.23294485663408
# Right upper arm - trunk -> Minimum Angle: 68.38789257923975
#
# Finishing position right upper arm - right forearm angle: 60.61099455002618
# Finishing position right upper arm - trunk angle: 71.37423724919563
#
# Repetition: 6
#
# Starting position left upper arm - left forearm angle: 66.06118806170961
# Starting position left upper arm - trunk angle: 74.44063874461303
#
# Left upper arm - left forearm -> Minimum Angle: 65.18313492737424
# Left upper arm - left forearm -> Maximum Angle: 151.79867828352167
# Left upper arm - trunk -> Maximum Angle: 157.67769854465425
# Left upper arm - trunk -> Minimum Angle: 74.28668275220016
#
# Finishing position left upper arm - left forearm angle: 65.18313492737424
# Finishing position left upper arm - trunk angle: 74.28668275220016
# Starting position right upper arm - right forearm angle: 60.61099455002618
# Starting position right upper arm - trunk angle: 68.54260278697967
#
# Right upper arm - right forearm -> Minimum Angle: 60.61099455002618
# Right upper arm - right forearm -> Maximum Angle: 151.92935949592325
# Right upper arm - trunk -> Maximum Angle: 151.67247081310558
# Right upper arm - trunk -> Minimum Angle: 68.1034488873907
#
# Finishing position right upper arm - right forearm angle: 63.714395808410714
# Finishing position right upper arm - trunk angle: 68.1034488873907
#
# Repetition: 7
#
# Starting position left upper arm - left forearm angle: 65.55000417342757
# Starting position left upper arm - trunk angle: 73.29399523521751
#
# Left upper arm - left forearm -> Minimum Angle: 65.55000417342757
# Left upper arm - left forearm -> Maximum Angle: 151.55190361187195
# Left upper arm - trunk -> Maximum Angle: 157.71249581663173
# Left upper arm - trunk -> Minimum Angle: 73.29399523521751
#
# Finishing position left upper arm - left forearm angle: 68.11606296694141
# Finishing position left upper arm - trunk angle: 74.57846335138429
# Starting position right upper arm - right forearm angle: 63.714395808410714
# Starting position right upper arm - trunk angle: 68.03285662611712
#
# Right upper arm - right forearm -> Minimum Angle: 63.714395808410714
# Right upper arm - right forearm -> Maximum Angle: 160.31014893383986
# Right upper arm - trunk -> Maximum Angle: 151.08049022208934
# Right upper arm - trunk -> Minimum Angle: 63.88808614467198
#
# Finishing position right upper arm - right forearm angle: 64.40676164747309
# Finishing position right upper arm - trunk angle: 63.88808614467198
#
# Repetition: 8
#
# Starting position left upper arm - left forearm angle: 70.03753001041986
# Starting position left upper arm - trunk angle: 73.96798067136677
#
# Left upper arm - left forearm -> Minimum Angle: 66.99299209264737
# Left upper arm - left forearm -> Maximum Angle: 158.16853347793227
# Left upper arm - trunk -> Maximum Angle: 158.41048980045466
# Left upper arm - trunk -> Minimum Angle: 73.96798067136677
#
# Finishing position left upper arm - left forearm angle: 66.99299209264737
# Finishing position left upper arm - trunk angle: 74.74249259612982
# Starting position right upper arm - right forearm angle: 63.04470038535731
# Starting position right upper arm - trunk angle: 63.83169198173028
#
# Right upper arm - right forearm -> Minimum Angle: 61.69310083691964
# Right upper arm - right forearm -> Maximum Angle: 157.86345338080702
# Right upper arm - trunk -> Maximum Angle: 157.38406615066404
# Right upper arm - trunk -> Minimum Angle: 63.83169198173028
#
# Finishing position right upper arm - right forearm angle: 66.75030190390804
# Finishing position right upper arm - trunk angle: 64.59907850451614

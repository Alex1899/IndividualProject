# %%
from Evaluation import evaluate_form
from Parser import parse_frames
import os
import glob

# %%
#test_video = "C:\\Users\\altaok\\Documents\\GitHub\\IndividualProject\\keypoints_for_all\\triceps pushdown\\triceps_pushdown_correct_20"
#test_video = "C:\\Users\\ak5u16\\Desktop\\IndividualProject\\keypoints_for_all\\triceps pushdown\\triceps_pushdown_incorrect_9"
#test_video = "C:\\Users\\ak5u16\\Desktop\\IndividualProject\\keypoints_for_all\\shoulder press\\shoulder_press_incorrect_16"
#input_folder = "C:\\Users\\altaok\\Documents\\GitHub\\IndividualProject\\keypoints_for_all\\shoulder press"
input_folder = "C:\\Users\\kvash\\Documents\\GitHub\\IndividualProject\\keypoints_for_all\\triceps_pushdown"
folder_paths = glob.glob(os.path.join(input_folder, 'triceps_pushdown_correct_*'))  


for test_video in folder_paths:
    video_name = os.path.basename(test_video)
    points_folder_name = video_name.split('.', 1)[0]
    folder = video_name.split('_', 2)[0] + ' ' + video_name.split('_', 2)[1]

    frame_pose = parse_frames(test_video)

    print(video_name, evaluate_form(frame_pose, os.path.basename(input_folder), False))
# Out:
# triceps_pushdown_correct_1 0
# triceps_pushdown_correct_10 0
# triceps_pushdown_correct_11 0
# triceps_pushdown_correct_12 0
# triceps_pushdown_correct_13 0
# triceps_pushdown_correct_14 0
# triceps_pushdown_correct_15 0
# triceps_pushdown_correct_16 0
# triceps_pushdown_correct_17 0
# triceps_pushdown_correct_18 0
# triceps_pushdown_correct_19 0
# triceps_pushdown_correct_2 0
# triceps_pushdown_correct_20 0
# triceps_pushdown_correct_21 0
# triceps_pushdown_correct_22 0
# triceps_pushdown_correct_23 0
# triceps_pushdown_correct_24 0
# triceps_pushdown_correct_25 0
# triceps_pushdown_correct_26 0
# triceps_pushdown_correct_27 0
# triceps_pushdown_correct_28 0
# triceps_pushdown_correct_29 0
# triceps_pushdown_correct_3 0
# triceps_pushdown_correct_30 0
# triceps_pushdown_correct_31 0
# triceps_pushdown_correct_32 0
# triceps_pushdown_correct_33 0
# triceps_pushdown_correct_34 0
# triceps_pushdown_correct_35 0
# triceps_pushdown_correct_36 0
# triceps_pushdown_correct_37 0
# triceps_pushdown_correct_38 0
# triceps_pushdown_correct_39 0
# triceps_pushdown_correct_4 0
# triceps_pushdown_correct_40 0
# triceps_pushdown_correct_41 0
# triceps_pushdown_correct_42 0
# triceps_pushdown_correct_43 0
# triceps_pushdown_correct_44 0
# triceps_pushdown_correct_45 0
# triceps_pushdown_correct_46 0
# triceps_pushdown_correct_47 0
# triceps_pushdown_correct_48 0
# triceps_pushdown_correct_49 0
# triceps_pushdown_correct_5 0
# triceps_pushdown_correct_6 0
# triceps_pushdown_correct_7 0
# triceps_pushdown_correct_8 0
# triceps_pushdown_correct_9 0

# %%
input_folder = "C:\\Users\\kvash\\Documents\\GitHub\\IndividualProject\\keypoints_for_all\\bicep_curl"
folder_paths = glob.glob(os.path.join(input_folder, 'bicep_curl*'))  


for test_video in folder_paths:
    video_name = os.path.basename(test_video)
    points_folder_name = video_name.split('.', 1)[0]
    folder = video_name.split('_', 2)[0] + ' ' + video_name.split('_', 2)[1]

    frame_pose = parse_frames(test_video)

    print(video_name, evaluate_form(frame_pose, os.path.basename(input_folder), False))
# Out:
# Starting Bicep Curl Analysis...
# Detected side: right
#
# Analysing each repetition below:
#
#
# ----------------------------------------------------------------------------------------------------
# Repetition 1
# ----------------------------------------------------------------------------------------------------
# Good Form: The weight was brought up high enough for a good contraction.
#
# Good Form: The weight was lowered and correct starting position was achieved.
#
# Good Form: Elbows did not move significantly during the movement.
#
# Good Form: No leaning forward excessively.
#
# Good Form: No leaning backwards excessively.
#
#
# Repetition was performed with a good form.
#
#
# ----------------------------------------------------------------------------------------------------
# Repetition 2
# ----------------------------------------------------------------------------------------------------
# Good Form: The weight was brought up high enough for a good contraction.
#
# Good Form: The weight was lowered and correct starting position was achieved.
#
# Good Form: Elbows did not move significantly during the movement.
#
# Good Form: No leaning forward excessively.
#
# Good Form: No leaning backwards excessively.
#
#
# Repetition was performed with a good form.
#
#
# ----------------------------------------------------------------------------------------------------
# Repetition 3
# ----------------------------------------------------------------------------------------------------
# Good Form: The weight was brought up high enough for a good contraction.
#
# Good Form: The weight was lowered and correct starting position was achieved.
#
# Good Form: Elbows did not move significantly during the movement.
#
# Good Form: No leaning forward excessively.
#
# Good Form: No leaning backwards excessively.
#
#
# Repetition was performed with a good form.
#
#
# ----------------------------------------------------------------------------------------------------
# Repetition 4
# ----------------------------------------------------------------------------------------------------
# Good Form: The weight was brought up high enough for a good contraction.
#
# Good Form: The weight was lowered and correct starting position was achieved.
#
# Good Form: Elbows did not move significantly during the movement.
#
# Good Form: No leaning forward excessively.
#
# Good Form: No leaning backwards excessively.
#
#
# Repetition was performed with a good form.
#
#
# ----------------------------------------------------------------------------------------------------
# Repetition 5
# ----------------------------------------------------------------------------------------------------
# Good Form: The weight was brought up high enough for a good contraction.
#
# Good Form: The weight was lowered and correct starting position was achieved.
#
# Good Form: Elbows did not move significantly during the movement.
#
# Good Form: No leaning forward excessively.
#
# Good Form: No leaning backwards excessively.
#
#
# Repetition was performed with a good form.
#
#
# ----------------------------------------------------------------------------------------------------
# Repetition 6
# ----------------------------------------------------------------------------------------------------
# Bad Form:  The weight has not been curled high enough.
# Fix: Focus on bringing the weight higher in order to get maximum biceps contraction.
#
# Good Form: The weight was lowered and correct starting position was achieved.
#
# Good Form: Elbows did not move significantly during the movement.
#
# Good Form: No leaning forward excessively.
#
# Good Form: No leaning backwards excessively.
#
#
# Repetition form could be improved.
#
#
# ----------------------------------------------------------------------------------------------------
# Repetition 7
# ----------------------------------------------------------------------------------------------------
# Bad Form:  The weight has not been curled high enough.
# Fix: Focus on bringing the weight higher in order to get maximum biceps contraction.
#
# Good Form: The weight was lowered and correct starting position was achieved.
#
# Good Form: Elbows did not move significantly during the movement.
#
# Good Form: No leaning forward excessively.
#
# Good Form: No leaning backwards excessively.
#
#
# Repetition form could be improved.
#
#
# ----------------------------------------------------------------------------------------------------
# Decision: Overall the exercise was performed with a good form. However, your technique during the following reps: [6, 7] could be improved. Look at the feedback for the following reps to see what you did wrong.
# ----------------------------------------------------------------------------------------------------
# bicep_curl_correct_10 None

# %%
from Parser import parse_frames
from scipy.signal import medfilt
from Functions import find_extremas, filter_extremas, detect_side, analyse_each_rep
from JointAngles import JointAngles
import numpy as np
import math
import glob
import os
import itertools
import pickle
import matplotlib.pyplot as plt

# %%
# modify this path for other videos 
# input_folder = "/home/aleko/Documents/Projects/IndividualProject/bicepvid"
# input_folder = "C:\\Users\\altaok\\Documents\\GitHub\\IndividualProject\\keypoints_for_all\\triceps pushdown"

input_folder = 'C:\\Users\\ak5u16\\Desktop\\IndividualProject\\keypoints_for_all\\triceps pushdown'
folder_paths = glob.glob(os.path.join(input_folder, 'triceps_pushdown_incorrect*'))     

for folder in folder_paths:
    print("Starting..." + "\nKeypoints from folder: " + os.path.basename(folder))
    video_name = os.path.basename(folder).replace('output_points_', '')
    frame_poses = parse_frames(folder)
    
    joint_angles = JointAngles('triceps pushdown', frame_poses)
    print('Detected arm: ' + joint_angles.side)

    upArm_trunk_angles = np.array(joint_angles.upArm_trunk_angles)
    upArm_trunk_angles_filtered = medfilt(medfilt(upArm_trunk_angles, 5), 5)
    
   
    upArm_forearm_angles = np.array(joint_angles.upArm_forearm_angles)
    upArm_forearm_angles_filtered = medfilt(medfilt(upArm_forearm_angles, 5), 5)
    
    trunk_knee_angles = np.array(joint_angles.trunk_knee_angles)
    trunk_knee_angles_filtered = medfilt(medfilt(trunk_knee_angles, 5), 5)
    
    # Find upper arm and trunk maximum angles to detect wrong form 
    upArm_trunk_maximas = find_extremas(upArm_trunk_angles_filtered)
    upArm_trunk_maximas = filter_extremas(upArm_trunk_angles_filtered, upArm_trunk_maximas)
    indexesmax1 = np.array([np.argwhere(upArm_trunk_angles_filtered == maxima)[0][0] for maxima in upArm_trunk_maximas])
    # print("Largest angles between upper arm and trunk: " + str(upArm_trunk_maximas))

    # Find trunk and knee maximum angles to detect wrong form 
    trunk_knee_maximas = find_extremas(trunk_knee_angles_filtered)
    trunk_knee_maximas = filter_extremas(trunk_knee_angles_filtered, trunk_knee_maximas)
    indexesmax2 = np.array([np.argwhere(trunk_knee_angles_filtered == maxima)[0][0] for maxima in trunk_knee_maximas])
   
    # print("Largest angles between trunk and knee: " + str(trunk_knee_maximas))

    # Count repetitions
    upArm_forearm_maximas = find_extremas(upArm_forearm_angles_filtered)  
    upArm_forearm_maximas = filter_extremas(upArm_forearm_angles_filtered, upArm_forearm_maximas)
    indexesmax3 = np.array([np.argwhere(upArm_forearm_angles_filtered == maxima)[0][0] for maxima in upArm_forearm_maximas])
   
    # print("Number of maxima points between Upper Arm and Forearm: " + str(upArm_forearm_maximas.size))
    # print(upArm_forearm_maximas)
    
    # Find upper arm and forearm minimum points to count reps 
    upArm_forearm_minimas = find_extremas(upArm_forearm_angles_filtered, maxima=False)
    print('\n----------------------------Filtering minimas-------------------------------------')
    upArm_forearm_minimas = filter_extremas(upArm_forearm_angles_filtered, upArm_forearm_minimas, maxima=False)
    indexesmin = np.array([np.argwhere(upArm_forearm_angles_filtered == minima)[0][0] for minima in upArm_forearm_minimas])
    print("\nSize of minima array: " + str(upArm_forearm_minimas.size))
    print('-'*90)
    
   
    # Plot 1
    plt.figure(figsize=(10,4))
    plt.scatter(np.arange(upArm_trunk_angles.shape[0]), upArm_trunk_angles, alpha=0.5)
    plt.scatter(np.arange(upArm_trunk_angles_filtered.shape[0]), upArm_trunk_angles_filtered, c='r', alpha=0.5)
    plt.title(video_name)
    plt.xlabel('Frames')
    plt.ylabel('Angle between Upper Arm and Trunk')
    # Set range on y-axis so the plots are consistent
    plt.ylim(0,90)
    
    # Annontate maxima points
    plt.plot(indexesmax1, upArm_trunk_angles_filtered[indexesmax1], 'ks')
    plt.show()
    
    # Plot 2
    plt.figure(figsize=(10,4))
    plt.scatter(np.arange(trunk_knee_angles.shape[0]), trunk_knee_angles, alpha=0.5)
    plt.scatter(np.arange(trunk_knee_angles_filtered.shape[0]), trunk_knee_angles_filtered, c='r', alpha=0.5)
    plt.title(video_name)
    plt.xlabel('Frames')
    plt.ylabel('Angle between Trunk and Knee')
    # Set range on y-axis so the plots are consistent
    plt.ylim(0,360)
    
    # Annontate maxima points
    plt.plot(indexesmax2, trunk_knee_angles_filtered[indexesmax2], 'ks')
    plt.show()

    # Plot 3
    plt.figure(figsize=(10,4))
    plt.scatter(np.arange(upArm_forearm_angles.shape[0]), upArm_forearm_angles, alpha=0.5)
    plt.scatter(np.arange(upArm_forearm_angles_filtered.shape[0]), upArm_forearm_angles_filtered, c='r', alpha=0.5)
    plt.title(video_name)
    plt.xlabel('Frames')
    plt.ylabel('Angle between Upper Arm and Forearm')
    # Set range on y-axis so the plots are consistent
    plt.ylim(0,220) 
    
    # Annotate minima apoints on the graph   
    max_points = upArm_forearm_angles_filtered[indexesmax3]
    min_points = upArm_forearm_angles_filtered[indexesmin]
    plt.plot(indexesmin, min_points, 'bo')
    plt.plot(indexesmax3, max_points, 'ks')

    """
        # Annotate local maximas
        for maxp, indx in zip(max_points, indexesmax3):
            plt.annotate('local max', xy=(indx, maxp), xytext=(indx, maxp+25),
                    arrowprops=dict(facecolor='black', shrink=0.05))

        # Annotate local minimas
        for minp, indx in zip(min_points, indexesmin):
            plt.annotate('local min', xy=(indx, minp), xytext=(indx, minp-35),
                    arrowprops=dict(facecolor='black', shrink=0.05))     
    """
    plt.show()

    # Plot 4
    plt.figure(figsize=(10,4))
    plt.scatter(np.arange(upArm_forearm_angles_filtered.shape[0]), upArm_forearm_angles_filtered, c='r', alpha=0.5)
    plt.scatter(np.arange(upArm_trunk_angles_filtered.shape[0]), upArm_trunk_angles_filtered, c='r', alpha=0.5)
    plt.scatter(np.arange(trunk_knee_angles_filtered.shape[0]), trunk_knee_angles_filtered, c='r', alpha=0.5)
    plt.title(video_name)
    plt.xlabel('Frames')
    plt.ylabel('Whole body movement')
    # Set range on y-axis so the plots are consistent
    plt.ylim(0,250) 
    # Annotate minima apoints      
    plt.plot(indexesmin, upArm_forearm_angles_filtered[indexesmin], 'bo')
    plt.plot(indexesmax1, upArm_trunk_angles_filtered[indexesmax1], 'ks')
    plt.plot(indexesmax2, trunk_knee_angles_filtered[indexesmax2], 'ks')
    plt.plot(indexesmax3, upArm_forearm_angles_filtered[indexesmax3], 'ks')
    
    plt.show()
   
    
    # Each rep analysis
    # local minimums for upper arm and forearm are min angles in each rep
    analyse_each_rep(string='analysis', extremas1=upArm_forearm_minimas, uf_angles1a=upArm_forearm_angles_filtered, ut_angles2a=upArm_trunk_angles_filtered, tk_angles3a=trunk_knee_angles_filtered)

    print('\n' + '='*120 + '\n')
# Out:
# Starting...
# Keypoints from folder: triceps_pushdown_incorrect_1
# Right side: 0
# Left  side: 183
# Detected arm: left
# extremas: [25.86483564 21.04210461 21.40289475 20.17611999 14.5523401  18.52409341
#  17.95393689 19.25277722 18.05503392 16.89205507 16.7794456  14.37211745]
# angle change threshold: 22.068680522712718
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [165.92248662 165.00542288 164.97692597 163.99317188 166.50426818
#  164.00815866 165.6177042  166.84659667]
# angle change threshold: 21.396422652223936
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [153.33137924 130.12276227 151.26940125 136.33506073 139.19623145
#  145.19936435]
# angle change threshold: 33.63078001657552
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [84.46776063 89.57966422 85.22168641 82.54239057 83.92771317]
# angle change threshold: 23.38362496136205
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 5
# ------------------------------------------------------------------------------------------
# Number of reps performed: 6
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 84.46776063244774
# Maximum angle between upper arm and trunk: 25.864835635864125
# Minimum angle between trunk and knee: 164.04514871685663
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 84.46776063244774
# Maximum angle between upper arm and trunk: 21.402894753351113
# Minimum angle between trunk and knee: 163.05256293951692
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 85.22168640778168
# Maximum angle between upper arm and trunk: 20.17611998585237
# Minimum angle between trunk and knee: 163.1100652926142
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 82.54239056727967
# Maximum angle between upper arm and trunk: 18.524093409708442
# Minimum angle between trunk and knee: 162.5033661850851
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 82.54239056727967
# Maximum angle between upper arm and trunk: 19.252777215402066
# Minimum angle between trunk and knee: 163.4662832765177
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 78.99328195577982
# Maximum angle between upper arm and trunk: 18.055033923899686
# Minimum angle between trunk and knee: 162.90135893778694
#
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_incorrect_10
# Right side: 0
# Left  side: 183
# Detected arm: left
# extremas: [30.66820077 36.65853378 29.01950436 34.16683651 26.87064434 28.15177076
#  27.56068651  4.13970149]
# angle change threshold: 27.338011776518474
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [157.51217827 154.32077528 158.93459143 167.13082888 173.48298705
#  174.37599881]
# angle change threshold: 24.649325304236317
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [165.2845214  164.59559731 164.08560294 175.19103609]
# angle change threshold: 24.10145054056134
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [ 72.05724552  69.27203868  67.8043892  104.71548706]
# angle change threshold: 33.721318061396005
#
#
# Testing to filter by average angle change....
# Testing Finished
# Filtering by average angle change...
# extrema array size: 4
# angles removed: [104.71548705875716]
#
# New extrema array: [72.05724552 69.27203868 67.8043892 ]
# new size: 3
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 3
# ------------------------------------------------------------------------------------------
# Number of reps performed: 4
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 72.05724552298747
# Maximum angle between upper arm and trunk: 36.6585337753671
# Minimum angle between trunk and knee: 147.00795416200745
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 69.272038677914
# Maximum angle between upper arm and trunk: 34.488033058522845
# Minimum angle between trunk and knee: 150.47778842729477
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 67.80438919877831
# Maximum angle between upper arm and trunk: 29.95274668883566
# Minimum angle between trunk and knee: 153.2048403631277
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 67.80438919877831
# Maximum angle between upper arm and trunk: 28.15177075649278
# Minimum angle between trunk and knee: 163.88394131332078
#
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_incorrect_2
# Right side: 0
# Left  side: 200
# Detected arm: left
# extremas: [17.65503273 14.96290527 13.34297728 17.48131776 14.28705292 14.32398818
#  13.19937409 16.0115807  16.27987418 14.73062993 12.99811652]
# angle change threshold: 21.916846788127962
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [165.94763669 164.11074514 165.86090062 164.92282254 166.35368226
#  166.74329136 163.47023521 165.05482899 166.5931246  163.51486837
#  165.08957905]
# angle change threshold: 21.73945063674381
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [141.0590351  147.35104806 143.73153281 145.92168803 149.64642048
#  145.58492987]
# angle change threshold: 23.97758129705779
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [79.37942971 84.33888437 91.75135176 86.17207013 82.86784634]
# angle change threshold: 25.31385686652079
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 5
# ------------------------------------------------------------------------------------------
# Number of reps performed: 6
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 79.37942971291905
# Maximum angle between upper arm and trunk: 17.655032728051797
# Minimum angle between trunk and knee: 160.1538065875256
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 79.37942971291905
# Maximum angle between upper arm and trunk: 17.481317764603833
# Minimum angle between trunk and knee: 162.9715536223909
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 84.33888437214766
# Maximum angle between upper arm and trunk: 14.323988181794656
# Minimum angle between trunk and knee: 163.86592302142114
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 86.17207012812307
# Maximum angle between upper arm and trunk: 16.01158070233196
# Minimum angle between trunk and knee: 163.70557900247476
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 82.86784634483513
# Maximum angle between upper arm and trunk: 16.279874175154077
# Minimum angle between trunk and knee: 161.16227593629532
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 82.86784634483513
# Maximum angle between upper arm and trunk: 16.406385616819303
# Minimum angle between trunk and knee: 160.62911293594422
#
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_incorrect_3
# Right side: 0
# Left  side: 224
# Detected arm: left
# extremas: [16.91100516 16.34573506 12.5488853  16.25343392 15.84676243 16.27862096
#  16.08035861 14.62750703 13.46850641 13.80018271 13.36656085 14.8413172
#   9.74460489 11.48541533]
# angle change threshold: 21.599453100154452
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [165.58297816 165.18565239 163.36711231 165.68754702 165.21955966
#  168.16946804 164.3924619  166.98038797 164.46922421 166.94928337
#  165.77291527 166.5267239 ]
# angle change threshold: 21.93095710546649
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [145.3148331  143.49854309 147.09831689 142.03901685 142.33313869
#  141.13465224 138.39410045]
# angle change threshold: 22.451420654461714
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [83.13686941 86.1944383  81.56816445 79.84915662 83.97437476 83.65141407]
# angle change threshold: 22.770205878667305
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 6
# ------------------------------------------------------------------------------------------
# Number of reps performed: 7
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 83.13686941004875
# Maximum angle between upper arm and trunk: 16.911005158740412
# Minimum angle between trunk and knee: 163.9291896940562
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 83.13686941004875
# Maximum angle between upper arm and trunk: 16.25343392142913
# Minimum angle between trunk and knee: 162.90978113480423
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 81.5681644535514
# Maximum angle between upper arm and trunk: 16.27862096037552
# Minimum angle between trunk and knee: 161.7350309799225
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 79.84915661671435
# Maximum angle between upper arm and trunk: 14.627507032377368
# Minimum angle between trunk and knee: 162.84411640767775
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 79.84915661671435
# Maximum angle between upper arm and trunk: 13.800182709539484
# Minimum angle between trunk and knee: 163.37101882901584
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 83.6514140721532
# Maximum angle between upper arm and trunk: 14.84131719938467
# Minimum angle between trunk and knee: 163.12049527593467
#
# Repetition: 7
#
# Minimum angle between upper arm and forearm: 79.28212622293256
# Maximum angle between upper arm and trunk: 11.485415329625358
# Minimum angle between trunk and knee: 163.00619316572278
#
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_incorrect_4
# Right side: 0
# Left  side: 198
# Detected arm: left
# extremas: [12.01016913 11.26541123 13.72065628 14.49053033 10.47206865 12.71613779
#  12.49541671 11.03226157 13.4286826  12.43112463 11.64343641]
# angle change threshold: 21.609795124302668
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [166.24842024 167.90285634 165.82568869 165.88171653 167.40113819
#  164.60283503 167.30331282 166.78757982 166.78070915]
# angle change threshold: 21.41605473431249
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [149.00375255 140.24809261 139.35104728 138.58003436 143.18317923
#  140.72708856]
# angle change threshold: 23.496590748042582
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [83.29471448 87.63819151 74.83171925 79.40538336 83.29396674 84.21994832]
# angle change threshold: 25.307635673538318
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 6
# ------------------------------------------------------------------------------------------
# Number of reps performed: 7
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 83.29471447652189
# Maximum angle between upper arm and trunk: 12.010169129056864
# Minimum angle between trunk and knee: 163.02902791703897
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 83.29471447652189
# Maximum angle between upper arm and trunk: 13.72065627734634
# Minimum angle between trunk and knee: 163.1967453053405
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 74.83171925342366
# Maximum angle between upper arm and trunk: 14.490530331781315
# Minimum angle between trunk and knee: 164.7414757258027
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 74.83171925342366
# Maximum angle between upper arm and trunk: 12.716137786547671
# Minimum angle between trunk and knee: 164.25928332474234
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 79.40538336194875
# Maximum angle between upper arm and trunk: 12.495416714248892
# Minimum angle between trunk and knee: 163.69073982005511
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 83.29396673599732
# Maximum angle between upper arm and trunk: 13.428682601758693
# Minimum angle between trunk and knee: 165.38740837691162
#
# Repetition: 7
#
# Minimum angle between upper arm and forearm: 84.21994832499935
# Maximum angle between upper arm and trunk: 12.018964675062602
# Minimum angle between trunk and knee: 164.01626862153034
#
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_incorrect_5
# Right side: 0
# Left  side: 360
# Detected arm: left
# extremas: [12.77854609 13.31235201 10.59595752 14.49171727  7.92756137 13.87888739
#  12.68956684 11.56718473 10.39842522 10.14788174 11.28269841 13.92818597
#  13.91093998 12.93343295 13.35179516 11.68201206 12.97338108 14.76565822
#  12.37131836 11.46023179]
# angle change threshold: 21.92866962517401
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [166.68883848 166.5613078  165.82699985 165.84421203 165.44816205
#  165.08057591 165.48113368 167.13979397 166.51539364 167.03157262
#  166.09622831 165.80609684 167.45774789 167.88133724 167.58737013
#  168.13823635 167.95554357]
# angle change threshold: 20.57317041298163
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [146.08396348 139.49810248 144.59181488 142.23444088 139.24798949
#  137.28707414 141.67543102 142.62661494 137.48873712 133.19876957
#  143.87321202 135.44428187]
# angle change threshold: 24.8050066292621
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [80.56787957 82.7717938  80.29147472 77.57995714 76.99617587 74.70304892
#  80.44090309 73.02701861 72.62362026 70.30546051 77.19514781]
# angle change threshold: 23.303564316213787
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 11
# ------------------------------------------------------------------------------------------
# Number of reps performed: 12
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 80.56787956772516
# Maximum angle between upper arm and trunk: 12.77854608814707
# Minimum angle between trunk and knee: 165.03329424004858
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 80.56787956772516
# Maximum angle between upper arm and trunk: 13.312352009082993
# Minimum angle between trunk and knee: 164.34201776139253
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 80.2914747217089
# Maximum angle between upper arm and trunk: 14.491717265752822
# Minimum angle between trunk and knee: 162.34109700478913
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 77.57995714005284
# Maximum angle between upper arm and trunk: 13.8788873927844
# Minimum angle between trunk and knee: 162.42279229037675
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 76.99617586637687
# Maximum angle between upper arm and trunk: 12.689566836013636
# Minimum angle between trunk and knee: 163.27102592063798
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 74.70304892053346
# Maximum angle between upper arm and trunk: 11.567184731016383
# Minimum angle between trunk and knee: 163.97787265524255
#
# Repetition: 7
#
# Minimum angle between upper arm and forearm: 74.70304892053346
# Maximum angle between upper arm and trunk: 10.147881738020079
# Minimum angle between trunk and knee: 164.53404520180823
#
# Repetition: 8
#
# Minimum angle between upper arm and forearm: 73.0270186132684
# Maximum angle between upper arm and trunk: 13.928185969242962
# Minimum angle between trunk and knee: 163.23209298013683
#
# Repetition: 9
#
# Minimum angle between upper arm and forearm: 72.62362025984214
# Maximum angle between upper arm and trunk: 13.910939984754611
# Minimum angle between trunk and knee: 164.48690457007407
#
# Repetition: 10
#
# Minimum angle between upper arm and forearm: 70.30546051432545
# Maximum angle between upper arm and trunk: 13.351795159245171
# Minimum angle between trunk and knee: 162.0316289461431
#
# Repetition: 11
#
# Minimum angle between upper arm and forearm: 70.30546051432545
# Maximum angle between upper arm and trunk: 14.765658215721949
# Minimum angle between trunk and knee: 161.10392259073285
#
# Repetition: 12
#
# Minimum angle between upper arm and forearm: 70.2958809468343
# Maximum angle between upper arm and trunk: 12.371318361256854
# Minimum angle between trunk and knee: 163.76103259375938
#
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_incorrect_6
# Right side: 0
# Left  side: 350
# Detected arm: left
# extremas: [11.25163915 13.28858094 10.77819787 12.95775403 13.72657412 12.01777747
#  11.54160464 13.94965856 11.01707292 10.76509009 12.83756603 11.63215277
#  10.22958718 11.75903214 11.23899292 13.96431699 13.09899972 10.01066678
#  14.18025894 13.54759739 13.09484614  9.58110461  9.28815612 12.08255751]
# angle change threshold: 21.762534894580465
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [166.84287088 166.50331725 166.49693479 166.02492538 167.63711582
#  166.91582826 165.29114397 166.88619369 165.85196059 166.83715287
#  165.89525502 165.97485749 165.89458757 164.85007626 165.15677793
#  166.41361139 165.96073819 165.62965614 164.78470861 165.89693527
#  167.64048204]
# angle change threshold: 20.829253788808547
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [133.72206502 136.07048007 137.77738462 137.93898228 139.81058341
#  137.82413478 135.35801005 137.56752541 135.27532382 136.43871896
#  131.3062068  133.79225964]
# angle change threshold: 22.16588807511893
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [76.59501848 69.98871464 70.86848901 74.58567281 75.17266011 74.61005746
#  73.80794391 69.92113028 75.15399942 72.40485833 73.09221521]
# angle change threshold: 22.571114624327713
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 11
# ------------------------------------------------------------------------------------------
# Number of reps performed: 12
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 76.5950184758342
# Maximum angle between upper arm and trunk: 13.173833923517407
# Minimum angle between trunk and knee: 164.7490806346513
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 69.98871463759119
# Maximum angle between upper arm and trunk: 13.288580938903223
# Minimum angle between trunk and knee: 163.70537841997307
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 69.98871463759119
# Maximum angle between upper arm and trunk: 13.726574119330651
# Minimum angle between trunk and knee: 165.79318958292743
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 70.86848900992821
# Maximum angle between upper arm and trunk: 13.726574119330651
# Minimum angle between trunk and knee: 164.1877976338538
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 74.58567280948238
# Maximum angle between upper arm and trunk: 13.949658555745081
# Minimum angle between trunk and knee: 164.32876583567497
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 74.61005746463456
# Maximum angle between upper arm and trunk: 12.837566026383904
# Minimum angle between trunk and knee: 163.5138887469256
#
# Repetition: 7
#
# Minimum angle between upper arm and forearm: 73.80794391188576
# Maximum angle between upper arm and trunk: 13.96431698799783
# Minimum angle between trunk and knee: 163.64097727312966
#
# Repetition: 8
#
# Minimum angle between upper arm and forearm: 69.92113028455277
# Maximum angle between upper arm and trunk: 13.96431698799783
# Minimum angle between trunk and knee: 164.69473468558715
#
# Repetition: 9
#
# Minimum angle between upper arm and forearm: 69.92113028455277
# Maximum angle between upper arm and trunk: 14.180258936749984
# Minimum angle between trunk and knee: 163.42060618193946
#
# Repetition: 10
#
# Minimum angle between upper arm and forearm: 72.40485832668874
# Maximum angle between upper arm and trunk: 14.180258936749984
# Minimum angle between trunk and knee: 164.7915261387893
#
# Repetition: 11
#
# Minimum angle between upper arm and forearm: 72.40485832668874
# Maximum angle between upper arm and trunk: 13.094846142411859
# Minimum angle between trunk and knee: 164.19939915178662
#
# Repetition: 12
#
# Minimum angle between upper arm and forearm: 73.09221520619201
# Maximum angle between upper arm and trunk: 12.082557513471167
# Minimum angle between trunk and knee: 164.3121369509184
#
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_incorrect_7
# Right side: 0
# Left  side: 293
# Detected arm: left
# extremas: [51.58890556 24.53187206 51.60390678 42.83046917 22.81415232 47.86335993
#  18.76070054 19.16483689 20.86581249 43.54965853]
# angle change threshold: 37.98440529220609
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [34, 19, 57, 35, 25, 23, 8, 5, 20]
# threshold: 21
# counts less than threshold: [19, 8, 5, 20]
# Array filtering: Done
# extremas: [178.46259711 176.62975707 177.09100175 178.8069613 ]
# angle change threshold: 21.33668142486174
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [175.67271201 172.04287778 173.53532532 178.11767286 165.51164521]
# angle change threshold: 25.577664243581296
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [78.96877202 74.77754564 71.48033863 71.36115207]
# angle change threshold: 22.535873317238494
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 4
# ------------------------------------------------------------------------------------------
# Number of reps performed: 5
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 78.96877202130557
# Maximum angle between upper arm and trunk: 51.58890555614554
# Minimum angle between trunk and knee: 111.63663575388965
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 74.77754563930716
# Maximum angle between upper arm and trunk: 51.60390677604522
# Minimum angle between trunk and knee: 114.70646369233772
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 71.48033863432671
# Maximum angle between upper arm and trunk: 42.830469171219264
# Minimum angle between trunk and knee: 118.96158592474832
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 71.36115206959009
# Maximum angle between upper arm and trunk: 47.863359928241266
# Minimum angle between trunk and knee: 114.64988832166645
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 70.126871003376
# Maximum angle between upper arm and trunk: 43.549658528820366
# Minimum angle between trunk and knee: 106.82254935700982
#
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_incorrect_8
# Right side: 46
# Left  side: 450
# Detected arm: left
# extremas: [21.72137649 47.41024685 18.78428136 48.63443267 54.34150086 23.21532469
#  50.9432006  47.74102    32.50140031 48.48558423 25.25101363 28.35229751
#  54.37685496]
# angle change threshold: 39.626041964273796
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [24, 32, 29, 69, 31, 31, 60, 38, 29, 27, 9, 25]
# threshold: 28
# counts less than threshold: [24, 27, 9, 25]
# Array filtering: Done
# extremas: [172.47075464 177.3216661  171.59279043 178.11714858 173.76475095
#  164.25467225]
# angle change threshold: 26.1933243215664
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [172.50177408 176.72947856 172.13141408 169.39418206 166.64733208
#  178.18106084 167.81656841]
# angle change threshold: 26.034678694330136
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [77.43533495 73.4769013  71.19741429 66.15783915 74.72121865 70.79027936]
# angle change threshold: 24.754362918465596
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 6
# ------------------------------------------------------------------------------------------
# Number of reps performed: 7
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 69.8511023792309
# Maximum angle between upper arm and trunk: 47.41024684588303
# Minimum angle between trunk and knee: 115.93583082932415
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 73.476901297422
# Maximum angle between upper arm and trunk: 48.63443267215703
# Minimum angle between trunk and knee: 117.84564998686307
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 71.1974142937485
# Maximum angle between upper arm and trunk: 54.3415008623092
# Minimum angle between trunk and knee: 111.96777533462217
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 66.15783914947201
# Maximum angle between upper arm and trunk: 50.94320060172021
# Minimum angle between trunk and knee: 103.359354888469
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 66.15783914947201
# Maximum angle between upper arm and trunk: 47.74101999762764
# Minimum angle between trunk and knee: 111.38772512409128
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 70.79027935527837
# Maximum angle between upper arm and trunk: 48.485584228224035
# Minimum angle between trunk and knee: 113.52144517799962
#
# Repetition: 7
#
# Minimum angle between upper arm and forearm: 70.79027935527837
# Maximum angle between upper arm and trunk: 54.37685496453951
# Minimum angle between trunk and knee: 104.21154894096406
#
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_incorrect_9
# Right side: 0
# Left  side: 491
# Detected arm: left
# extremas: [69.46848921 30.08551098 52.13945071 59.64081333 30.05501458 48.82410724
#  46.39793414 31.91921552 45.10833872 22.43286781 32.88029408 24.86898348
#  41.27730434 41.17381657 36.26875886 38.63412468 37.97344767 41.90981673
#  42.06651003 39.75827349 44.44441131]
# angle change threshold: 31.20258702824544
#
#
# Testing to filter by average angle change....
# Testing Finished
# Filtering by average angle change...
# extrema array size: 21
# angles removed: [30.085510976065656]
#
# New extrema array: [69.46848921 52.13945071 59.64081333 30.05501458 48.82410724 46.39793414
#  31.91921552 45.10833872 22.43286781 32.88029408 24.86898348 41.27730434
#  41.17381657 36.26875886 38.63412468 37.97344767 41.90981673 42.06651003
#  39.75827349 44.44441131]
# new size: 20
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [151.5327776  160.59275162 152.63496132 157.59680841 162.34749218
#  158.76574365 163.06899815 161.31419032 160.62979582 158.54425428
#  158.81601906 158.81559269 158.61962856 165.03247313 161.4986712
#  157.34470751 159.70868553 162.43967379 167.09984979 162.70958439]
# angle change threshold: 23.571274485554483
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [38, 20, 8, 12, 12, 30, 52, 39, 49, 4, 31, 7, 38, 16, 12, 25, 19, 33, 18]
# threshold: 31
# counts less than threshold: [20, 8, 12, 12, 30, 4, 7, 16, 12, 25, 19, 18]
# Array filtering: Done
# extremas: [175.92259704 175.38943948 175.56767533 174.90505716 168.13311672
#  171.27396465 161.27025985 142.06341135 122.39119639 136.57626349
#  128.61327803 137.79235405 139.18329897]
# angle change threshold: 27.740636809496667
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [54.7787234  61.44109931 47.50781991 54.69744483 67.11579443 72.62376221
#  72.42338195 76.9083835  70.95339674 80.31011711 82.50533098 95.8915983 ]
# angle change threshold: 27.390015249070757
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 12
# ------------------------------------------------------------------------------------------
# Number of reps performed: 13
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 54.77872339914643
# Maximum angle between upper arm and trunk: 69.46848921485925
# Minimum angle between trunk and knee: 134.0512070220865
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 54.77872339914643
# Maximum angle between upper arm and trunk: 52.1394507118198
# Minimum angle between trunk and knee: 150.21503296868303
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 47.50781990538444
# Maximum angle between upper arm and trunk: 59.64081332728357
# Minimum angle between trunk and knee: 157.07980956777868
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 47.50781990538444
# Maximum angle between upper arm and trunk: 48.824107240494115
# Minimum angle between trunk and knee: 153.508562249393
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 54.69744483020296
# Maximum angle between upper arm and trunk: 46.39793414009085
# Minimum angle between trunk and knee: 156.28581990297374
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 67.11579443279636
# Maximum angle between upper arm and trunk: 45.1083387210066
# Minimum angle between trunk and knee: 153.66741437616838
#
# Repetition: 7
#
# Minimum angle between upper arm and forearm: 72.42338194502564
# Maximum angle between upper arm and trunk: 32.880294075052
# Minimum angle between trunk and knee: 152.56379910220477
#
# Repetition: 8
#
# Minimum angle between upper arm and forearm: 72.42338194502564
# Maximum angle between upper arm and trunk: 26.59150511914453
# Minimum angle between trunk and knee: 156.16715253515915
#
# Repetition: 9
#
# Minimum angle between upper arm and forearm: 70.95339674429367
# Maximum angle between upper arm and trunk: 41.27730433631633
# Minimum angle between trunk and knee: 154.5534526422082
#
# Repetition: 10
#
# Minimum angle between upper arm and forearm: 70.95339674429367
# Maximum angle between upper arm and trunk: 41.17381656658756
# Minimum angle between trunk and knee: 154.7924694436174
#
# Repetition: 11
#
# Minimum angle between upper arm and forearm: 80.31011711459023
# Maximum angle between upper arm and trunk: 38.63412468127322
# Minimum angle between trunk and knee: 155.380300074655
#
# Repetition: 12
#
# Minimum angle between upper arm and forearm: 82.50533098079866
# Maximum angle between upper arm and trunk: 42.06651003354248
# Minimum angle between trunk and knee: 157.9887130357583
#
# Repetition: 13
#
# Minimum angle between upper arm and forearm: 95.89159829910267
# Maximum angle between upper arm and trunk: 44.44441131232929
# Minimum angle between trunk and knee: 155.91616325168442
#
# ========================================================================================================================

# %%
a = [1,2,3]
a[-1:]
print(a)
# Out:
# [1, 2, 3]

# %%
from Parser import parse_frames
from scipy.signal import medfilt
from Functions import find_extremas, filter_extremas, detect_side, analyse_each_rep
from JointAngles import JointAngles
import numpy as np
import math
import glob
import os
import itertools
import pickle
import matplotlib.pyplot as plt

# %%
# modify this path for other videos 
# input_folder = "/home/aleko/Documents/Projects/IndividualProject/bicepvid"
input_folder = "C:\\Users\\altaok\\Documents\\GitHub\\IndividualProject\\keypoints_for_all\\triceps pushdown"

# input_folder = 'C:\\Users\\ak5u16\\Desktop\\openpose\\keypoints_for_all\\bicep_curl'
folder_paths = glob.glob(os.path.join(input_folder, 'triceps_pushdown_correct*'))     

for folder in folder_paths:
    print("Starting..." + "\nKeypoints from folder: " + os.path.basename(folder))
    video_name = os.path.basename(folder).replace('output_points_', '')
    frame_poses = parse_frames(folder)
    
    joint_angles = JointAngles('triceps pushdown', frame_poses)
    print('Detected arm: ' + joint_angles.side)

    upArm_trunk_angles = np.array(joint_angles.upArm_trunk_angles)
    upArm_trunk_angles_filtered = medfilt(medfilt(upArm_trunk_angles, 5), 5)
    
   
    upArm_forearm_angles = np.array(joint_angles.upArm_forearm_angles)
    upArm_forearm_angles_filtered = medfilt(medfilt(upArm_forearm_angles, 5), 5)
    
    trunk_knee_angles = np.array(joint_angles.trunk_knee_angles)
    trunk_knee_angles_filtered = medfilt(medfilt(trunk_knee_angles, 5), 5)
    
    # Find upper arm and trunk maximum angles to detect wrong form 
    upArm_trunk_maximas = find_extremas(upArm_trunk_angles_filtered)
    upArm_trunk_maximas = filter_extremas(upArm_trunk_angles_filtered, upArm_trunk_maximas)
    indexesmax1 = np.array([np.argwhere(upArm_trunk_angles_filtered == maxima)[0][0] for maxima in upArm_trunk_maximas])
    # print("Largest angles between upper arm and trunk: " + str(upArm_trunk_maximas))

    # Find trunk and knee maximum angles to detect wrong form 
    trunk_knee_maximas = find_extremas(trunk_knee_angles_filtered)
    trunk_knee_maximas = filter_extremas(trunk_knee_angles_filtered, trunk_knee_maximas)
    indexesmax2 = np.array([np.argwhere(trunk_knee_angles_filtered == maxima)[0][0] for maxima in trunk_knee_maximas])
   
    # print("Largest angles between trunk and knee: " + str(trunk_knee_maximas))

    # Count repetitions
    upArm_forearm_maximas = find_extremas(upArm_forearm_angles_filtered)  
    upArm_forearm_maximas = filter_extremas(upArm_forearm_angles_filtered, upArm_forearm_maximas)
    indexesmax3 = np.array([np.argwhere(upArm_forearm_angles_filtered == maxima)[0][0] for maxima in upArm_forearm_maximas])
   
    # print("Number of maxima points between Upper Arm and Forearm: " + str(upArm_forearm_maximas.size))
    # print(upArm_forearm_maximas)
    
    # Find upper arm and forearm minimum points to count reps 
    upArm_forearm_minimas = find_extremas(upArm_forearm_angles_filtered, maxima=False)
    print('\n----------------------------Filtering minimas-------------------------------------')
    upArm_forearm_minimas = filter_extremas(upArm_forearm_angles_filtered, upArm_forearm_minimas, maxima=False)
    indexesmin = np.array([np.argwhere(upArm_forearm_angles_filtered == minima)[0][0] for minima in upArm_forearm_minimas])
    print("\nSize of minima array: " + str(upArm_forearm_minimas.size))
    print('-'*90)
    
   
    # Plot 1
    plt.figure(figsize=(10,4))
    plt.scatter(np.arange(upArm_trunk_angles.shape[0]), upArm_trunk_angles, alpha=0.5)
    plt.scatter(np.arange(upArm_trunk_angles_filtered.shape[0]), upArm_trunk_angles_filtered, c='r', alpha=0.5)
    plt.title(video_name)
    plt.xlabel('Frames')
    plt.ylabel('Angle between Upper Arm and Trunk')
    # Set range on y-axis so the plots are consistent
    plt.ylim(0,90)
    
    # Annontate maxima points
    plt.plot(indexesmax1, upArm_trunk_angles_filtered[indexesmax1], 'ks')
    plt.show()
    
    # Plot 2
    plt.figure(figsize=(10,4))
    plt.scatter(np.arange(trunk_knee_angles.shape[0]), trunk_knee_angles, alpha=0.5)
    plt.scatter(np.arange(trunk_knee_angles_filtered.shape[0]), trunk_knee_angles_filtered, c='r', alpha=0.5)
    plt.title(video_name)
    plt.xlabel('Frames')
    plt.ylabel('Angle between Trunk and Knee')
    # Set range on y-axis so the plots are consistent
    plt.ylim(0,360)
    
    # Annontate maxima points
    plt.plot(indexesmax2, trunk_knee_angles_filtered[indexesmax2], 'ks')
    plt.show()

    # Plot 3
    plt.figure(figsize=(10,4))
    plt.scatter(np.arange(upArm_forearm_angles.shape[0]), upArm_forearm_angles, alpha=0.5)
    plt.scatter(np.arange(upArm_forearm_angles_filtered.shape[0]), upArm_forearm_angles_filtered, c='r', alpha=0.5)
    plt.title(video_name)
    plt.xlabel('Frames')
    plt.ylabel('Angle between Upper Arm and Forearm')
    # Set range on y-axis so the plots are consistent
    plt.ylim(0,220) 
    
    # Annotate minima apoints on the graph   
    max_points = upArm_forearm_angles_filtered[indexesmax3]
    min_points = upArm_forearm_angles_filtered[indexesmin]
    plt.plot(indexesmin, min_points, 'bo')
    plt.plot(indexesmax3, max_points, 'ks')

    """
        # Annotate local maximas
        for maxp, indx in zip(max_points, indexesmax3):
            plt.annotate('local max', xy=(indx, maxp), xytext=(indx, maxp+25),
                    arrowprops=dict(facecolor='black', shrink=0.05))

        # Annotate local minimas
        for minp, indx in zip(min_points, indexesmin):
            plt.annotate('local min', xy=(indx, minp), xytext=(indx, minp-35),
                    arrowprops=dict(facecolor='black', shrink=0.05))     
    """
    plt.show()

    # Plot 4
    plt.figure(figsize=(10,4))
    plt.scatter(np.arange(upArm_forearm_angles_filtered.shape[0]), upArm_forearm_angles_filtered, c='r', alpha=0.5)
    plt.scatter(np.arange(upArm_trunk_angles_filtered.shape[0]), upArm_trunk_angles_filtered, c='r', alpha=0.5)
    plt.scatter(np.arange(trunk_knee_angles_filtered.shape[0]), trunk_knee_angles_filtered, c='r', alpha=0.5)
    plt.title(video_name)
    plt.xlabel('Frames')
    plt.ylabel('Whole body movement')
    # Set range on y-axis so the plots are consistent
    plt.ylim(0,250) 
    # Annotate minima apoints      
    plt.plot(indexesmin, upArm_forearm_angles_filtered[indexesmin], 'bo')
    plt.plot(indexesmax1, upArm_trunk_angles_filtered[indexesmax1], 'ks')
    plt.plot(indexesmax2, trunk_knee_angles_filtered[indexesmax2], 'ks')
    plt.plot(indexesmax3, upArm_forearm_angles_filtered[indexesmax3], 'ks')
    
    plt.show()
   
    
    # Each rep analysis
    # local minimums for upper arm and forearm are min angles in each rep
    analyse_each_rep(string='analysis', extremas1=upArm_forearm_minimas, uf_angles1a=upArm_forearm_angles_filtered, ut_angles2a=upArm_trunk_angles_filtered, tk_angles3a=trunk_knee_angles_filtered)

    print('\n' + '='*120 + '\n')
# Out:
# Starting...
# Keypoints from folder: triceps_pushdown_correct_1
# Right side: 207
# Left  side: 37
# Detected arm: right
# extremas: [12.43867326  9.9830052   9.81206704 12.41609147 15.30177029 16.10361323
#  18.55593146 15.97133055 16.16912034 19.14147254 15.38637182 18.39494251]
# angle change threshold: 22.171716813053184
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [14, 7, 25, 16, 15, 25, 10, 7, 12, 18, 17]
# threshold: 18
# counts less than threshold: [14, 7, 16, 15, 10, 7, 12, 17]
# Array filtering: Done
# extremas: [178.37707168 178.04306993 179.3661192  179.53190132 177.46912999
#  178.64765551 179.02272977 179.88786358 178.17919394 179.21354864
#  179.23252169 177.95995909 178.87504645 178.80010592 179.66913084]
# angle change threshold: 20.871282204822705
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [19, 14, 5, 19, 9, 11, 7, 14, 14, 6, 17, 8, 8, 19]
# threshold: 20
# counts less than threshold: [19, 14, 5, 19, 9, 11, 7, 14, 14, 6, 17, 8, 8, 19]
# Array filtering: Done
# extremas: [153.26495816 136.24058379 139.80074312 156.19766528 161.1367651
#  166.33138834 160.26529315]
# angle change threshold: 28.863545684745226
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [86.37535649 89.46710897 85.36540413 88.53253884 92.65135213 89.44920173]
# angle change threshold: 23.536311143340136
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 6
# ------------------------------------------------------------------------------------------
# Number of reps performed: 7
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 86.37535648550877
# Maximum angle between upper arm and trunk: 12.438673255332418
# Minimum angle between trunk and knee: 175.4137910512449
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 86.37535648550877
# Maximum angle between upper arm and trunk: 9.983005196857928
# Minimum angle between trunk and knee: 174.68446643459978
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 85.3654041302139
# Maximum angle between upper arm and trunk: 12.416091467297854
# Minimum angle between trunk and knee: 174.67209284354556
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 85.3654041302139
# Maximum angle between upper arm and trunk: 16.103613229953393
# Minimum angle between trunk and knee: 175.91012429000907
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 88.53253883529422
# Maximum angle between upper arm and trunk: 18.555931456087556
# Minimum angle between trunk and knee: 177.78836783059108
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 89.44920172799912
# Maximum angle between upper arm and trunk: 19.141472537678357
# Minimum angle between trunk and knee: 173.41537516416557
#
# Repetition: 7
#
# Minimum angle between upper arm and forearm: 79.38631363612107
# Maximum angle between upper arm and trunk: 18.394942505191146
# Minimum angle between trunk and knee: 174.55072685239583
#
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_10
# Right side: 626
# Left  side: 574
# Detected arm: right
# extremas: [ 9.58713809 10.22363135  6.06462815  8.05862551  4.20051104  4.1359256
#  12.44581204 11.0777212   5.57167416  3.06639638 15.10501889 13.76542352
#   2.93007082  2.05443004  9.50592072 12.68850028  7.735455    9.7991793
#  10.97166158 11.93873544  7.20560431  5.65448804  4.79936369 12.65842574
#  12.88903168  4.29289229  8.20551631 13.82237471  5.41707934  9.30791797
#  14.18396869  5.32101303 10.68344602 12.38705543]
# angle change threshold: 24.234452953549198
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [8, 14, 10, 11, 8, 21, 7, 19, 18, 28, 13, 17, 16, 24, 15, 12, 38, 7, 6, 8, 23, 12, 19, 5, 33, 16, 12, 36, 13, 15, 30, 33, 8]
# threshold: 41
# counts less than threshold: [8, 14, 10, 11, 8, 21, 7, 19, 18, 28, 13, 17, 16, 24, 15, 12, 38, 7, 6, 8, 23, 12, 19, 5, 33, 16, 12, 36, 13, 15, 30, 33, 8]
#
# Starting another stage of filtering...
#
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [25, 42, 75, 89, 66, 71, 63, 66, 73]
# threshold: 40
# counts less than threshold: [25]
# Array filtering: Done
# extremas: [168.0852382  168.20163706 170.6638157  168.13090497 167.80945314
#  166.94628002 169.05587011 169.18744509 165.17997392 168.94341728
#  163.49165279 166.94322697 169.95908423 169.59467007 167.44297758
#  169.39686224 169.98539721 167.80845351 162.6473401  168.29619779
#  165.75244686 164.1515498  165.79190532 168.5948054  166.9059926
#  166.24597669 168.64349045 169.79296862 167.57230266 167.78074533
#  165.81963798 166.1158045  171.94924486 171.14895512 167.91166785]
# angle change threshold: 22.21511629159699
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [18, 10, 16, 21, 16, 10, 14, 22, 9, 15, 10, 13, 7, 20, 35, 20, 26, 14, 27, 11, 14, 20, 21, 12, 16, 35, 22, 26, 6, 18, 10, 15, 9, 17]
# threshold: 42
# counts less than threshold: [18, 10, 16, 21, 16, 10, 14, 22, 9, 15, 10, 13, 7, 20, 35, 20, 26, 14, 27, 11, 14, 20, 21, 12, 16, 35, 22, 26, 6, 18, 10, 15, 9, 17]
#
# Starting another stage of filtering...
#
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [81, 32, 40, 85, 69, 69, 88, 33, 45]
# threshold: 39
# counts less than threshold: [32, 33]
# Array filtering: Done
# extremas: [177.35990748 178.80368264 179.08359916 179.93646779 178.69716273
#  176.27796145 175.30817974 175.05427401 177.07201752 177.91429185
#  178.34390317 175.9741471 ]
# angle change threshold: 21.192558120293675
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [74, 66, 7, 67, 9, 64, 7, 67, 69, 64, 73]
# threshold: 36
# counts less than threshold: [7, 9, 7]
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [ 80.07878886  83.37375974 179.0405454   81.26170809 173.64266081
#   86.45593861 172.61219149  85.45443928  83.03000824  83.02924037
#   81.79501   ]
# angle change threshold: 75.32817031392341
#
#
# Testing to filter by average angle change....
# Testing Finished
# Filtering by average angle change...
# extrema array size: 11
# angles removed: [179.04054539627109, 173.6426608096759, 172.61219149367622]
#
# New extrema array: [80.07878886 83.37375974 81.26170809 86.45593861 85.45443928 83.03000824
#  83.02924037 81.79501   ]
# new size: 8
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 8
# ------------------------------------------------------------------------------------------
# Number of reps performed: 9
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 77.76745786620461
# Maximum angle between upper arm and trunk: 10.223631350818803
# Minimum angle between trunk and knee: 164.89782978180276
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 80.07878885592906
# Maximum angle between upper arm and trunk: 12.44581204297958
# Minimum angle between trunk and knee: 160.6585000027334
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 81.26170808653703
# Maximum angle between upper arm and trunk: 15.105018890926637
# Minimum angle between trunk and knee: 160.90824161341192
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 81.26170808653703
# Maximum angle between upper arm and trunk: 12.688500283578016
# Minimum angle between trunk and knee: 161.2614038740343
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 85.45443928234417
# Maximum angle between upper arm and trunk: 11.938735440422192
# Minimum angle between trunk and knee: 160.08545194080975
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 83.03000824208098
# Maximum angle between upper arm and trunk: 12.88903167708721
# Minimum angle between trunk and knee: 158.0756068399156
#
# Repetition: 7
#
# Minimum angle between upper arm and forearm: 83.02924036833726
# Maximum angle between upper arm and trunk: 13.822374710431317
# Minimum angle between trunk and knee: 159.81395304782347
#
# Repetition: 8
#
# Minimum angle between upper arm and forearm: 81.79501000259758
# Maximum angle between upper arm and trunk: 14.183968688643862
# Minimum angle between trunk and knee: 158.67180798874452
#
# Repetition: 9
#
# Minimum angle between upper arm and forearm: 77.49729102804656
# Maximum angle between upper arm and trunk: 12.387055425447315
# Minimum angle between trunk and knee: 164.18418978571725
#
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_11
# Right side: 546
# Left  side: 10
# Detected arm: right
# extremas: [15.37750044  7.14327437  2.80295494 14.04390641  2.26067586 13.47361696
#   7.22477518 12.75269663  2.34638499 12.7480558  10.67584392  4.1097915
#   7.69540479 15.19629505  5.96367173 10.49100442 11.18725851  3.37726731
#   9.18651192 13.89438746  2.02642912 11.66842497  5.22324209  9.0461274
#   4.62963109]
# angle change threshold: 27.004125928015906
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [18, 13, 14, 34, 14, 15, 29, 25, 16, 15, 16, 11, 12, 25, 21, 52, 21, 18, 7, 32, 26, 28, 22, 12]
# threshold: 34
# counts less than threshold: [18, 13, 14, 14, 15, 29, 25, 16, 15, 16, 11, 12, 25, 21, 21, 18, 7, 32, 26, 28, 22, 12]
# Array filtering: Done
# extremas: [174.9976055  172.27998323 175.90924293 172.74080191 173.43005052
#  172.05815196 175.21652565 177.71824504 177.51022868 177.42455268
#  174.19091475 174.92732048 174.68616532 175.35214771 175.50712388
#  175.66201014 176.19213969 172.90345538 173.10433854 173.08331399
#  173.11176732 174.35796675 173.64216481 173.96653943 170.78210905
#  171.99289328 169.86110317 170.6621474  169.80013462 169.38497848
#  168.83380729 168.83894318 170.97372234 169.28058223 168.67609308]
# angle change threshold: 21.25490539782329
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [14, 25, 31, 16, 9, 38, 8, 13, 6, 14, 11, 12, 5, 9, 42, 19, 20, 9, 8, 21, 12, 18, 18, 11, 20, 7, 5, 13, 5, 9, 6, 17, 21, 11]
# threshold: 41
# counts less than threshold: [14, 25, 31, 16, 9, 38, 8, 13, 6, 14, 11, 12, 5, 9, 19, 20, 9, 8, 21, 12, 18, 18, 11, 20, 7, 5, 13, 5, 9, 6, 17, 21, 11]
#
# Starting another stage of filtering...
#
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [40, 48, 57, 47, 28, 62, 30, 43, 37, 32, 13, 54]
# threshold: 32
# counts less than threshold: [28, 30, 13]
# Array filtering: Done
# extremas: [176.64111324 179.2293365  178.83410056 177.78324305 173.92685354
#  175.00427387 178.97647264 176.54010986 176.6584419  176.07360798
#  171.12871119 162.97185471]
# angle change threshold: 22.652873394483777
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [9, 40, 48, 45, 43, 52, 50, 54, 48, 57, 56]
# threshold: 33
# counts less than threshold: [9]
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [173.51155982  83.9713891   74.16098562  77.996171    77.27829887
#   77.1063977   82.63039426  77.89983338  76.88432078  74.26502371
#   80.06154044]
# angle change threshold: 32.37614167024779
#
#
# Testing to filter by average angle change....
# Testing Finished
# Filtering by average angle change...
# extrema array size: 11
# angles removed: [173.5115598161966]
#
# New extrema array: [83.9713891  74.16098562 77.996171   77.27829887 77.1063977  82.63039426
#  77.89983338 76.88432078 74.26502371 80.06154044]
# new size: 10
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 10
# ------------------------------------------------------------------------------------------
# Number of reps performed: 11
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 83.9713891022581
# Maximum angle between upper arm and trunk: 15.377500436834788
# Minimum angle between trunk and knee: 169.05100426684947
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 74.16098562405122
# Maximum angle between upper arm and trunk: 14.043906410109782
# Minimum angle between trunk and knee: 167.4040140692613
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 74.16098562405122
# Maximum angle between upper arm and trunk: 13.473616958335578
# Minimum angle between trunk and knee: 167.79848937295466
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 77.27829886665072
# Maximum angle between upper arm and trunk: 12.752696625345697
# Minimum angle between trunk and knee: 174.00571289656932
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 77.10639769620346
# Maximum angle between upper arm and trunk: 12.748055797271451
# Minimum angle between trunk and knee: 171.95503690541082
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 77.10639769620346
# Maximum angle between upper arm and trunk: 15.196295048208995
# Minimum angle between trunk and knee: 168.75765005999847
#
# Repetition: 7
#
# Minimum angle between upper arm and forearm: 77.89983337991691
# Maximum angle between upper arm and trunk: 10.491004424031347
# Minimum angle between trunk and knee: 170.8059676782977
#
# Repetition: 8
#
# Minimum angle between upper arm and forearm: 76.8843207795844
# Maximum angle between upper arm and trunk: 11.187258508179287
# Minimum angle between trunk and knee: 168.69279804650503
#
# Repetition: 9
#
# Minimum angle between upper arm and forearm: 74.26502370754442
# Maximum angle between upper arm and trunk: 13.894387456411138
# Minimum angle between trunk and knee: 168.25995843175917
#
# Repetition: 10
#
# Minimum angle between upper arm and forearm: 74.26502370754442
# Maximum angle between upper arm and trunk: 11.668424974120521
# Minimum angle between trunk and knee: 167.20965776450475
#
# Repetition: 11
#
# Minimum angle between upper arm and forearm: 80.0615404385191
# Maximum angle between upper arm and trunk: 9.046127400389517
# Minimum angle between trunk and knee: 164.79520742216812
#
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_12
# Right side: 243
# Left  side: 6
# Detected arm: right
# extremas: [15.05060961 16.14638566 19.56640288 23.30033918 19.08580837 17.32226592
#  16.20390796 22.1875294  17.92319044 25.43866416 17.64747228 22.68593085
#  17.48097913]
# angle change threshold: 24.26201642036776
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [16, 6, 13, 12, 25, 25, 17, 27, 17, 18, 17, 20]
# threshold: 20
# counts less than threshold: [16, 6, 13, 12, 17, 17, 18, 17]
# Array filtering: Done
# extremas: [174.96800055 175.22132233 173.78204101 174.15490581 175.9408687
#  175.59122846 173.81217208 171.83977064 177.67567152 170.47503441
#  173.10147154 178.13609635 175.32397479 177.3024601  177.68843913
#  176.7589312  175.69533392 174.26735265]
# angle change threshold: 22.191047128422714
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [5, 14, 8, 8, 7, 10, 11, 12, 14, 14, 14, 27, 10, 23, 7, 14, 11]
# threshold: 23
# counts less than threshold: [5, 14, 8, 8, 7, 10, 11, 12, 14, 14, 14, 10, 7, 14, 11]
# Array filtering: Done
# extremas: [173.60798722 176.17442798 166.56456003  87.3720068  166.56437594
#  170.15676379 169.14226888]
# angle change threshold: 49.19468564299305
#
#
# Testing to filter by average angle change....
# Testing Finished
# Filtering by average angle change...
# extrema array size: 7
# angles removed: [87.37200679582388]
#
# New extrema array: [173.60798722 176.17442798 166.56456003 166.56437594 170.15676379
#  169.14226888]
# new size: 6
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [94.1347905  89.09791211 85.93915129 87.34310767 96.16283257 88.99360701]
# angle change threshold: 25.1177092119509
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [41, 35, 5, 42, 40]
# threshold: 21
# counts less than threshold: [5]
# Array filtering: Done
#
# Size of minima array: 5
# ------------------------------------------------------------------------------------------
# Number of reps performed: 6
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 94.13479050291522
# Maximum angle between upper arm and trunk: 16.146385663070838
# Minimum angle between trunk and knee: 172.90202909867662
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 89.09791211237138
# Maximum angle between upper arm and trunk: 23.300339177655726
# Minimum angle between trunk and knee: 170.08667924044923
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 85.93915128965988
# Maximum angle between upper arm and trunk: 17.322265918083527
# Minimum angle between trunk and knee: 168.67576532907398
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 85.93915128965988
# Maximum angle between upper arm and trunk: 22.187529395751586
# Minimum angle between trunk and knee: 168.67576532907398
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 88.99360700633608
# Maximum angle between upper arm and trunk: 25.438664155330976
# Minimum angle between trunk and knee: 173.23482812759306
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 88.99360700633608
# Maximum angle between upper arm and trunk: 22.685930845880474
# Minimum angle between trunk and knee: 171.29035520448528
#
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_13
# Right side: 244
# Left  side: 17
# Detected arm: right
# extremas: [24.96016995 25.97942184 15.89503249 20.68637384 17.9312841  21.18975485
#  18.94166953 22.02171882 13.22920619 21.76864532 15.93029782 19.72803959
#  13.5045316 ]
# angle change threshold: 25.035685557165202
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [6, 25, 13, 9, 24, 20, 15, 19, 23, 21, 12, 26]
# threshold: 20
# counts less than threshold: [6, 13, 9, 15, 19, 12]
# Array filtering: Done
# extremas: [177.02932659 178.40795198 175.71808519 177.96140421 177.51228576
#  177.13670855 178.10573668 177.25505702 174.1822435  174.35866902
#  175.95388546 176.6617027  177.4083221  178.66424796 176.07765848
#  177.12590248 175.93457215 178.94154723 176.94643867]
# angle change threshold: 21.463293336899014
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [8, 9, 23, 5, 8, 14, 8, 8, 9, 13, 7, 13, 19, 6, 7, 15, 14, 20]
# threshold: 23
# counts less than threshold: [8, 9, 5, 8, 14, 8, 8, 9, 13, 7, 13, 19, 6, 7, 15, 14, 20]
# Array filtering: Done
# extremas: [171.77592569 170.62261038 168.73434494 174.26172145 171.18270565
#  175.55036785]
# angle change threshold: 23.20312705195891
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [94.36585186 90.27437862 91.97362918 89.06182547 85.64856177]
# angle change threshold: 23.028947800675823
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 5
# ------------------------------------------------------------------------------------------
# Number of reps performed: 6
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 90.07933603712704
# Maximum angle between upper arm and trunk: 25.97942183519624
# Minimum angle between trunk and knee: 170.88035319305803
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 90.2743786234252
# Maximum angle between upper arm and trunk: 20.686373835426323
# Minimum angle between trunk and knee: 173.8930125109157
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 90.2743786234252
# Maximum angle between upper arm and trunk: 21.18975485454133
# Minimum angle between trunk and knee: 173.53153827885188
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 89.06182547361713
# Maximum angle between upper arm and trunk: 22.021718822673808
# Minimum angle between trunk and knee: 173.8239899377235
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 85.64856176665876
# Maximum angle between upper arm and trunk: 21.76864531510258
# Minimum angle between trunk and knee: 169.4573416542645
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 81.44026617143
# Maximum angle between upper arm and trunk: 19.728039585268373
# Minimum angle between trunk and knee: 174.09483185819988
#
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_14
# Right side: 269
# Left  side: 51
# Detected arm: right
# extremas: [15.38042914 18.28965085 13.46052321 11.83944221 15.85860478 19.34579898
#  14.51550019 15.98624124  9.38318045 11.55813072 13.05083844 14.89866566
#  13.26477711  8.7507641   7.36138925]
# angle change threshold: 23.058760671717998
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [39, 10, 14, 12, 34, 24, 8, 15, 15, 10, 29, 7, 14, 8]
# threshold: 22
# counts less than threshold: [10, 14, 12, 8, 15, 15, 10, 7, 14, 8]
# Array filtering: Done
# extremas: [178.80276641 173.65290505 176.74313563 177.20511547 175.46239959
#  179.03689686 177.54453702 177.68402953 178.82092806 177.58698446
#  178.61354753 172.04932656 171.95847933 179.20588478 178.47062755
#  177.59423049 176.74328007]
# angle change threshold: 22.21335130248535
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [22, 11, 6, 12, 17, 30, 7, 23, 9, 8, 12, 8, 14, 9, 22, 13]
# threshold: 22
# counts less than threshold: [11, 6, 12, 17, 7, 9, 8, 12, 8, 14, 9, 13]
# Array filtering: Done
# extremas: [158.38219086 167.15341844 156.43863041 167.99531487 161.04294287
#  162.35085982 152.53103539]
# angle change threshold: 28.18713557433356
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [89.89206781 89.91733559 90.86437699 92.49473722 86.23138855 85.25620775]
# angle change threshold: 21.96823977662424
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 6
# ------------------------------------------------------------------------------------------
# Number of reps performed: 7
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 88.23698715093361
# Maximum angle between upper arm and trunk: 15.380429142735148
# Minimum angle between trunk and knee: 172.25243047654038
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 89.89206781333858
# Maximum angle between upper arm and trunk: 18.28965085015572
# Minimum angle between trunk and knee: 172.02789242684457
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 89.91733559186036
# Maximum angle between upper arm and trunk: 15.85860477511797
# Minimum angle between trunk and knee: 173.09779975769763
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 90.8643769913231
# Maximum angle between upper arm and trunk: 19.345798982928468
# Minimum angle between trunk and knee: 174.3803497890788
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 86.23138854862549
# Maximum angle between upper arm and trunk: 15.986241237015893
# Minimum angle between trunk and knee: 169.58286106833134
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 85.25620774975943
# Maximum angle between upper arm and trunk: 13.050838443738872
# Minimum angle between trunk and knee: 171.44257602767206
#
# Repetition: 7
#
# Minimum angle between upper arm and forearm: 85.25620774975943
# Maximum angle between upper arm and trunk: 14.898665664856535
# Minimum angle between trunk and knee: 172.6468214718548
#
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_15
# Right side: 382
# Left  side: 567
# Detected arm: left
# extremas: [10.31362822  9.62116619  6.36281288  5.12544115  6.37652014  4.27889381
#   4.01572664  4.29021837  4.92688305  7.07544459  5.71709928  5.44990204
#   1.68718429  2.0597028   2.29941493  1.29295176  4.08043692  3.40968678
#   6.30300645  4.13619011  0.96339636  0.96339636  4.80480465  5.40129112
#   0.88838864  1.67036734  5.52017375  6.75095906  6.29906587  4.36727353
#   3.92851814  7.41622328  8.72495302  6.36540188  6.12444197  2.33167172]
# angle change threshold: 21.69666918316583
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [15, 63, 19, 9, 22, 8, 16, 23, 19, 15, 12, 13, 7, 21, 7, 11, 11, 28, 20, 8, 22, 12, 15, 7, 17, 11, 8, 8, 9, 19, 7, 14, 10, 17]
# threshold: 41
# counts less than threshold: [15, 19, 9, 22, 8, 16, 23, 19, 15, 12, 13, 7, 21, 7, 11, 11, 28, 20, 8, 22, 12, 15, 7, 17, 11, 8, 8, 9, 19, 7, 14, 10, 17]
#
# Starting another stage of filtering...
#
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [79, 29, 92, 72, 19, 40, 29, 36, 53, 55, 43]
# threshold: 35
# counts less than threshold: [29, 19, 29]
#
# Starting another stage of filtering...
#
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [109, 92, 92, 40, 66, 53, 55, 43]
# threshold: 42
# counts less than threshold: [40]
#
# Starting another stage of filtering...
#
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [109, 92, 133, 66, 53, 55, 43]
# threshold: 46
# counts less than threshold: [43]
# Array filtering: Done
# extremas: [12.98818618  7.25078101 11.94353769  7.02373052  9.13997379 12.79484732
#  11.32851166  0.82110409  1.2015973   1.2015973   8.04849546  7.37001583
#   6.20325936  7.31928574  6.16265003  3.28541514  2.26727369  3.58058059
#   9.95777641  7.57796079  4.18767612  9.22968963  7.02605841 14.40144201
#   4.5732864  18.11829925  3.26553717]
# angle change threshold: 24.409348339857768
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [43, 22, 30, 10, 15, 31, 7, 10, 17, 15, 26, 7, 17, 21, 9, 11, 21, 10, 14, 38, 15, 42, 19, 33, 40]
# threshold: 35
# counts less than threshold: [22, 30, 10, 15, 31, 7, 10, 17, 15, 26, 7, 17, 21, 9, 11, 21, 10, 14, 15, 19, 33]
#
# Starting another stage of filtering...
#
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [66, 57, 50, 18, 50, 83, 64, 58, 53, 40]
# threshold: 36
# counts less than threshold: [18]
# Array filtering: Done
# extremas: [169.28279162 170.55353288 167.6308713  174.63323441 165.91090892
#  171.15356892 167.97451581 164.09772002 160.74588871]
# angle change threshold: 24.446053955929056
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [68.50753896 79.29091544 80.531643   68.81247985 64.66434739 79.35705694
#  84.79610473 90.29733844]
# angle change threshold: 27.646341526663004
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 8
# ------------------------------------------------------------------------------------------
# Number of reps performed: 9
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 68.50753895553687
# Maximum angle between upper arm and trunk: 10.313628224985946
# Minimum angle between trunk and knee: 6.671830803947415
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 68.50753895553687
# Maximum angle between upper arm and trunk: 6.362812876375201
# Minimum angle between trunk and knee: 5.513755520676894
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 79.29091543860639
# Maximum angle between upper arm and trunk: 6.376520136262754
# Minimum angle between trunk and knee: 0.8139877395440315
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 68.81247985313641
# Maximum angle between upper arm and trunk: 7.075444588962101
# Minimum angle between trunk and knee: 0.34989254407678555
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 64.66434739489748
# Maximum angle between upper arm and trunk: 4.0804369223900006
# Minimum angle between trunk and knee: 1.2985755526061542
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 64.66434739489748
# Maximum angle between upper arm and trunk: 6.303006452137441
# Minimum angle between trunk and knee: 0.8037692058571368
#
# Repetition: 7
#
# Minimum angle between upper arm and forearm: 79.35705694003605
# Maximum angle between upper arm and trunk: 5.401291118324037
# Minimum angle between trunk and knee: 0.3270761579416942
#
# Repetition: 8
#
# Minimum angle between upper arm and forearm: 84.79610473212917
# Maximum angle between upper arm and trunk: 6.750959055102313
# Minimum angle between trunk and knee: 0.6519732195415966
#
# Repetition: 9
#
# Minimum angle between upper arm and forearm: 90.2973384388264
# Maximum angle between upper arm and trunk: 8.724953015715265
# Minimum angle between trunk and knee: 0.6519732195415966
#
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_16
# Right side: 396
# Left  side: 450
# Detected arm: left
# extremas: [ 7.93984693  7.37619106  7.45355551  1.77452689  7.12510526  3.91837089
#   9.31569046  8.53286494  4.84819839  1.80168278  1.70090811  3.2274618
#   3.00282803  4.1996587   1.81473869  2.34537562  2.03380094  2.13723673
#  10.8182363   2.05363602  3.62549196  4.20120712  4.60876162  4.33584869
#   2.10616629]
# angle change threshold: 22.36130708050214
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [7, 38, 20, 11, 39, 23, 9, 15, 15, 10, 9, 13, 10, 21, 14, 10, 5, 31, 15, 20, 17, 15, 9, 20]
# threshold: 32
# counts less than threshold: [7, 20, 11, 23, 9, 15, 15, 10, 9, 13, 10, 21, 14, 10, 5, 31, 15, 20, 17, 15, 9, 20]
# Array filtering: Done
# extremas: [10.33362018  9.04862439  7.9204304   7.2785663   2.6508177   8.03340568
#   4.95565444  7.52299719  6.44956951  8.512988    8.57622371  7.33437147
#   2.61008561 15.04267135  9.03083307 14.7164186 ]
# angle change threshold: 23.46711426642735
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [7, 18, 5, 31, 26, 24, 32, 7, 15, 10, 59, 40, 34, 27, 47]
# threshold: 27
# counts less than threshold: [7, 18, 5, 26, 24, 7, 15, 10]
# Array filtering: Done
# extremas: [170.20383206 168.57931799 164.75181235 167.35420463 168.58217255
#  162.53864465]
# angle change threshold: 23.065181561253997
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [73.28641518 79.24129822 68.89500549 82.06124254 63.04738153 76.28762204]
# angle change threshold: 32.34430286464342
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 6
# ------------------------------------------------------------------------------------------
# Number of reps performed: 6
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 73.2864151821178
# Maximum angle between upper arm and trunk: 7.939846932846906
# Minimum angle between trunk and knee: 1.4065053188387318
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 73.2864151821178
# Maximum angle between upper arm and trunk: 7.125105256939472
# Minimum angle between trunk and knee: 1.4380722961692096
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 68.89500549439364
# Maximum angle between upper arm and trunk: 9.31569045880943
# Minimum angle between trunk and knee: 0.854282536044856
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 68.89500549439364
# Maximum angle between upper arm and trunk: 4.199658702937401
# Minimum angle between trunk and knee: 0.04373157497326121
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 63.04738153284851
# Maximum angle between upper arm and trunk: 10.818236298641311
# Minimum angle between trunk and knee: 0.6032516652470155
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 63.04738153284851
# Maximum angle between upper arm and trunk: 4.60876162166876
# Minimum angle between trunk and knee: 0.9360448665972435
#
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_17
# Right side: 274
# Left  side: 319
# Detected arm: left
# extremas: [11.5467449  10.86228531  6.18599009  9.11945742  7.7956569   3.23093899
#   8.70906317 10.90532317 15.20407286  5.98647373  6.57210371 12.4427342
#  12.57483133  5.7389483  13.47373082 13.60695447  9.59520166 13.02255043]
# angle change threshold: 23.77087187699345
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [5, 35, 12, 8, 18, 12, 17, 12, 17, 16, 17, 5, 28, 15, 6, 27, 12]
# threshold: 24
# counts less than threshold: [5, 12, 8, 18, 12, 17, 12, 17, 16, 17, 5, 15, 6, 12]
# Array filtering: Done
# extremas: [18.92883259 23.97517572 21.42678847 20.68673921 20.59992103 22.58848097
#  21.61216398 22.73574692 24.68278223 22.1434919  23.13461797 22.56290135
#  21.54919281 21.47118579 21.66249478 19.92113604 22.11635821 20.81700098]
# angle change threshold: 21.475187572213315
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [28, 22, 12, 10, 16, 16, 18, 24, 16, 7, 22, 10, 2, 13, 19, 17, 14]
# threshold: 24
# counts less than threshold: [22, 12, 10, 16, 16, 18, 16, 7, 22, 10, 2, 13, 19, 17, 14]
# Array filtering: Done
# extremas: [179.15805214 175.38075111 178.45291967 178.05624727 179.62918628
#  173.38260564]
# angle change threshold: 23.01313233126566
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [73.65367472 67.82231754 74.64897703 77.98584312 76.78062961]
# angle change threshold: 24.300024065342935
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 5
# ------------------------------------------------------------------------------------------
# Number of reps performed: 6
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 73.65367472075717
# Maximum angle between upper arm and trunk: 11.54674490407383
# Minimum angle between trunk and knee: 14.759593171484918
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 67.82231754214227
# Maximum angle between upper arm and trunk: 9.11945741621456
# Minimum angle between trunk and knee: 17.748690022729978
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 67.82231754214227
# Maximum angle between upper arm and trunk: 15.204072856151875
# Minimum angle between trunk and knee: 19.774334688957854
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 74.64897702547161
# Maximum angle between upper arm and trunk: 12.574831327586947
# Minimum angle between trunk and knee: 19.304668505343045
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 76.78062960786781
# Maximum angle between upper arm and trunk: 13.606954467104844
# Minimum angle between trunk and knee: 19.234394854911983
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 76.78062960786781
# Maximum angle between upper arm and trunk: 13.02255042829911
# Minimum angle between trunk and knee: 18.794667134686257
#
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_18
# Right side: 346
# Left  side: 398
# Detected arm: left
# extremas: [14.79780224  7.54274633 10.96543255  7.4455425   9.07050292  6.91822794
#   6.89281213  6.98746422 11.63844153  5.95209246 11.78476526  6.94396609
#   7.96359303  8.70537428  5.75722986  6.22840105  5.93440756  7.29279143
#   5.47170829]
# angle change threshold: 22.65332878480184
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [26, 28, 39, 7, 19, 10, 16, 9, 22, 36, 29, 13, 19, 22, 15, 11, 10, 25]
# threshold: 27
# counts less than threshold: [26, 7, 19, 10, 16, 9, 22, 13, 19, 22, 15, 11, 10, 25]
#
# Starting another stage of filtering...
#
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [55, 47, 57, 59, 63, 38, 22]
# threshold: 31
# counts less than threshold: [22]
# Array filtering: Done
# extremas: [22.11229913 22.44668623 22.2672412  21.55278049 25.00002339 20.93116364
#  22.12208973 26.37887636 22.09714205 21.45831802 24.17058124 23.50590225
#  21.89064095 21.94712787 24.4234946  22.96197348 21.83534393 21.72793445
#  21.55609886 20.64066645 22.03810071 22.35470235 22.30199653 21.40554889
#  21.28376979 21.26031327]
# angle change threshold: 21.32915907309806
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [6, 9, 19, 8, 16, 13, 21, 21, 4, 26, 15, 19, 9, 15, 20, 13, 7, 14, 15, 15, 10, 11, 33, 7, 5]
# threshold: 32
# counts less than threshold: [6, 9, 19, 8, 16, 13, 21, 21, 4, 26, 15, 19, 9, 15, 20, 13, 7, 14, 15, 15, 10, 11, 7, 5]
# Array filtering: Done
# extremas: [174.14653156 172.59513656 164.49007852 169.85470669 166.75175872
#  165.99150206 164.10924179]
# angle change threshold: 23.461091015690155
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [71.01329588 74.52240708 72.64896851 72.38791526 75.88592082 74.95780282]
# angle change threshold: 22.01394531425473
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 6
# ------------------------------------------------------------------------------------------
# Number of reps performed: 7
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 71.01329588134908
# Maximum angle between upper arm and trunk: 14.79780223521343
# Minimum angle between trunk and knee: 20.40106114467965
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 71.01329588134908
# Maximum angle between upper arm and trunk: 10.965432547079686
# Minimum angle between trunk and knee: 19.913153254835876
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 72.64896851388372
# Maximum angle between upper arm and trunk: 9.070502922784643
# Minimum angle between trunk and knee: 20.699633258930838
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 72.38791526117959
# Maximum angle between upper arm and trunk: 11.638441531692504
# Minimum angle between trunk and knee: 20.84632086366649
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 72.38791526117959
# Maximum angle between upper arm and trunk: 11.784765260272323
# Minimum angle between trunk and knee: 21.411586205392542
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 74.95780281835398
# Maximum angle between upper arm and trunk: 8.705374283779834
# Minimum angle between trunk and knee: 19.733609066524135
#
# Repetition: 7
#
# Minimum angle between upper arm and forearm: 68.38156099457716
# Maximum angle between upper arm and trunk: 7.292791425108178
# Minimum angle between trunk and knee: 19.639978698253262
#
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_19
# Right side: 342
# Left  side: 276
# Detected arm: right
# extremas: [14.07477712  7.92361918  2.7880813  17.48403654 12.19246176  4.94664747
#   1.65950252  3.8293595  11.13607193  3.08051349  9.28628412  2.99600607
#   4.44963251 14.33853217  3.30662714 15.91416544  4.28292094]
# angle change threshold: 27.4030359696933
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [13, 18, 13, 46, 15, 18, 8, 12, 33, 10, 13, 16, 16, 27, 28, 24]
# threshold: 25
# counts less than threshold: [13, 18, 13, 15, 18, 8, 12, 10, 13, 16, 16, 24]
# Array filtering: Done
# extremas: [168.30059237 167.7165908  167.4840217  167.7036813  166.49439031
#  167.62038261 167.39847599 167.29018306 166.77133445 166.84269302
#  166.96773163 167.89928733 166.31456066 165.68649478 166.12014033
#  165.44371426 166.26175549 165.53524358 167.1457618  166.9206445 ]
# angle change threshold: 20.634293021497857
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [15, 15, 9, 9, 17, 20, 24, 9, 15, 15, 8, 20, 3, 22, 26, 19, 33, 10, 9]
# threshold: 26
# counts less than threshold: [15, 15, 9, 9, 17, 20, 24, 9, 15, 15, 8, 20, 3, 22, 19, 10, 9]
# Array filtering: Done
# extremas: [179.2579852  173.78810475 174.68760374 173.04480087 169.96485129
#  173.45221146 179.94151749]
# angle change threshold: 23.511466347059052
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [80.83722099 80.80119226 80.01504781 79.71633857 80.11492975 80.78147431]
# angle change threshold: 20.43720363455264
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 6
# ------------------------------------------------------------------------------------------
# Number of reps performed: 7
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 80.83722099112582
# Maximum angle between upper arm and trunk: 14.074777121620548
# Minimum angle between trunk and knee: 164.3291554602672
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 80.80119226436223
# Maximum angle between upper arm and trunk: 17.484036535305286
# Minimum angle between trunk and knee: 163.87826306338087
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 80.01504781337896
# Maximum angle between upper arm and trunk: 12.192461755811054
# Minimum angle between trunk and knee: 163.9748523633143
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 79.71633856652713
# Maximum angle between upper arm and trunk: 11.136071934874535
# Minimum angle between trunk and knee: 163.02819448445138
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 79.71633856652713
# Maximum angle between upper arm and trunk: 9.286284118048028
# Minimum angle between trunk and knee: 162.31770946045583
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 80.11492974594124
# Maximum angle between upper arm and trunk: 14.338532167044617
# Minimum angle between trunk and knee: 162.4977431122239
#
# Repetition: 7
#
# Minimum angle between upper arm and forearm: 80.78147431469165
# Maximum angle between upper arm and trunk: 15.914165435347718
# Minimum angle between trunk and knee: 160.22212190972334
#
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_2
# Right side: 211
# Left  side: 3
# Detected arm: right
# extremas: [19.86837474 12.10607622 11.3852666  21.0049615  13.39818303 20.40411163
#  11.26482863 16.34462276 16.35816893  9.85240052  9.8108759  11.51034265
#  14.39797928 12.29403846 19.52714596]
# angle change threshold: 24.815684154415095
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [16, 7, 12, 19, 12, 9, 12, 8, 11, 5, 11, 5, 21, 15]
# threshold: 19
# counts less than threshold: [16, 7, 12, 12, 9, 12, 8, 11, 5, 11, 5, 15]
# Array filtering: Done
# extremas: [179.38294326 176.73858364 178.56523591 177.32923645 178.52075819
#  176.14867211 174.16002752 177.18163777 175.12151218 177.96066591
#  178.26147965 174.91018511 174.55538728 178.82926078 177.71033726]
# angle change threshold: 22.04141832083337
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# ...
#  10.2648733  11.34095179 10.89522868 10.68767713 11.45558599 10.10089152
#  10.34053581  8.01367201 16.13222668 13.10533526  9.62831465 10.9966906
#   7.03102048  6.77340902 15.1406058   8.8102767   7.45771071  2.96913513]
# angle change threshold: 22.4236779366287
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [11, 10, 16, 24, 17, 27, 18, 8, 18, 7, 27, 15, 11, 16, 23, 36, 17, 14, 14, 26, 19, 9, 22]
# threshold: 31
# counts less than threshold: [11, 10, 16, 24, 17, 27, 18, 8, 18, 7, 27, 15, 11, 16, 23, 17, 14, 14, 26, 19, 9, 22]
# Array filtering: Done
# extremas: [175.48805569 178.15744791 173.05843937 173.63106936 170.08415881
#  171.49595016]
# angle change threshold: 22.659946529331894
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [80.34802897 80.61654646 87.12822915 71.24799693 70.20311759]
# angle change threshold: 25.926327934384013
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 5
# ------------------------------------------------------------------------------------------
# Number of reps performed: 6
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 80.34802896887346
# Maximum angle between upper arm and trunk: 7.398262911204388
# Minimum angle between trunk and knee: 7.573469103583243
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 80.34802896887346
# Maximum angle between upper arm and trunk: 7.74737010754991
# Minimum angle between trunk and knee: 6.918559391113984
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 80.61654646343435
# Maximum angle between upper arm and trunk: 4.888434582596549
# Minimum angle between trunk and knee: 8.212823414949128
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 71.24799693189915
# Maximum angle between upper arm and trunk: 6.9625845414894725
# Minimum angle between trunk and knee: 5.539051315325829
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 70.20311758874446
# Maximum angle between upper arm and trunk: 2.665444552727683
# Minimum angle between trunk and knee: 4.455028463742021
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 70.20311758874446
# Maximum angle between upper arm and trunk: 5.836510023268425
# Minimum angle between trunk and knee: 2.602663747744044
#
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_7
# Right side: 356
# Left  side: 478
# Detected arm: left
# extremas: [3.56668657 6.01242183 5.25981536 4.30595183 4.39594064 0.50537356
#  1.1633932  5.96247263 4.05682122 3.09229018 3.13657273 8.77812582
#  5.55259808 2.07643215 2.49431134 2.05235273 2.2720885  6.50163921
#  4.20811282 0.82404709 2.2801243  2.56525797 6.83215307 0.73959649
#  0.77041598 5.57151818]
# angle change threshold: 22.270674905685546
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [17, 14, 14, 12, 20, 12, 19, 11, 9, 28, 32, 26, 23, 10, 10, 9, 26, 17, 11, 22, 9, 33, 34, 7, 11]
# threshold: 33
# counts less than threshold: [17, 14, 14, 12, 20, 12, 19, 11, 9, 28, 32, 26, 23, 10, 10, 9, 26, 17, 11, 22, 9, 7, 11]
# Array filtering: Done
# extremas: [13.27399893  3.11555038  7.17493885  8.96374174 10.82239085  8.2447871
#   7.67367006  9.39509218  7.88191296  8.32515205  2.84996748  3.22236452
#  12.27145686 10.08980962  9.66629696  2.68246652 11.08545871  8.63179067
#   8.84287763  4.39828728]
# angle change threshold: 23.404729055774794
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [47, 26, 13, 18, 11, 24, 19, 11, 20, 27, 12, 31, 21, 7, 26, 39, 14, 26, 23]
# threshold: 29
# counts less than threshold: [26, 13, 18, 11, 24, 19, 11, 20, 27, 12, 21, 7, 26, 14, 26, 23]
#
# Starting another stage of filtering...
#
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [107, 56, 32, 40, 31, 96, 41]
# threshold: 35
# counts less than threshold: [32, 31]
#
# Starting another stage of filtering...
#
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [107, 56, 105, 96, 41]
# threshold: 45
# counts less than threshold: [41]
# Array filtering: Done
# extremas: [173.72251885 168.66763986 168.61140552 172.23346094 170.28608663
#  168.13262981  74.68228546]
# angle change threshold: 37.71405737410302
#
#
# Testing to filter by average angle change....
# Testing Finished
# Filtering by average angle change...
# extrema array size: 7
# angles removed: [74.68228546468276]
#
# New extrema array: [173.72251885 168.66763986 168.61140552 172.23346094 170.28608663
#  168.13262981]
# new size: 6
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [96, 10, 81, 99, 102]
# threshold: 43
# counts less than threshold: [10]
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [ 75.51927018 167.83176167  63.32455932  74.86240349  70.99388873
#   74.67974744]
# angle change threshold: 63.18238229920895
#
#
# Testing to filter by average angle change....
# Testing Finished
# Filtering by average angle change...
# extrema array size: 6
# angles removed: [167.83176167392648]
#
# New extrema array: [75.51927018 63.32455932 74.86240349 70.99388873 74.67974744]
# new size: 5
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 5
# ------------------------------------------------------------------------------------------
# Number of reps performed: 5
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 71.29320205532214
# Maximum angle between upper arm and trunk: 6.012421830035854
# Minimum angle between trunk and knee: 1.7591291764388648
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 63.32455931708101
# Maximum angle between upper arm and trunk: 5.962472632570442
# Minimum angle between trunk and knee: 2.0883909907222327
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 63.32455931708101
# Maximum angle between upper arm and trunk: 8.778125818476406
# Minimum angle between trunk and knee: 1.6365232301248407
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 70.99388872907775
# Maximum angle between upper arm and trunk: 6.501639211314556
# Minimum angle between trunk and knee: 2.393740819388082
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 70.99388872907775
# Maximum angle between upper arm and trunk: 6.83215306911709
# Minimum angle between trunk and knee: 3.3132722317496137
#
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_8
# Right side: 389
# Left  side: 437
# Detected arm: left
# extremas: [4.5775037  6.12544411 6.99205996 3.77512673 8.51317628 5.53418504
#  3.39325812 4.00115983 5.83285344 7.67574802 3.50402151 1.11919101
#  1.53775416 2.26719954 3.45279156 5.31377222 2.53930855 4.74964654
#  5.81611987 5.37259762 8.59443816 0.89186179]
# angle change threshold: 22.282966640937804
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [47, 11, 15, 14, 23, 30, 10, 18, 12, 17, 28, 5, 11, 14, 7, 19, 13, 25, 18, 18, 30]
# threshold: 30
# counts less than threshold: [11, 15, 14, 23, 10, 18, 12, 17, 28, 5, 11, 14, 7, 19, 13, 25, 18, 18]
#
# Starting another stage of filtering...
#
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [59, 30, 97, 87, 59, 37, 30]
# threshold: 35
# counts less than threshold: [30, 30]
#
# Starting another stage of filtering...
#
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [90, 97, 87, 59, 37]
# threshold: 42
# counts less than threshold: [37]
# Array filtering: Done
# extremas: [17.22554694 11.72790567 12.76328286 13.20210876 10.34586359 12.71436457
#  13.05689507 12.84846411 11.53749945  9.28414485 12.6578079  13.8072052
#  14.10467009 11.60009287 11.12084607 13.66053284  7.10444405  9.129236
#   8.8962463   3.26725813 11.49188699 10.50902477 10.79948799  9.83862816]
# angle change threshold: 22.241633912084446
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [13, 15, 18, 13, 11, 11, 32, 14, 7, 16, 7, 7, 3, 11, 20, 54, 14, 20, 23, 47, 10, 11, 17]
# threshold: 31
# counts less than threshold: [13, 15, 18, 13, 11, 11, 14, 7, 16, 7, 7, 3, 11, 20, 14, 20, 23, 10, 11, 17]
#
# Starting another stage of filtering...
#
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [48, 37, 32, 55, 36, 69, 92, 22]
# threshold: 32
# counts less than threshold: [22]
# Array filtering: Done
# extremas: [170.34296603 170.64003081 167.70418892 169.01804796 163.85042879
#  168.19028831  85.59378954]
# angle change threshold: 36.10845719334995
#
#
# Testing to filter by average angle change....
# Testing Finished
# Filtering by average angle change...
# extrema array size: 7
# angles removed: [85.59378954253226]
#
# New extrema array: [170.34296603 170.64003081 167.70418892 169.01804796 163.85042879
#  168.19028831]
# new size: 6
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [86, 84, 10, 89, 97]
# threshold: 41
# counts less than threshold: [10]
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [ 66.96679207  74.62983524 166.91609354  69.27930776  80.78622794
#   85.59307949]
# angle change threshold: 62.77997179290245
#
#
# Testing to filter by average angle change....
# Testing Finished
# Filtering by average angle change...
# extrema array size: 6
# angles removed: [166.91609353663728]
#
# New extrema array: [66.96679207 74.62983524 69.27930776 80.78622794 85.59307949]
# new size: 5
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 5
# ------------------------------------------------------------------------------------------
# Number of reps performed: 5
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 66.96679207419096
# Maximum angle between upper arm and trunk: 6.992059963507094
# Minimum angle between trunk and knee: 6.860215834178586
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 66.96679207419096
# Maximum angle between upper arm and trunk: 8.513176284362448
# Minimum angle between trunk and knee: 3.8638989499318304
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 69.27930776099451
# Maximum angle between upper arm and trunk: 7.675748015594478
# Minimum angle between trunk and knee: 5.322302082325425
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 69.27930776099451
# Maximum angle between upper arm and trunk: 5.816119865939788
# Minimum angle between trunk and knee: 0.31378208003491687
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 80.78622794373695
# Maximum angle between upper arm and trunk: 8.594438157096219
# Minimum angle between trunk and knee: 0.23602241937679827
#
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_9
# Right side: 357
# Left  side: 239
# Detected arm: right
# extremas: [11.2600547  11.79074404  5.12317017  9.04699744 11.22912155  2.88227858
#   6.51843514 13.35926515  9.7517994  14.71347082  5.52882028  6.67456127
#   6.50468758 11.92763635  5.4449224   6.46828281 10.55218831  9.43912991
#   4.21133343]
# angle change threshold: 24.141735001982653
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [5, 13, 18, 18, 28, 10, 19, 41, 19, 18, 18, 7, 7, 35, 10, 12, 20, 14]
# threshold: 26
# counts less than threshold: [5, 13, 18, 18, 10, 19, 19, 18, 18, 7, 7, 10, 12, 20, 14]
#
# Starting another stage of filtering...
#
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [51, 59, 61, 37, 15, 59]
# threshold: 29
# counts less than threshold: [15]
# Array filtering: Done
# extremas: [167.73914016 168.57325392 167.96462356 163.29783346 168.9053954
#  167.95601027 166.76066503 165.83283315 165.74230683 170.03569867
#  171.56463087 168.96841949 168.36139918 165.07893669 168.39677306
#  168.83018198 165.10341485 167.45155495 167.9802196  169.25737094
#  169.96336789 168.98556012 168.34742708 173.27961276 172.39651859]
# angle change threshold: 21.95655787842685
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [18, 17, 20, 9, 12, 14, 14, 3, 25, 7, 9, 11, 14, 15, 9, 16, 21, 7, 11, 17, 12, 9, 12, 10]
# threshold: 30
# counts less than threshold: [18, 17, 20, 9, 12, 14, 14, 3, 25, 7, 9, 11, 14, 15, 9, 16, 21, 7, 11, 17, 12, 9, 12, 10]
# Array filtering: Done
# extremas: [179.07535474 176.51406842 179.07546132 177.63412105 177.38542273
#  175.76165697]
# angle change threshold: 21.687296715385656
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [75.18993724 79.32559498 84.61426944 82.52471873 82.86320507]
# angle change threshold: 22.96309231216323
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 5
# ------------------------------------------------------------------------------------------
# Number of reps performed: 6
#
# Repetition: 1
#
# Minimum angle between upper arm and forearm: 75.18993724151194
# Maximum angle between upper arm and trunk: 11.790744044328903
# Minimum angle between trunk and knee: 160.64524995517624
#
# Repetition: 2
#
# Minimum angle between upper arm and forearm: 75.18993724151194
# Maximum angle between upper arm and trunk: 11.22912154809745
# Minimum angle between trunk and knee: 161.6022196106424
#
# Repetition: 3
#
# Minimum angle between upper arm and forearm: 79.32559498070275
# Maximum angle between upper arm and trunk: 13.35926514576849
# Minimum angle between trunk and knee: 162.25437301103983
#
# Repetition: 4
#
# Minimum angle between upper arm and forearm: 82.52471872574489
# Maximum angle between upper arm and trunk: 14.71347081998797
# Minimum angle between trunk and knee: 164.64684342885892
#
# Repetition: 5
#
# Minimum angle between upper arm and forearm: 82.52471872574489
# Maximum angle between upper arm and trunk: 11.92763635222479
# Minimum angle between trunk and knee: 161.5363006265375
#
# Repetition: 6
#
# Minimum angle between upper arm and forearm: 82.86320506804157
# Maximum angle between upper arm and trunk: 10.552188312324965
# Minimum angle between trunk and knee: 163.23240857635253
#
# ========================================================================================================================

# %%
a = [1,2,3]
a[-1:]
print(a)
# Out:
# [1, 2, 3]

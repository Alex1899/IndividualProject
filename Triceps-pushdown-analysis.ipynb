# %%
from Parser import parse_frames
from scipy.signal import medfilt
from Functions import find_extremas, filter_extremas, detect_side, analyse_each_rep
from JointAngles import JointAngles
import numpy as np
import math
import glob
import os
import itertools
import pickle
import matplotlib.pyplot as plt

# %%
8*(80/100)
# Out:
# 6.4

# %%
# modify this path for other videos 
# input_folder = "/home/aleko/Documents/Projects/IndividualProject/bicepvid"
# input_folder = "C:\\Users\\altaok\\Documents\\GitHub\\IndividualProject\\keypoints_for_all\\triceps pushdown"

input_folder = 'C:\\Users\\ak5u16\\Desktop\\IndividualProject\\keypoints_for_all\\triceps pushdown'
folder_paths = glob.glob(os.path.join(input_folder, 'triceps_pushdown_correct*'))     
min_upper_arm_forearm = [] 
max_upper_arm_forearm = []
max_upper_arm_trunk = []
min_trunk_knee = []
max_trunk_knee = []


for folder in folder_paths:
    print("Starting..." + "\nKeypoints from folder: " + os.path.basename(folder))
    video_name = os.path.basename(folder).replace('output_points_', '')
    frame_poses = parse_frames(folder)
    
    joint_angles = JointAngles('triceps pushdown', frame_poses)
    print('Detected arm: ' + joint_angles.side)

    upArm_trunk_angles = np.array(joint_angles.upArm_trunk_angles)
    upArm_trunk_angles_filtered = medfilt(medfilt(upArm_trunk_angles, 5), 5)
    
   
    upArm_forearm_angles = np.array(joint_angles.upArm_forearm_angles)
    upArm_forearm_angles_filtered = medfilt(medfilt(upArm_forearm_angles, 5), 5)
    
    trunk_knee_angles = np.array(joint_angles.trunk_knee_angles)
    trunk_knee_angles_filtered = medfilt(medfilt(trunk_knee_angles, 5), 5)
    
    # Find upper arm and trunk maximum angles to detect wrong form 
    upArm_trunk_maximas = find_extremas(upArm_trunk_angles_filtered)
    upArm_trunk_maximas = filter_extremas(upArm_trunk_angles_filtered, upArm_trunk_maximas)
    indexesmax1 = np.array([np.argwhere(upArm_trunk_angles_filtered == maxima)[0][0] for maxima in upArm_trunk_maximas])
    # print("Largest angles between upper arm and trunk: " + str(upArm_trunk_maximas))

    # Find trunk and knee maximum angles to detect wrong form 
    trunk_knee_maximas = find_extremas(trunk_knee_angles_filtered)
    trunk_knee_maximas = filter_extremas(trunk_knee_angles_filtered, trunk_knee_maximas)
    indexesmax2 = np.array([np.argwhere(trunk_knee_angles_filtered == maxima)[0][0] for maxima in trunk_knee_maximas])
   
    # print("Largest angles between trunk and knee: " + str(trunk_knee_maximas))

    # Count repetitions
    upArm_forearm_maximas = find_extremas(upArm_forearm_angles_filtered)  
    upArm_forearm_maximas = filter_extremas(upArm_forearm_angles_filtered, upArm_forearm_maximas)
    indexesmax3 = np.array([np.argwhere(upArm_forearm_angles_filtered == maxima)[0][0] for maxima in upArm_forearm_maximas])
   
    # print("Number of maxima points between Upper Arm and Forearm: " + str(upArm_forearm_maximas.size))
    # print(upArm_forearm_maximas)
    
    # Find upper arm and forearm minimum points to count reps 
    upArm_forearm_minimas = find_extremas(upArm_forearm_angles_filtered, maxima=False)
    print('\n----------------------------Filtering minimas-------------------------------------')
    upArm_forearm_minimas = filter_extremas(upArm_forearm_angles_filtered, upArm_forearm_minimas, maxima=False)
    indexesmin = np.array([np.argwhere(upArm_forearm_angles_filtered == minima)[0][0] for minima in upArm_forearm_minimas])
    print("\nSize of minima array: " + str(upArm_forearm_minimas.size))
    print('-'*90)
    
   
    # Plot 1
    plt.figure(figsize=(10,4))
    plt.scatter(np.arange(upArm_trunk_angles.shape[0]), upArm_trunk_angles, alpha=0.5)
    plt.scatter(np.arange(upArm_trunk_angles_filtered.shape[0]), upArm_trunk_angles_filtered, c='r', alpha=0.5)
    plt.title(video_name)
    plt.xlabel('Frames')
    plt.ylabel('Angle between Upper Arm and Trunk')
    # Set range on y-axis so the plots are consistent
    plt.ylim(0,90)
    
    # Annontate maxima points
    plt.plot(indexesmax1, upArm_trunk_angles_filtered[indexesmax1], 'ks')
    plt.show()
    
    # Plot 2
    plt.figure(figsize=(10,4))
    plt.scatter(np.arange(trunk_knee_angles.shape[0]), trunk_knee_angles, alpha=0.5)
    plt.scatter(np.arange(trunk_knee_angles_filtered.shape[0]), trunk_knee_angles_filtered, c='r', alpha=0.5)
    plt.title(video_name)
    plt.xlabel('Frames')
    plt.ylabel('Angle between Trunk and Knee')
    # Set range on y-axis so the plots are consistent
    plt.ylim(0,360)
    
    # Annontate maxima points
    plt.plot(indexesmax2, trunk_knee_angles_filtered[indexesmax2], 'ks')
    plt.show()

    # Plot 3
    plt.figure(figsize=(10,4))
    plt.scatter(np.arange(upArm_forearm_angles.shape[0]), upArm_forearm_angles, alpha=0.5)
    plt.scatter(np.arange(upArm_forearm_angles_filtered.shape[0]), upArm_forearm_angles_filtered, c='r', alpha=0.5)
    plt.title(video_name)
    plt.xlabel('Frames')
    plt.ylabel('Angle between Upper Arm and Forearm')
    # Set range on y-axis so the plots are consistent
    plt.ylim(0,220) 
    
    # Annotate minima apoints on the graph   
    max_points = upArm_forearm_angles_filtered[indexesmax3]
    min_points = upArm_forearm_angles_filtered[indexesmin]
    plt.plot(indexesmin, min_points, 'bo')
    plt.plot(indexesmax3, max_points, 'ks')

    """
        # Annotate local maximas
        for maxp, indx in zip(max_points, indexesmax3):
            plt.annotate('local max', xy=(indx, maxp), xytext=(indx, maxp+25),
                    arrowprops=dict(facecolor='black', shrink=0.05))

        # Annotate local minimas
        for minp, indx in zip(min_points, indexesmin):
            plt.annotate('local min', xy=(indx, minp), xytext=(indx, minp-35),
                    arrowprops=dict(facecolor='black', shrink=0.05))     
    """
    plt.show()

    # Plot 4
    plt.figure(figsize=(10,4))
    plt.scatter(np.arange(upArm_forearm_angles_filtered.shape[0]), upArm_forearm_angles_filtered, c='r', alpha=0.5)
    plt.scatter(np.arange(upArm_trunk_angles_filtered.shape[0]), upArm_trunk_angles_filtered, c='r', alpha=0.5)
    plt.scatter(np.arange(trunk_knee_angles_filtered.shape[0]), trunk_knee_angles_filtered, c='r', alpha=0.5)
    plt.title(video_name)
    plt.xlabel('Frames')
    plt.ylabel('Whole body movement')
    # Set range on y-axis so the plots are consistent
    plt.ylim(0,250) 
    # Annotate minima apoints      
    plt.plot(indexesmin, upArm_forearm_angles_filtered[indexesmin], 'bo')
    plt.plot(indexesmax1, upArm_trunk_angles_filtered[indexesmax1], 'ks')
    plt.plot(indexesmax2, trunk_knee_angles_filtered[indexesmax2], 'ks')
    plt.plot(indexesmax3, upArm_forearm_angles_filtered[indexesmax3], 'ks')
    
    plt.show()
   
    
    # Each rep analysis
    # local minimums for upper arm and forearm are min angles in each rep
    min_upper_arm_forearm1, max_upper_arm_forearm1, max_upper_arm_trunk1, min_trunk_knee1, max_trunk_knee1 = analyse_each_rep(exercise='triceps pushdown', string='thresholds', 
                                                                                                                                         extremas1=upArm_forearm_minimas, 
                                                                                                                                         uf_angles1=upArm_forearm_angles_filtered, 
                                                                                                                                         ut_angles1=upArm_trunk_angles_filtered, 
                                                                                                                                         tk_angles1=trunk_knee_angles_filtered)
    min_upper_arm_forearm = min_upper_arm_forearm + min_upper_arm_forearm1
    max_upper_arm_forearm = max_upper_arm_forearm + max_upper_arm_forearm1
    max_upper_arm_trunk = max_upper_arm_trunk + max_upper_arm_trunk1
    min_trunk_knee = min_trunk_knee + min_trunk_knee1
    max_trunk_knee = max_trunk_knee + max_trunk_knee1
    
    print('\n' + '='*120 + '\n')


print('Minimum Upper Arm Forearm threshold: ' + str(min(min_upper_arm_forearm)))
print('Maximum Upper Arm Forearm threshold: ' + str(max(max_upper_arm_forearm)))
# print('Minimum Upper Arm Trunk threshold: ' + str(min(min_upper_arm_trunk)))
print('Maximum Upper Arm Trunk threshold: ' + str(max(max_upper_arm_trunk)))
print('Minimum Trunk Knee threshold: ' + str(min(min_trunk_knee)))
print('Maximum Trunk Knee threshold: ' + str(max(max_trunk_knee)))
# Out:
# Starting...
# Keypoints from folder: triceps_pushdown_correct_1
# Right side: 0
# Left  side: 276
# Detected arm: left
# extremas: [13.22480165 12.16347611 15.14572155 12.05257449 12.36399587 12.01923929
#  13.15883021 10.442466   11.00732435 11.36163589 10.49355371 15.22076523
#  13.67554574 10.42002058 10.89915109 13.09171432]
# angle change threshold: 21.70905020899091
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [178.44249288 176.51830993 176.83040019 176.31657317 178.27377978
#  175.95531917 177.50646273 177.91066391 176.3748604  176.61425574
#  179.36562334 177.44875093 178.86164964 179.356489   178.15048325
#  178.58945676 178.93731857 176.2174199  177.21672886]
# angle change threshold: 21.280240991130313
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [167.92355621 170.23943547 166.27556387 170.36052621 167.42463307
#  165.39122234 170.49591658]
# angle change threshold: 23.40645188400845
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [94.52428257 95.8773112  89.32800468 86.12571966 88.14053113 91.48098768]
# angle change threshold: 23.29197763572258
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 6
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_10
# Right side: 0
# Left  side: 642
# Detected arm: left
# extremas: [ 9.93598561 10.64663348  8.0468238  15.56450761 12.32141008  5.72580267
#  19.24877166 17.41383711  2.36005188  7.54670479  7.69017374 15.26960614
#   6.87116345  7.36185577 14.99566682 17.03945952  7.41333461 15.0479779
#  15.24997859  8.82821581 14.94633074  7.4424555   7.41260181 16.58803022
#   7.12415993  5.69775173  7.25322896 15.358463    3.11335906]
# angle change threshold: 25.787954490295995
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [165.83956259 161.52966954 162.81294509 164.74386543 162.47678812
#  160.18823326 159.75410554 165.15388171 161.07261849 160.58486466
#  160.87023147 162.54255716 165.15912403 159.60875682 158.52205484
#  161.42141149 159.48823368 157.37418545 158.70419158 160.38495559
#  159.11094829 159.69135532 162.85158394 162.6173734  163.23033426
#  163.1607447  159.95742701 161.14269772 162.60796182 162.50845206
#  160.59902897 160.77313645]
# angle change threshold: 21.858697425057173
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [173.32050139 179.72883564 178.33857055 178.82035396 177.88903433
#  176.62605427 177.21274248 176.91196413 175.53842998 175.52374639
#  176.93103596 171.37252674]
# angle change threshold: 21.79237868769478
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [65, 10, 65, 15, 61, 10, 72, 64, 71, 69, 77]
# threshold: 37
# counts less than threshold: [10, 15, 10]
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [ 73.95391054 178.14363785  80.80329915 176.44640623  77.15181721
#  176.22859759  84.74792864  80.04342393  75.78828132  77.23336159
#   70.2465152 ]
# angle change threshold: 80.44167854208922
#
#
# Testing to filter by average angle change....
# Testing Finished
# Filtering by average angle change...
# extrema array size: 11
# angles removed: [178.14363785159307, 176.44640622607116, 176.2285975878542]
#
# New extrema array: [73.95391054 80.80329915 77.15181721 84.74792864 80.04342393 75.78828132
#  77.23336159 70.2465152 ]
# new size: 8
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 8
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_11
# Right side: 0
# Left  side: 558
# Detected arm: left
# extremas: [15.62073157 13.1278301   6.65172841 11.58995365  3.44513924 10.85597869
#   4.01268948 13.20118637  5.16394146 11.84352494  2.04606842 12.73080381
#   3.05989738  7.03619383  9.79864542  9.08364141  5.14801619 11.17897953
#   7.19909167 10.25114755  6.77876186  8.86952566]
# angle change threshold: 25.732382331244857
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [163.20535314 162.76390407 160.531387   158.79627095 158.86061673
#  158.20025412 158.08109463 158.89485563 159.43960065 159.43960065
#  163.0271119  159.97442821 162.29167493 160.4287751  160.55464197
#  159.62804965 160.49746504 161.06650193 160.37971158 161.10946738
#  161.54266631 160.1411681  162.24931283 160.47875076 159.95108363
#  161.10741878 161.34036003 160.6076951  159.45424572 158.86986318
#  158.21900092 157.32547108 157.86325638 158.91560985 158.93024253]
# angle change threshold: 21.017331265262797
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [177.70765362 179.17639639 173.32527063 171.76891208 172.54523868
#  168.93240614 171.74088098 171.04083111 168.30043984 168.04296997
#  164.03927725 154.68434997]
# angle change threshold: 23.01185382515698
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [9, 43, 49, 48, 50, 49, 51, 54, 48, 57, 55]
# threshold: 34
# counts less than threshold: [9]
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [177.56046889  76.4460279   73.91177544  73.0573803   72.11333521
#   74.27699937  64.21598706  70.91576221  75.96037637  67.45690601
#   68.30339992]
# angle change threshold: 33.8766163708612
#
#
# Testing to filter by average angle change....
# Testing Finished
# Filtering by average angle change...
# extrema array size: 11
# angles removed: [177.5604688856787]
#
# New extrema array: [76.4460279  73.91177544 73.0573803  72.11333521 74.27699937 64.21598706
#  70.91576221 75.96037637 67.45690601 68.30339992]
# new size: 10
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 10
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_12
# Right side: 0
# Left  side: 264
# Detected arm: left
# extremas: [15.57906506 18.40921569  9.95343305 12.9022444  11.14415985 11.05264294
#  11.81111126 13.38299803  9.40312552  9.89333249 12.96249101 10.47020818
#  11.34134564 15.07343745  9.85936106 12.69730599]
# angle change threshold: 22.740098172056967
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [179.6576659  179.64020134 179.34145404 179.89242919 179.67571187
#  179.73690655 179.92024848 179.76580531 179.6379551  179.52506158
#  179.33333314 179.70212799 179.75742554 178.67409111 178.62806252
#  179.51622418 178.65343773 179.59367634]
# angle change threshold: 20.362352848293835
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [169.8703122  170.40972685 173.63965003 170.61588347 169.26755983
#  170.67158113]
# angle change threshold: 21.909089863314147
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [96.76142427 90.3103465  89.43598248 91.9581254  93.42042473]
# angle change threshold: 22.827471013310085
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 5
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_13
# Right side: 0
# Left  side: 285
# Detected arm: left
# extremas: [13.65274291 10.0827643  12.20406079 14.21765913  7.46504965  9.84116968
#  10.28846956  6.60403388 13.02373451  8.13710217 10.57857922 12.48754013
#   9.1807836  12.33358034]
# angle change threshold: 23.313974055293354
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [179.31811803 179.38030797 179.3423414  179.09886771 179.53515683
#  179.55849534 178.98102764 179.21256647 179.09539949 179.4576412
#  179.07110387 179.07110387 178.78657701 179.72566204 178.89206743
#  179.46937904 179.11881016 179.40344013 179.26665324 177.86801028]
# angle change threshold: 20.383334589507488
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [169.67287114 169.75791983 169.20590914 170.47034849 166.13390086
#  163.85225393]
# angle change threshold: 21.703918657668073
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [91.13696821 89.1644571  86.827625   87.02706764 86.87723379]
# angle change threshold: 21.16465492367923
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 5
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_14
# Right side: 0
# Left  side: 324
# Detected arm: left
# extremas: [13.02125367 13.08507498 13.36382075 10.0460205  11.77776447  8.49132889
#   9.06874871  9.52379941  8.3004219   8.8919906   9.28128876 10.44772117
#  11.29887178  9.74215484 10.63221502 10.20415145  5.2116117   9.9226206
#   9.9226206 ]
# angle change threshold: 21.4728463397701
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [179.41919644 179.67647037 179.78600225 179.66894101 179.49573052
#  179.69519209 179.47531786 179.69319773 178.91411828 179.24608076
#  179.78260579 179.63282152 179.24235802 179.96471036 179.73147772
#  179.6159609  179.78846606 179.35214247 178.19413575 177.89558655
#  179.2270722  179.80551212]
# angle change threshold: 20.4061199991692
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [170.55439721 172.05271598 172.42810619 170.33827225 165.21600198
#  165.4393933  159.97982597]
# angle change threshold: 22.46146197147959
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [94.03437134 94.72433918 90.90901468 88.53104046 88.79347717 84.52349462]
# angle change threshold: 22.28313716408754
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 6
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_15
# Right side: 0
# Left  side: 636
# Detected arm: left
# extremas: [10.31362822  9.62116619  6.36281288  5.12544115  6.37652014  4.27889381
#   4.01572664  4.29021837  4.92688305  7.07544459  5.71709928  5.44990204
#   1.68718429  2.0597028   1.19060379  2.29941493  1.29295176  4.08043692
#   3.40968678  6.30300645  4.13619011  0.96339636  0.96134277  2.69090053
#   4.80480465  5.40129112  0.88838864  1.67036734  6.67543145  6.75095906
#   6.29906587  4.36727353  3.92851814  1.00368715  7.41622328  8.72495302
#   6.36540188  6.12444197  2.33167172]
# angle change threshold: 21.762510225983533
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [170.00979983 171.98244711 173.82021453 175.216446   172.96983841
#  172.5153869  173.53815915 177.71842582 173.31080891 173.775633
#  175.74718914 174.18525131 173.17625448 173.44164122 175.40472075
#  177.05433108 174.19199283 171.39050264 173.4068261  175.50382457
#  171.54026749 173.18225423 172.69910005 176.99933414 169.41125926
#  172.75823734 172.79035691 177.03529956 176.54087416 176.46298869]
# angle change threshold: 22.150146934819286
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [170.00301722 170.55353288 167.6308713  174.63323441 165.91090892
#  171.15356892 167.97451581 164.09772002 160.74588871]
# angle change threshold: 24.35602575501602
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [68.50753896 79.29091544 80.531643   68.81247985 63.02492996 79.35705694
#  84.26914248 76.44111345]
# angle change threshold: 28.37186551962597
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 8
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_16
# Right side: 0
# Left  side: 450
# Detected arm: left
# extremas: [ 7.93984693  7.37619106  7.45355551  1.77452689  7.12510526  3.91837089
#   9.31569046  8.53286494  4.84819839  1.80168278  1.70090811  3.2274618
#   3.00282803  4.1996587   1.81473869  2.34537562  2.03380094  2.13723673
#  10.8182363   2.05363602  3.62549196  4.20120712  4.60876162  4.33584869
#   2.10616629]
# angle change threshold: 22.36130708050214
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [174.55828454 177.56241121 178.55533081 178.59148118 173.08258263
#  172.82268734 175.08344573 177.50530774 174.47538385 175.38415845
#  179.69800755 179.73571885 179.73769542 179.23862617 170.69110759
#  177.83753353 171.6424501 ]
# angle change threshold: 22.82280897060931
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [170.20383206 168.57931799 164.75181235 167.35420463 168.58217255
#  162.53864465]
# angle change threshold: 23.065181561253997
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [73.28641518 79.24129822 68.89500549 82.06124254 63.04738153 76.28762204]
# angle change threshold: 32.34430286464342
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 6
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_17
# Right side: 0
# Left  side: 341
# Detected arm: left
# extremas: [11.5467449  10.86228531  6.18599009  9.11945742  7.7956569   3.23093899
#   8.70906317 10.90532317 15.20407286  5.98647373  6.57210371 12.4427342
#  12.57483133  6.78775832 13.47373082 13.60695447  9.49155861 13.29533519
#  13.28414388  9.26845218]
# angle change threshold: 23.500745039166215
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [167.78109429 163.97046787 166.54524029 161.39335467 161.58990005
#  162.97366702 162.92677308 161.25638414 163.27504386 160.8651989
#  161.45225265 160.48820049 160.69118544 162.55904892 160.27478034]
# angle change threshold: 21.797829091779505
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [179.15805214 175.38075111 178.45291967 178.05624727 179.62918628
#  173.38260564]
# angle change threshold: 23.01313233126566
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [73.65367472 67.82231754 74.64897703 77.98584312 75.05167226]
# angle change threshold: 24.73226340277208
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 5
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_18
# Right side: 0
# Left  side: 398
# Detected arm: left
# extremas: [14.79780224  7.54274633 10.96543255  7.4455425   9.07050292  6.91822794
#   6.89281213  6.98746422 11.63844153  5.95209246 11.78476526  6.94396609
#   7.96359303  8.70537428  5.75722986  6.22840105  5.93440756  7.29279143
#   5.47170829]
# angle change threshold: 22.65332878480184
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [161.19917363 159.69328025 159.67915524 159.80721659 161.62108695
#  161.77729083 159.15148759 158.87838042 160.97259608 160.56757161
#  160.5272352  160.89166684 160.54052272 160.74084667 159.36088493
#  159.14767268 159.43696463 159.47428468 159.93596216 160.84562506
#  161.93291117 162.63025912 160.89643795 162.13815517 161.81702802
#  161.44875024]
# angle change threshold: 20.748529775162282
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [174.14653156 172.59513656 164.49007852 169.85470669 166.75175872
#  165.99150206 164.10924179]
# angle change threshold: 23.461091015690155
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [71.01329588 74.52240708 72.64896851 72.38791526 75.88592082 74.95780282]
# angle change threshold: 22.01394531425473
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 6
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_19
# Right side: 0
# Left  side: 381
# Detected arm: left
# extremas: [11.87190352  5.06250333  4.95907829 11.00128167  5.15262427 11.61132032
#  12.50971999  5.51003204 10.90138834  5.433283    7.42879676  5.50871829
#   5.37124872 14.75349203  5.74981286 14.54759429]
# angle change threshold: 25.01711313686286
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [164.81540521 164.31100042 161.99379617 163.67311593 163.64502228
#  161.30346191 162.36989755 162.43727402 162.90173253 161.93993918
#  161.45044941 162.22531072 161.34691459 158.88531687 160.46710316
#  159.59391258 160.83880485 162.26642717 160.1114649  160.16827888
#  161.40006815 162.23426897 162.46439246]
# angle change threshold: 21.075926046464247
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [177.0109946  170.64597618 175.43757447 169.14430014 161.67571001
#  174.06787215 173.66640515]
# angle change threshold: 26.285351716461324
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [79.89561885 77.85778424 76.66328232 80.84500407 76.60534318 77.68049368]
# angle change threshold: 22.545773934795747
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 6
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_2
# Right side: 0
# Left  side: 254
# Detected arm: left
# extremas: [13.28682187  9.19407539 11.08391397 11.7498493   9.19593111 10.13678967
#   9.00051309  8.79703094  9.86872141  5.90283059  7.03669702  9.19017585
#   8.48523971 11.03318428]
# angle change threshold: 21.773912551676485
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [178.99278529 178.73930022 179.525399   179.23325306 176.94902606
#  176.99283989 179.3761977  178.80546323 177.28277772 179.10708192
#  179.13927917 178.95122426 179.78126248 179.35206724 179.60964411
#  176.29771268 178.16559264]
# angle change threshold: 21.05485790477364
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [169.53444818 165.63438087 164.39680861 166.50903737 164.83073135
#  167.83126869]
# angle change threshold: 22.38574233741492
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [89.74821733 92.32322535 89.18779893 84.99723006 78.36831486]
# angle change threshold: 24.132479627521462
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 5
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_20
# Right side: 0
# Left  side: 311
# Detected arm: left
# extremas: [10.62561323 11.41210815 13.26791194 13.72122983 10.76104102 11.63434168
#  11.08711084 11.65271776 11.21062435 10.85263414]
# angle change threshold: 20.982447494339027
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [178.70663033 179.23994686 178.58208612 179.2804417  178.19120122
#  179.63211469 179.28123792 179.33535021 179.74575187 179.85380711
#  179.26175726 178.92285257 178.5738731  179.17860136 179.87533464
#  179.39637512 179.11727399 179.67977394 179.39645726 178.8703949 ]
# angle change threshold: 20.529182522966384
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [171.50922174 168.90339646 170.01833245 171.94458985 168.68402354
#  169.56120801 170.19250175]
# angle change threshold: 21.73601052916075
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [79.15431223 85.82284159 87.96323401 83.8588575  85.83466325 86.94977979]
# angle change threshold: 23.200844113986847
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 6
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_21
# Right side: 0
# Left  side: 288
# Detected arm: left
# extremas: [ 9.79451586  9.53225634  5.69533181  9.36743979  9.41682068  9.71961856
#   5.50735064 11.6980244   5.85796329 11.27809463 12.35540692 14.96835391]
# angle change threshold: 23.043351291238647
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [178.88552758 179.80344379 179.39953639 179.17848548 179.34812852
#  179.5005663  179.30730992 179.37867655 179.09579997 179.11999904
#  177.62274706 177.6252596  178.81822351 178.99609207 179.11758865
#  173.29976737 179.46775142]
# angle change threshold: 21.088409555613296
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [165.28398277 161.32826203 162.04031955 156.79534044 158.83434204
#  153.02353369]
# angle change threshold: 23.55251346584626
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [82.71785459 83.84048268 81.61440349 78.09160894 79.1587314 ]
# angle change threshold: 21.98465607502806
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 5
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_22
# Right side: 0
# Left  side: 311
# Detected arm: left
# extremas: [12.64536378 17.10967363 12.77105088 12.59095121 12.59095121 13.94239268
#   7.66629849 11.11524067 12.98462152  9.10147116 10.8341455  11.88851663
#  11.2609735   7.83272508 12.00773054  9.49596168]
# angle change threshold: 22.622776845322104
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [175.93969208 176.61346626 178.68226825 179.2699401  179.23966281
#  178.75690923 178.59262384 178.81394267 177.83542048 177.97399031
#  178.71176059 178.59859802 176.94243087 179.45373042 179.02385283
#  178.77657112 179.50926516 179.66806121 177.56210377 179.59488692
#  178.66075996]
# angle change threshold: 20.850294580720142
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [167.83825411 171.33205625 167.60031612 163.30108671 163.38220014
#  157.94670394 156.95172941  95.81200813]
# angle change threshold: 31.310868160193102
#
#
# Testing to filter by average angle change....
# Testing Finished
# Filtering by average angle change...
# extrema array size: 8
# angles removed: [95.81200812610662]
#
# New extrema array: [167.83825411 171.33205625 167.60031612 163.30108671 163.38220014
#  157.94670394 156.95172941]
# new size: 7
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [93.72452695 93.49120353 88.5884085  86.86094235 87.78995668 87.68851671
#  95.81055217]
# angle change threshold: 22.66934572663018
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 7
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_23
# Right side: 0
# Left  side: 450
# Detected arm: left
# extremas: [3.4803581  5.12573709 4.25560374 2.05016782 1.13916068 1.90297677
#  4.02982371 3.75091385 3.07053555 2.48756834 2.8345148  1.01352879
#  1.9212258  4.94432426 3.51086102 2.82984695 3.65106923 3.69051286
#  1.58357193 0.83648531 3.18896603 3.23344944 1.15093385 1.28714345
#  4.6016293  4.6016293  6.09145686 7.01735684]
# angle change threshold: 21.197728711623775
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [169.66806743 167.88747267 168.21161013 176.08137494 176.12386541
#  171.94266115 170.31857663 171.41161374 175.07584673 173.52184846
#  168.28331877 170.14623536 174.87493624 175.59405254 172.24913181
#  172.55238885 174.54162828 174.28074263 173.75179488 176.37783363
#  179.48002983 171.53563341 170.44760841 173.29517427 177.78162305]
# angle change threshold: 22.633530404320002
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [172.8232701  170.96685519 167.15204663 159.29744708 157.68616149
#  170.66028756]
# angle change threshold: 25.62224693846722
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [73.81770567 69.96665738 72.25149579 64.85842514 77.20846647]
# angle change threshold: 26.469749665949628
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 5
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_24
# Right side: 0
# Left  side: 417
# Detected arm: left
# extremas: [5.20314579 1.50396847 5.2267099  3.75134696 4.48733805 1.93861588
#  8.69834098 2.78187216 2.82599945 7.39819407 7.33688553 1.1949526
#  5.09132409 2.92590419 3.19494088 1.90665356 1.52621145 5.71846534
#  7.32424448 3.88174205 4.25278721 2.44684055 4.72636632 4.70717397
#  6.15969364]
# angle change threshold: 22.45191978601072
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [173.68676772 173.29560782 174.57470669 178.93037507 178.75720665
#  177.6312765  177.36588011 177.73581403 179.84033138 179.274143
#  178.06786397 179.0405472  179.09328659 179.72337335 179.21460861
#  179.70708115 176.70976857 179.47748245 179.73561227 179.66517336
#  179.64547269]
# angle change threshold: 21.03036916597854
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [166.02736017 172.69986104 161.40579735 166.78574161 165.02048398]
# angle change threshold: 26.27794160805881
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [71.58564225 70.96621631 71.47217538 63.97974332]
# angle change threshold: 22.872605686362085
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 4
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_25
# Right side: 0
# Left  side: 387
# Detected arm: left
# extremas: [14.71432404 14.09802203 15.93704967 15.19853685  5.80768482 12.23443381
#   8.59534003  4.89418008  9.99855898 12.84174737 14.14998603  6.52936227
#   7.41157194 10.86263246 11.29671169  4.3747134   6.21242249 13.0286783
#  13.55720014  4.02142376]
# angle change threshold: 23.87556514469629
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [161.66753079 161.61439555 160.96730099 160.1033919  164.29223324
#  160.78002991 162.27687283 162.38584003 165.36687861 162.57092481
#  166.41478992 164.65056113 163.83939557 168.75056455 169.78374982
#  168.16412795]
# angle change threshold: 22.04208144291531
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [179.11112613 179.14262985 177.36375647 178.26834234 177.62824991
#  179.29213473 179.36834246 178.58599725 177.41443844]
# angle change threshold: 20.881131494521334
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [13, 61, 8, 54, 64, 60, 62, 10]
# threshold: 28
# counts less than threshold: [13, 8, 10]
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [178.30169659  71.68328929 176.40325966  70.7493979   72.37919791
#   76.48772862  72.85749631 177.00298302]
# angle change threshold: 81.50089845718637
#
#
# Testing to filter by average angle change....
# Testing Finished
# Filtering by average angle change...
# extrema array size: 8
# angles removed: [178.30169659006262, 176.40325966342434, 177.00298302031013]
#
# New extrema array: [71.68328929 70.7493979  72.37919791 76.48772862 72.85749631]
# new size: 5
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 5
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_26
# Right side: 0
# Left  side: 360
# Detected arm: left
# extremas: [12.63090984 11.69148973 10.85822258 10.21233792  5.85048548  9.06206877
#   9.74937084 11.02255456 10.37374015  7.01090509  7.50049456  7.57418643
#   8.69038925  9.99279874  8.27319535 11.2384989   9.97283975  9.73909595
#  11.58376008]
# angle change threshold: 21.49861169935206
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [163.14682276 162.50302789 163.77823153 162.84864244 163.82814274
#  164.57029956 162.91578021 162.9310101  165.85058981 163.68117371
#  163.16674359 167.28253133 167.08953475 165.02611464 162.02973815
#  163.20154465 162.7404677  169.90881409 164.01702085]
# angle change threshold: 21.99472354858162
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [179.37044731 175.28410337 174.83053155 176.84911462 173.32532835
#  175.98770331]
# angle change threshold: 22.548932011547738
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [76.26973078 73.02085551 74.9905865  80.15431093 78.19136424]
# angle change threshold: 23.08631934480682
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 5
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_27
# Right side: 0
# Left  side: 390
# Detected arm: left
# extremas: [10.78272974 10.12620855  9.49282233  7.58550343 10.54976283 11.46199101
#   8.96553311 11.50299642 10.74268796 11.80983329 10.57459256  9.63017101
#  10.48824337 11.09642754 10.58070651 10.01315404 11.74312483  9.63675798]
# angle change threshold: 21.323565813625898
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [166.10090662 164.20438456 163.90844366 165.82850203 162.73897505
#  165.65684829 162.74238917 162.93181197 165.19181742 162.83623235
#  166.56610386 163.10718776 165.38226971 162.93357052]
# angle change threshold: 22.288612520193507
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [9, 15, 36, 33, 34, 16, 5, 39, 27, 46, 25, 42, 20]
# threshold: 26
# counts less than threshold: [9, 15, 16, 5, 25, 20]
# Array filtering: Done
# extremas: [171.98676222 172.73864921 171.56054533 170.48637942 165.47632281
#  157.12395648]
# angle change threshold: 23.273315943417277
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [73.66865266 71.43092847 72.51001388 69.59137688 66.4874386 ]
# angle change threshold: 22.33484622140923
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 5
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_28
# Right side: 0
# Left  side: 353
# Detected arm: left
# extremas: [15.23812891  8.01399699 11.76022129  6.30967539 10.30337847 12.3692523
#   3.00075986 12.61632559 12.33028367  5.24404774 11.63835158  5.04232671
#  14.87387575  5.81198982 16.31952271]
# angle change threshold: 26.516293685615018
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [163.67934491 162.46398689 165.51785653 165.02170106 160.17695892
#  165.41353182 163.28202716 162.50165306 164.41956257 166.08252939
#  165.68779924 165.17922624 165.3088717  163.78471862 164.41296009
#  165.15710125 162.76256972 162.65927997 162.95672105 162.06476466]
# angle change threshold: 21.524008228863934
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [177.94941287 176.09668316 175.37123264 178.08808246 175.68698066
#  178.21456928 178.7394923 ]
# angle change threshold: 21.791440583072312
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [74.07250578 75.34487046 74.57740896 76.6834431  67.5311288  75.8465427 ]
# angle change threshold: 24.322717703527218
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 6
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_29
# Right side: 0
# Left  side: 293
# Detected arm: left
# extremas: [15.5835738  14.88230143  5.1371536  16.27705258 13.99385112  3.88304255
#  12.55406472 11.79508099 11.86677982]
# angle change threshold: 25.435254245415603
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [43, 29, 27, 39, 24, 32, 38, 10]
# threshold: 23
# counts less than threshold: [10]
# Array filtering: Done
# extremas: [164.06186916 162.14262272 163.24420149 162.65871584 162.89716371
#  161.69047029 161.96763096 166.85001946 160.73162257 162.37227491
#  162.20574528 159.86626266 161.87201583 158.95196902]
# angle change threshold: 21.953989440636445
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [179.57184943 179.10570466 178.85601739 178.67771027 171.62672123
#  172.0396177 ]
# angle change threshold: 21.67160493564624
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [79.93991898 83.01019923 82.49344135 75.02276416 83.50313962]
# angle change threshold: 24.884522694726314
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 5
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_3
# Right side: 0
# Left  side: 201
# Detected arm: left
# extremas: [10.15340781  7.6671113  12.17787847 13.80825037 10.77236818 10.59574541
#  11.49044925 12.81566804 10.21282171  7.96327205 10.24132171]
# angle change threshold: 22.119030883482466
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [178.4004894  178.00148717 179.3461949  178.45545416 179.0366051
#  178.76862651 178.62460389 179.51268187 179.18084445]
# angle change threshold: 20.60593977992546
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [171.12013758 168.37259957 169.35919052 170.23104937]
# angle change threshold: 21.53532926899474
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [85.18504383 82.45228345 80.48505974]
# angle change threshold: 22.349992044615973
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 3
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_30
# Right side: 0
# Left  side: 270
# Detected arm: left
# extremas: [ 9.49322737  7.54300549 13.0162761   4.05869765 13.08239475 11.87665801
#   4.48807324 10.85167276  6.38034736  7.06281603  3.55063169]
# angle change threshold: 24.902866750224216
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [158.367916   164.41230571 160.71025645 161.5489151  161.58814339
#  161.00948802 162.57048399 162.64577277 159.3888676  160.70309109
#  163.1519732  159.14242548 162.76634769 161.35656562 159.04339438
#  164.60571613 160.30306415]
# angle change threshold: 22.567542111664565
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [167.54540542 172.95114661 170.57829753 171.95424964 171.81510262
#  165.65323067]
# angle change threshold: 23.09111227012779
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [76.78908988 77.73225045 83.47454787 81.49068481 76.18043793]
# angle change threshold: 23.49489198523469
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 5
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_31
# Right side: 0
# Left  side: 522
# Detected arm: left
# extremas: [ 4.65905272  3.80025184  3.07802005  4.39319942  6.54723769  4.13483282
#   9.80153299  4.0323999   7.64216506 10.04264547 10.353369    5.7521733
#   6.96206976 11.07644486  4.28553088  9.4268592   5.98326874  3.78008486
#   6.00617231  4.89419486  4.06668934  6.17135158  8.71221466  9.86533705
#   4.59204108 10.57263672  4.99551928]
# angle change threshold: 23.058429561666454
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [165.63390458 162.82333911 160.93801304 164.95098342 159.14140472
#  159.04498269 162.91590184 159.30545941 163.27859174 159.74841981
#  162.63474989 159.68883334 162.82624829 159.35419199 162.1090257
#  160.67310775 159.70610452 162.70403205 160.33791237 165.13365363
#  161.44246374 163.82100296 163.42934135 162.39011566 163.12179016
#  161.50705676 160.85920108 162.06170603 161.52919906]
# angle change threshold: 22.48531005774142
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [163.31600418 158.86964006 166.30812648 166.84356167 167.86818591
#  162.49892178 169.15181917 162.67991477 162.21977212 166.71012245
#  166.34776929 167.4112057 ]
# angle change threshold: 23.483205313978157
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [81.60777818 75.52425345 81.22179654 74.63844738 75.58563324 74.93051873
#  76.77948755 80.9782289  74.21480323 77.99084013 78.93246867]
# angle change threshold: 23.749551864415736
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 11
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_4
# Right side: 0
# Left  side: 246
# Detected arm: left
# extremas: [11.66227728 13.9454557  13.88213732 13.84372172 12.27495624 11.42744669
#  13.63365769  9.58027594 10.77432566 12.41613539  8.09454628  8.95719882]
# angle change threshold: 21.734625570303272
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [177.97148866 178.92010171 179.3838571  178.51389873 177.94357903
#  179.24237455 179.02709882 179.03715032 178.57427886 178.45915892
#  179.7724709  179.52806326 179.69086775 179.4913701  178.53673987
#  179.44792355]
# angle change threshold: 20.582706421414528
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [169.80170563 170.13483745 169.02015991 167.69304177 169.88457893
#  173.62992257]
# angle change threshold: 21.742361662602416
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [88.89679636 90.73750356 91.05330849 90.29044377 89.91883717]
# angle change threshold: 20.82274586374909
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 5
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_5
# Right side: 0
# Left  side: 198
# Detected arm: left
# extremas: [ 9.22133267  9.5654796   8.95515057 10.21827761  8.48327542  8.13373644
#   9.44786833 10.55636482  2.77851878  9.13529036  8.90801004]
# angle change threshold: 22.10866704690983
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [179.00224207 178.55914599 179.49307026 179.3962299  178.80123728
#  179.56050612 179.38519641 179.62008073 179.32577582 178.93533663
#  177.50075382]
# angle change threshold: 20.535764312592498
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [164.3209546  161.37400155 160.17706769 159.15398952]
# angle change threshold: 21.722321693897005
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [91.15770939 87.51264958 86.83391336]
# angle change threshold: 22.161898010535005
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 3
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_6
# Right side: 0
# Left  side: 450
# Detected arm: left
# extremas: [7.39826291 5.98643734 7.74737011 4.1858982  4.88843458 3.72808902
#  1.19261684 2.32410877 0.94850309 3.53147225 6.44861796 6.96258454
#  2.62575331 3.02077869 2.60062009 2.03383134 1.07263872 4.00156332
#  5.83651002 4.0275036  1.99099927 2.0445955  2.31030026]
# angle change threshold: 21.602838321328377
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [169.07783595 170.71918546 170.71918546 171.5215112  171.72192629
#  172.18873119 171.73732521 172.66646871 173.1839293  172.98271858
#  171.89134586 170.28652755 171.41299833 173.69850228 171.81282051
#  174.80102125 175.76689295 173.9038396  174.98297137 174.5689173
#  173.96365886 173.51272831 174.71470925 172.17200677 173.87335912
#  174.08335391 175.24842868 172.35860136 173.34387513 173.62160354
#  175.91794961 176.30473094]
# angle change threshold: 21.136371818882683
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [175.48805569 178.15744791 173.05843937 173.63106936 170.08415881
#  171.49595016]
# angle change threshold: 22.659946529331894
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [80.34802897 80.61654646 87.12822915 71.24799693 70.20311759]
# angle change threshold: 25.926327934384013
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 5
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_7
# Right side: 1
# Left  side: 491
# Detected arm: left
# extremas: [3.56668657 6.01242183 5.25981536 4.30595183 4.39594064 0.50537356
#  1.1633932  5.96247263 4.05682122 3.09229018 3.13657273 2.53176126
#  8.77812582 5.55259808 2.07643215 2.49431134 2.05235273 2.2720885
#  6.50163921 4.20811282 0.82404709 2.2801243  2.56525797 6.83215307
#  0.73959649 0.77041598 5.57151818]
# angle change threshold: 22.229865214344862
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [176.53977193 174.61686711 172.03527419 177.56109223 177.65624761
#  176.91064637 175.24814552 172.38723251 172.65983645 172.79910285
#  173.94278326 172.50108374 173.81417022 175.51810489 176.70714278
#  176.34451545 176.45809938 170.51706202 172.22774942 177.37974619
#  177.72734422 172.65646688 175.44550221 174.48926897]
# angle change threshold: 21.95832488156964
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [173.72251885 168.66763986 168.61140552 172.23346094 170.28608663
#  168.13262981  74.68228546]
# angle change threshold: 37.71405737410302
#
#
# Testing to filter by average angle change....
# Testing Finished
# Filtering by average angle change...
# extrema array size: 7
# angles removed: [74.68228546468276]
#
# New extrema array: [173.72251885 168.66763986 168.61140552 172.23346094 170.28608663
#  168.13262981]
# new size: 6
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [96, 10, 87, 99, 104]
# threshold: 44
# counts less than threshold: [10]
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [ 75.51927018 167.83176167  63.32455932  74.86240349  70.99388873
#   74.67974744]
# angle change threshold: 63.18238229920895
#
#
# Testing to filter by average angle change....
# Testing Finished
# Filtering by average angle change...
# extrema array size: 6
# angles removed: [167.83176167392648]
#
# New extrema array: [75.51927018 63.32455932 74.86240349 70.99388873 74.67974744]
# new size: 5
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 5
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_8
# Right side: 0
# Left  side: 443
# Detected arm: left
# extremas: [4.5775037  6.12544411 6.99205996 3.77512673 8.51317628 5.53418504
#  3.39325812 4.00115983 5.83285344 7.67574802 3.50402151 1.11919101
#  1.53775416 2.26719954 3.45279156 5.31377222 2.53930855 4.74964654
#  5.81611987 5.37259762 8.59443816 0.97597229 0.89186179]
# angle change threshold: 22.179195429986088
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [168.24874301 170.02222776 169.57732757 172.32909604 174.28630247
#  169.7890536  171.77100485 171.351975   167.76349803 168.63553238
#  173.18957053 172.5772078  171.93509361 171.34528993 169.30911006
#  171.10902773 175.70411526 173.99355427 173.66529143 178.37610662
#  179.51068836 179.8323643  170.19090063 170.40298659 171.42135092]
# angle change threshold: 22.174725651437562
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [170.34296603 170.64003081 167.70418892 169.01804796 163.85042879
#  168.19028831  85.59378954]
# angle change threshold: 36.10845719334995
#
#
# Testing to filter by average angle change....
# Testing Finished
# Filtering by average angle change...
# extrema array size: 7
# angles removed: [85.59378954253226]
#
# New extrema array: [170.34296603 170.64003081 167.70418892 169.01804796 163.85042879
#  168.19028831]
# new size: 6
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [86, 84, 10, 89, 98]
# threshold: 41
# counts less than threshold: [10]
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [ 66.96679207  74.62983524 166.91609354  69.27930776  80.78622794
#   85.59307949]
# angle change threshold: 62.77997179290245
#
#
# Testing to filter by average angle change....
# Testing Finished
# Filtering by average angle change...
# extrema array size: 6
# angles removed: [166.91609353663728]
#
# New extrema array: [66.96679207 74.62983524 69.27930776 80.78622794 85.59307949]
# new size: 5
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 5
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Starting...
# Keypoints from folder: triceps_pushdown_correct_9
# Right side: 0
# Left  side: 378
# Detected arm: left
# extremas: [ 7.66380277 15.84083182 11.68253459 16.69485737 13.67270958 13.76115331
#  10.36845542 12.10533945  8.39544082 13.48649651 10.97135672 15.77699091]
# angle change threshold: 23.791777347821636
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [164.10001932 164.13959873 162.57287709 160.73466077 163.79203836
#  159.90754804 160.56467891 162.10288539 162.03046195 162.22133384
#  164.33093882 164.0892003  161.09413426 162.20227337 162.31313264
#  161.20292996 163.69661695 163.68604519]
# angle change threshold: 21.354405135180137
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
# extremas: [176.51814925 175.71768288 177.49685199 177.77305199 179.32760109
#  179.19540401 178.19297454 178.76292193 177.10985938]
# angle change threshold: 20.971002633782934
#
#
# Testing to filter by average angle change....
# Filter by angle change N/A
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [6, 6, 48, 8, 62, 67, 52, 63]
# threshold: 27
# counts less than threshold: [6, 6, 8]
#
# Starting another stage of filtering...
#
#
# Testing to filter by number of angles inbetween....
# Testing Finished
# Filtering by number of angles inbetween:
# count_list: [13, 57, 62, 67, 52, 63]
# threshold: 32
# counts less than threshold: [13]
# Array filtering: Done
#
# ----------------------------Filtering minimas-------------------------------------
# extremas: [175.66282128 175.65978336  66.39169958 176.90071794  72.8944156
#   71.00640388  72.18063486  79.78370345]
# angle change threshold: 67.77882195484406
#
#
# Testing to filter by average angle change....
# Testing Finished
# Filtering by average angle change...
# extrema array size: 8
# angles removed: [175.65978336170903, 176.9007179392655]
#
# New extrema array: [175.66282128  66.39169958  72.8944156   71.00640388  72.18063486
#   79.78370345]
# new size: 6
#
# Testing to filter by number of angles inbetween....
# Array filtering: Done
#
# Size of minima array: 6
# ------------------------------------------------------------------------------------------
# ========================================================================================================================
#
# Minimum Upper Arm Forearm threshold: 63.02492995922685
# Maximum Upper Arm Forearm threshold: 179.7288356443576
# Maximum Upper Arm Trunk threshold: 19.248771657602756
# Minimum Trunk Knee threshold: 152.2253801476131
# Maximum Trunk Knee threshold: 179.96471035786146

# %%
a = [1,2,3]
a[-1:]
print(a)
# Out:
# [1, 2, 3]
